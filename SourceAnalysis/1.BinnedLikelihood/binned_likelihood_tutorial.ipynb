# %% [markdown]
# # Binned Likelihood Tutorial
#
# The detection, flux determination, and spectral modeling of Fermi LAT sources is accomplished by a maximum likelihood optimization technique as described in the [Likelihood Overview](https://fermi.gsfc.nasa.gov/ssc/data/analysis/likelihood/likelihood_overview.html) (see also, e.g., [Abdo, A. A. et al. 2009, ApJS, 183, 46](http://adsabs.harvard.edu/abs/2009ApJS..183...46A)).
#
# To illustrate how to use the Likelihood software, this tutorial gives a step-by-step description for performing a binned likelihood analysis.

# %% [markdown]
# ## Binned vs Unbinned Likelihood
#
# Binned likelihood analysis is the preferred method for most types of LAT analysis (see [Likelihood Overview](https://fermi.gsfc.nasa.gov/ssc/data/analysis/likelihood/likelihood_overview.html)).
#
# However, when analyzing data over short time periods (with few events), it is better to use the **unbinned** analysis.
#
# To perform an unbinned likelihood analysis, see the [Unbinned Likelihood](https://github.com/fermi-lat/AnalysisThreads/blob/master/SourceAnalysis/2.UnbinnedLikelihood/likelihood_tutorial.ipynb) tutorial.
#
# **Additional references**:
# * [SciTools References](https://fermi.gsfc.nasa.gov/ssc/data/analysis/scitools/references.html)
# * Descriptions of available [Spectral and Spatial Models](https://fermi.gsfc.nasa.gov/ssc/data/analysis/scitools/source_models.html)
# * Examples of [XML Model Definitions for Likelihood](https://fermi.gsfc.nasa.gov/ssc/data/analysis/scitools/xml_model_defs.html#xmlModelDefinitions):
#     * [Power Law](https://fermi.gsfc.nasa.gov/ssc/data/analysis/scitools/xml_model_defs.html#powerlaw)
#     * [Broken Power Law](https://fermi.gsfc.nasa.gov/ssc/data/analysis/scitools/xml_model_defs.html#brokenPowerLaw)
#     * [Broken Power Law 2](https://fermi.gsfc.nasa.gov/ssc/data/analysis/scitools/xml_model_defs.html#powerLaw2)
#     * [Log Parabola](https://fermi.gsfc.nasa.gov/ssc/data/analysis/scitools/xml_model_defs.html#logParabola)
#     * [Exponential Cutoff](https://fermi.gsfc.nasa.gov/ssc/data/analysis/scitools/xml_model_defs.html#expCutoff)
#     * [BPL Exponential Cutoff](https://fermi.gsfc.nasa.gov/ssc/data/analysis/scitools/xml_model_defs.html#bplExpCutoff)
#     * [Gaussian](https://fermi.gsfc.nasa.gov/ssc/data/analysis/scitools/xml_model_defs.html#gaussian)
#     * [Constant Value](https://fermi.gsfc.nasa.gov/ssc/data/analysis/scitools/xml_model_defs.html#constantValue)
#     * [File Function](https://fermi.gsfc.nasa.gov/ssc/data/analysis/scitools/xml_model_defs.html#fileFunction)
#     * [Band Function](https://fermi.gsfc.nasa.gov/ssc/data/analysis/scitools/xml_model_defs.html#bandFunction)
#     * [PL Super Exponential Cutoff](https://fermi.gsfc.nasa.gov/ssc/data/analysis/scitools/xml_model_defs.html#plSuperExpCutoff)

# %% [markdown]
# # Prerequisites
#
# You will need an **event** data file, a **spacecraft** data file (also referred to as the "pointing and livetime history" file), and the current **background models** (available for [download](https://fermi.gsfc.nasa.gov/ssc/data/access/lat/BackgroundModels.html)). They are also found in code cells below.
#
# You may choose to select your own data files, or to use the files provided within this tutorial.
#
# Custom data sets may be retrieved from the [Lat Data Server](http://fermi.gsfc.nasa.gov/cgi-bin/ssc/LAT/LATDataQuery.cgi).

# %% [markdown]
# # Outline
#
# 1. **Make Subselections from the Event Data**
#
#     Since there is computational overhead for each event associated with each diffuse component, it is useful to filter out any events that are not within the extraction region used for the analysis.
#
#
# 2. **Make Counts Maps from the Event Files**
#
#     By making simple FITS images, we can inspect our data and pick out obvious sources.
#
#
# 3. **Download the latest diffuse models**
#
#     The recommended models for a normal point source analysis are `gll_iem_v07.fits` (a very large file) and `iso_P8R3_SOURCE_V3_v1.txt`. All of the background models along with a description of the models are available [here](https://fermi.gsfc.nasa.gov/ssc/data/access/lat/BackgroundModels.html).
#
#
# 4. **Create a Source Model XML File**
#
#     The source model XML file contains the various sources and their model parameters to be fit using the **gtlike** tool.
#
#
# 5. **Create a 3D Counts Cube**
#
#     The binned counts cube is used to reduce computation requirements in regions with large numbers of events.
#
#
# 6. **Compute Livetimes**
#
#     Precomputing the livetime for the dataset speeds up the exposure calculation.
#
#
# 7. **Compute Exposure Cube**
#
#     This accounts for exposure as a function of energy, based on the cuts made. The exposure map must be recomputed if any change is made to the data selection or binning.
#
#
# 8. **Compute Source Maps**
#
#     Here the exposure calculation is applied to each of the sources described in the model.
#
#
# 9. **Perform the Likelihood Fit**
#
#     Fitting the data to the model provides flux, errors, spectral indices, and other information.
#
#
# 10. **Create a Model Map**
#
#     This can be compared to the counts map to verify the quality of the fit and to make a residual map.

# %% [markdown]
# # 1. Make subselections from the event data
#
# For this case we will use two years of LAT Pass 8 data.
#
# >**NOTE**: The ROI used by the binned likelihood analysis is defined by the 3D counts map boundary. The region selection used in the data extraction step, which is conical, must fully contain the 3D counts map spatial boundary, which is square.
#
# Selection of data:
#
#     Search Center (RA, DEC) =(193.98, -5.82)
#     Radius = 15 degrees
#     Start Time (MET) = 239557417 seconds (2008-08-04 T15:43:37)
#     Stop Time (MET) = 302572802 seconds (2010-08-04 T00:00:00)
#     Minimum Energy = 100 MeV
#     Maximum Energy = 500000 MeV
#
# This two-year dataset generates numerous data files. We provide the user with the original event data files and the accompanying spacecraft file:
#
# * L181126210218F4F0ED2738_PH00.fits (5.0 MB)
# * L181126210218F4F0ED2738_PH01.fits (10.5 MB)
# * L181126210218F4F0ED2738_PH02.fits (6.5 MB)
# * L181126210218F4F0ED2738_PH03.fits (9.2 MB)
# * L181126210218F4F0ED2738_PH04.fits (7.4 MB)
# * L181126210218F4F0ED2738_PH05.fits (6.2 MB)
# * L181126210218F4F0ED2738_PH06.fits (4.5 MB)
# * L181126210218F4F0ED2738_SC00.fits (256 MB spacecraft file)

# %%
# !wget https://fermi.gsfc.nasa.gov/ssc/data/analysis/scitools/data/BinnedLikelihood/L181126210218F4F0ED2738_PH00.fits
# !wget https://fermi.gsfc.nasa.gov/ssc/data/analysis/scitools/data/BinnedLikelihood/L181126210218F4F0ED2738_PH01.fits
# !wget https://fermi.gsfc.nasa.gov/ssc/data/analysis/scitools/data/BinnedLikelihood/L181126210218F4F0ED2738_PH02.fits
# !wget https://fermi.gsfc.nasa.gov/ssc/data/analysis/scitools/data/BinnedLikelihood/L181126210218F4F0ED2738_PH03.fits
# !wget https://fermi.gsfc.nasa.gov/ssc/data/analysis/scitools/data/BinnedLikelihood/L181126210218F4F0ED2738_PH04.fits
# !wget https://fermi.gsfc.nasa.gov/ssc/data/analysis/scitools/data/BinnedLikelihood/L181126210218F4F0ED2738_PH05.fits
# !wget https://fermi.gsfc.nasa.gov/ssc/data/analysis/scitools/data/BinnedLikelihood/L181126210218F4F0ED2738_PH06.fits
# !wget https://fermi.gsfc.nasa.gov/ssc/data/analysis/scitools/data/BinnedLikelihood/L181126210218F4F0ED2738_SC00.fits
# Out:
# --2025-12-16 17:14:04--  https://fermi.gsfc.nasa.gov/ssc/data/analysis/scitools/data/BinnedLikelihood/L181126210218F4F0ED2738_PH00.fits
# Resolving fermi.gsfc.nasa.gov (fermi.gsfc.nasa.gov)... 129.164.179.26
# Connecting to fermi.gsfc.nasa.gov (fermi.gsfc.nasa.gov)|129.164.179.26|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5189760 (4.9M) [application/fits]
# Saving to: ‘L181126210218F4F0ED2738_PH00.fits’
#
# L181126210218F4F0ED 100%[===================>]   4.95M  2.75MB/s    in 1.8s
#
# 2025-12-16 17:14:06 (2.75 MB/s) - ‘L181126210218F4F0ED2738_PH00.fits’ saved [5189760/5189760]
#
# --2025-12-16 17:14:06--  https://fermi.gsfc.nasa.gov/ssc/data/analysis/scitools/data/BinnedLikelihood/L181126210218F4F0ED2738_PH01.fits
# Resolving fermi.gsfc.nasa.gov (fermi.gsfc.nasa.gov)... 129.164.179.26
# Connecting to fermi.gsfc.nasa.gov (fermi.gsfc.nasa.gov)|129.164.179.26|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 10995840 (10M) [application/fits]
# Saving to: ‘L181126210218F4F0ED2738_PH01.fits’
#
# L181126210218F4F0ED 100%[===================>]  10.49M  3.34MB/s    in 3.1s
#
# 2025-12-16 17:14:10 (3.34 MB/s) - ‘L181126210218F4F0ED2738_PH01.fits’ saved [10995840/10995840]
#
# --2025-12-16 17:14:10--  https://fermi.gsfc.nasa.gov/ssc/data/analysis/scitools/data/BinnedLikelihood/L181126210218F4F0ED2738_PH02.fits
# Resolving fermi.gsfc.nasa.gov (fermi.gsfc.nasa.gov)... 129.164.179.26
# Connecting to fermi.gsfc.nasa.gov (fermi.gsfc.nasa.gov)|129.164.179.26|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6799680 (6.5M) [application/fits]
# Saving to: ‘L181126210218F4F0ED2738_PH02.fits’
#
# L181126210218F4F0ED 100%[===================>]   6.48M  3.45MB/s    in 1.9s
#
# 2025-12-16 17:14:12 (3.45 MB/s) - ‘L181126210218F4F0ED2738_PH02.fits’ saved [6799680/6799680]
#
# --2025-12-16 17:14:12--  https://fermi.gsfc.nasa.gov/ssc/data/analysis/scitools/data/BinnedLikelihood/L181126210218F4F0ED2738_PH03.fits
# Resolving fermi.gsfc.nasa.gov (fermi.gsfc.nasa.gov)... 129.164.179.26
# Connecting to fermi.gsfc.nasa.gov (fermi.gsfc.nasa.gov)|129.164.179.26|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 9676800 (9.2M) [application/fits]
# Saving to: ‘L181126210218F4F0ED2738_PH03.fits’
#
# L181126210218F4F0ED 100%[===================>]   9.23M  2.74MB/s    in 3.4s
#
# 2025-12-16 17:14:16 (2.70 MB/s) - ‘L181126210218F4F0ED2738_PH03.fits’ saved [9676800/9676800]
#
# --2025-12-16 17:14:16--  https://fermi.gsfc.nasa.gov/ssc/data/analysis/scitools/data/BinnedLikelihood/L181126210218F4F0ED2738_PH04.fits
# Resolving fermi.gsfc.nasa.gov (fermi.gsfc.nasa.gov)... 129.164.179.26
# Connecting to fermi.gsfc.nasa.gov (fermi.gsfc.nasa.gov)|129.164.179.26|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 7793280 (7.4M) [application/fits]
# Saving to: ‘L181126210218F4F0ED2738_PH04.fits’
#
# L181126210218F4F0ED 100%[===================>]   7.43M  3.22MB/s    in 2.3s
#
# 2025-12-16 17:14:19 (3.22 MB/s) - ‘L181126210218F4F0ED2738_PH04.fits’ saved [7793280/7793280]
#
# --2025-12-16 17:14:19--  https://fermi.gsfc.nasa.gov/ssc/data/analysis/scitools/data/BinnedLikelihood/L181126210218F4F0ED2738_PH05.fits
# Resolving fermi.gsfc.nasa.gov (fermi.gsfc.nasa.gov)... 129.164.179.26
# Connecting to fermi.gsfc.nasa.gov (fermi.gsfc.nasa.gov)|129.164.179.26|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6497280 (6.2M) [application/fits]
# Saving to: ‘L181126210218F4F0ED2738_PH05.fits’
#
# L181126210218F4F0ED 100%[===================>]   6.20M  3.10MB/s    in 2.0s
#
# 2025-12-16 17:14:21 (3.10 MB/s) - ‘L181126210218F4F0ED2738_PH05.fits’ saved [6497280/6497280]
#
# --2025-12-16 17:14:22--  https://fermi.gsfc.nasa.gov/ssc/data/analysis/scitools/data/BinnedLikelihood/L181126210218F4F0ED2738_PH06.fits
# Resolving fermi.gsfc.nasa.gov (fermi.gsfc.nasa.gov)... 129.164.179.26
# Connecting to fermi.gsfc.nasa.gov (fermi.gsfc.nasa.gov)|129.164.179.26|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4746240 (4.5M) [application/fits]
# Saving to: ‘L181126210218F4F0ED2738_PH06.fits’
#
# L181126210218F4F0ED 100%[===================>]   4.53M  2.37MB/s    in 1.9s
#
# 2025-12-16 17:14:24 (2.37 MB/s) - ‘L181126210218F4F0ED2738_PH06.fits’ saved [4746240/4746240]
#
# --2025-12-16 17:14:24--  https://fermi.gsfc.nasa.gov/ssc/data/analysis/scitools/data/BinnedLikelihood/L181126210218F4F0ED2738_SC00.fits
# Resolving fermi.gsfc.nasa.gov (fermi.gsfc.nasa.gov)... 129.164.179.26
# Connecting to fermi.gsfc.nasa.gov (fermi.gsfc.nasa.gov)|129.164.179.26|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 268153920 (256M) [application/fits]
# Saving to: ‘L181126210218F4F0ED2738_SC00.fits’
#
# L181126210218F4F0ED 100%[===================>] 255.73M  5.88MB/s    in 40s
#
# 2025-12-16 17:15:04 (6.47 MB/s) - ‘L181126210218F4F0ED2738_SC00.fits’ saved [268153920/268153920]

# %%
# !mkdir ./data
# !mv *.fits ./data
# !ls ./data
# Out:
# mkdir: ./data: File exists
# zsh:1: no matches found: *.fits
# 3C279_binned_allsky_expcube.fits  binned_events.txt
# 3C279_binned_ccube.fits           counts_spectra.fits
# 3C279_binned_cmap_small.fits      gll_psc_v32.xml
# 3C279_binned_cmap.fits            L181126210218F4F0ED2738_PH00.fits
# 3C279_binned_expcube.fits         L181126210218F4F0ED2738_PH01.fits
# 3C279_binned_expcubewithcmap.fits L181126210218F4F0ED2738_PH02.fits
# 3C279_binned_exptest.fits         L181126210218F4F0ED2738_PH03.fits
# 3C279_binned_filtered.fits        L181126210218F4F0ED2738_PH04.fits
# 3C279_binned_gti.fits             L181126210218F4F0ED2738_PH05.fits
# 3C279_binned_ltcube.fits          L181126210218F4F0ED2738_PH06.fits
# 3C279_binned_output.xml           L181126210218F4F0ED2738_SC00.fits
# 3C279_binned_srcmaps.fits         ROI_3C279_input_model.reg
# 3C279_input_model.xml             test.fits
# 3C279_model_map.fits

# %% [markdown]
# In order to combine the two events files for your analysis, you must first generate a text file listing the events files to be included.
#
# If you do not wish to download all the individual files, you can skip to the next step and retrieve the combined, filtered event file. However, you will need the spacecraft file to complete the analysis, so you should retrieve that now.
#
# To generate the file list, type:

# %%
# !ls ./data/*_PH* > ./data/binned_events.txt

# %% [markdown]
# When analyzing point sources, it is recommended that you include events with high probability of being photons. To do this, you should use **gtselect** to cut on the event class, keeping only the SOURCE class events (event class 128).
#
# In addition, since we do not wish to cut on any of the three event types (conversion type, PSF, or EDISP), we will use `evtype=3` (which corresponds to standard analysis in Pass 7). Note that `INDEF` is the default for evtype in gtselect.

# %% [markdown]
# ```bash
# gtselect evclass=128 evtype=3
# ```

# %% [markdown]
# Be aware that `evclass` and `evtype` are hidden parameters. So, to use them, you must type them on the command line.
#
# The text file you made (`binned_events.txt`) will be used in place of the input fits filename when running gtselect. The syntax requires that you use an @ before the filename to indicate that this is a text file input rather than a fits file.
#
# We perform a selection to the data we want to analyze. For this example, we consider the source class photons within our 15 degree region of interest (ROI) centered on the blazar 3C 279. For some of the selections that we made with the data server and don't want to modify, we can use "INDEF" to instruct the tool to read those values from the data file header. Here, we are only filtering on event class (not on event type) and applying a zenith cut, so many of the parameters are designated as "INDEF".

# %% [markdown]
# We apply the **gtselect** tool to the data file as follows:

# %%
# %%bash
# gtselect evclass=128 evtype=3
#     @./data/binned_events.txt
#     ./data/3C279_binned_filtered.fits
#     INDEF
#     INDEF
#     INDEF
#     INDEF
#     INDEF
#     100
#     500000
#     90
# Out:
# Input FT1 file[./data/binned_events.txt] Output FT1 file[./data/3C279_binned_filtered.fits] RA for new search center (degrees) (0:360) [INDEF] Dec for new search center (degrees) (-90:90) [INDEF] radius of new search region (degrees) (0:180) [INDEF] start time (MET in s) (0:) [INDEF] end time (MET in s) (0:) [INDEF] lower energy limit (MeV) (0:) [100] upper energy limit (MeV) (0:) [500000] maximum zenith angle value (degrees) (0:180) [90] Done.

# %% [markdown]
# In the last step we also selected the energy range and the maximum zenith angle value (90 degrees) as recommended by the LAT instrument team.
#
# The Earth's limb is a strong source of background gamma rays and we can filter them out with a zenith-angle cut. The use of "zmax" in calculating the exposure allows for a more selective method than just using the ROI cuts in controlling the Earth limb contamination. The filtered data from the above steps are provided [here](https://fermi.gsfc.nasa.gov/ssc/data/analysis/scitools/data/BinnedLikelihood/3C279_binned_filtered.fits).

# %% [markdown]
# After the data selection is made, we need to select the good time intervals in which the satellite was working in standard data taking mode and the data quality was good. For this task we use **gtmktime** to select GTIs by filtering on information provided in the spacecraft file. The current **gtmktime** filter expression recommended by the LAT team is:

# %% [markdown]
# ```
# (DATA_QUAL>0)&&(LAT_CONFIG==1)
# ```

# %% [markdown]
# This excludes time periods when some spacecraft event has affected the quality of the data; it ensures the LAT instrument was in normal science data-taking mode.
#
# Here is an example of running **gtmktime** for our analysis of the region surrounding 3C 279.

# %%
# %%bash
# gtmktime
#     @./data/L181126210218F4F0ED2738_SC00.fits
#     (DATA_QUAL>0)&&(LAT_CONFIG==1)
#     no
#     ./data/3C279_binned_filtered.fits
#     ./data/3C279_binned_gti.fits
# Out:
# Spacecraft data file[@./data/L181126210218F4F0ED2738_SC00.fits] Filter expression[(DATA_QUAL>0)&&(LAT_CONFIG==1)] Apply ROI-based zenith angle cut[no] Event data file[./data/3C279_binned_filtered.fits] Output event file name[./data/3C279_binned_gti.fits]

# %% [markdown]
# The data file with all the cuts described above is provided in this [link](https://fermi.gsfc.nasa.gov/ssc/data/analysis/scitools/data/BinnedLikelihood/3C279_binned_gti.fits). A more detailed discussion of data selection can be found in the [Data Preparation](https://github.com/fermi-lat/AnalysisThreads/blob/master/DataSelection/2.DataPreparation/data_preparation.ipynb) analysis thread.
#
# To view the DSS keywords in a given extension of a data file, use the **gtvcut** tool and review the data cuts on the EVENTS extension. This provides a listing of the keywords reflecting each cut applied to the data file and their values, including the entire list of GTIs. (Use the option `suppress_gtis=no` to view the entire list.)

# %% [markdown]
# With **gtvcut** you can see the event class and event type, the location and radius of the data selection, as well as the energy range in MeV, the zenith angle cut, and the fact that the time cuts to be used in the exposure calculation are defined by the GTI table.
#
# Various Fermitools will be unable to run if you have multiple copies of a particular DSS keyword. This can happen if the position used in extracting the data from the data server is different than the position used with **gtselect**. It is wise to review the keywords for duplicates before proceeding. If you do have keyword duplication, it is advisable to regenerate the data file with consistent cuts.

# %% [markdown]
# # 2. Make a counts map from the event data
#
# Next, we create a counts map of the ROI, summed over photon energies, in order to identify candidate sources and to ensure that the field looks sensible as a simple sanity check. For creating the counts map, we will use the [gtbin](https://fermi.gsfc.nasa.gov/ssc/data/analysis/scitools/help/gtbin.txt) tool with the option "CMAP" (no spacecraft file is necessary for this step).
#
# Then we will view the output file, as shown below:

# %%
# %%bash
# gtbin
#     CMAP
#     ./data/3C279_binned_gti.fits
#     ./data/3C279_binned_cmap.fits
#     NONE
#     150
#     150
#     0.2
#     CEL
#     193.98
#     -5.82
#     0.0
#     AIT
# Out:
# This is gtbin version HEAD
# Type of output file (CCUBE|CMAP|LC|PHA1|PHA2|HEALPIX) [CCUBE] Event data file name[./data/3C279_binned_gti.fits] Output file name[./data/3C279_binned_ccube.fits] Spacecraft data file name[NONE] Size of the X axis in pixels[100] Size of the Y axis in pixels[100] Image scale (in degrees/pixel)[0.2] Coordinate system (CEL - celestial, GAL -galactic) (CEL|GAL) [CEL] First coordinate of image center in degrees (RA or galactic l)[193.98] Second coordinate of image center in degrees (DEC or galactic b)[-5.82] Rotation angle of image axis, in degrees[0] Projection method e.g. AIT|ARC|CAR|GLS|MER|NCP|SIN|STG|TAN:[AIT]
# gtbin: WARNING: No spacecraft file: EXPOSURE keyword will be set equal to ontime.

# %% [markdown]
# We chose an ROI of 15 degrees, corresponding to 30 degrees in diameter. Since we want a pixel size of 0.2 degrees/pixel, then we must select 30/0.2=150 pixels for the size of the x and y axes. The last command launches the visualization tool _ds9_ and produces a display of the generated [counts](https://fermi.gsfc.nasa.gov/ssc/data/analysis/scitools/data/BinnedLikelihood/3C279_binned_cmap.fits) map.

# %% [markdown]
# <img src='https://fermi.gsfc.nasa.gov/ssc/data/analysis/scitools/images/BinnedLikelihood/3C279_binned_counts_map.png'>
#
# You can see several strong sources and a number of weaker sources in this map. Mousing over the positions of these sources shows that two of them are likely 3C 279 and 3C 273.
#
# It is important to inspect your data prior to proceeding to verify that the contents are as you expect. A malformed data query or improper data selection can generate a non-circular region, or a file with zero events. By inspecting your data prior to analysis, you have an opportunity to detect such issues early in the analysis.
#
# A more detailed discussion of data exploration can be found in the [Explore LAT Data](https://github.com/fermi-lat/AnalysisThreads/blob/master/DataSelection/3.ExploreLATData/explore_latdata.ipynb) analysis thread.

# %% [markdown]
# # 3. Create a 3-D (binned) counts map
#
# Since the counts map shows the expected data, you are ready to prepare your data set for analysis. For binned likelihood analysis, the data input is a three-dimensional counts map with an energy axis, called a counts cube. The gtbin tool performs this task as well by using the `CCUBE` option.
#
# <img src="https://fermi.gsfc.nasa.gov/ssc/data/analysis/scitools/images/BinnedLikelihood/square_in_circle.png">
#
# The binning of the counts map determines the binning of the exposure calculation. The likelihood analysis may lose accuracy if the energy bins are not sufficiently narrow to accommodate more rapid variations in the effective area with decreasing energy below a few hundred MeV. For a typical analysis, ten logarithmically spaced bins per decade in energy are recommended. The analysis is less sensitive to the spatial binning and 0.2 deg bins are a reasonable standard.
#
# This counts cube is a square binned region that must fit within the circular acceptance cone defined during the data extraction step, and visible in the counts map above. To find the maximum size of the region your data will support, find the side of a square that can be fully inscribed within your circular acceptance region (multiply the radius of the acceptance cone by sqrt(2)). For this example, the maximum length for a side is 21.21 degrees.

# %% [markdown]
# To create the counts cube, we run [gtbin](https://fermi.gsfc.nasa.gov/ssc/data/analysis/scitools/help/gtbin.txt) as follows:

# %%
# %%bash
# gtbin
#     CCUBE
#     ./data/3C279_binned_gti.fits
#     ./data/3C279_binned_ccube.fits
#     NONE
#     100
#     100
#     0.2
#     CEL
#     193.98
#     -5.82
#     0.0
#     AIT
#     LOG
#     100
#     500000
#     37
# Out:
# This is gtbin version HEAD
# Type of output file (CCUBE|CMAP|LC|PHA1|PHA2|HEALPIX) [CMAP] Event data file name[./data/3C279_binned_gti.fits] Output file name[./data/3C279_binned_cmap.fits] Spacecraft data file name[NONE] Size of the X axis in pixels[150] Size of the Y axis in pixels[150] Image scale (in degrees/pixel)[0.2] Coordinate system (CEL - celestial, GAL -galactic) (CEL|GAL) [CEL] First coordinate of image center in degrees (RA or galactic l)[193.98] Second coordinate of image center in degrees (DEC or galactic b)[-5.82] Rotation angle of image axis, in degrees[0] Projection method e.g. AIT|ARC|CAR|GLS|MER|NCP|SIN|STG|TAN:[AIT] Algorithm for defining energy bins (FILE|LIN|LOG) [LOG] Start value for first energy bin in MeV[100] Stop value for last energy bin in MeV[500000] Number of logarithmically uniform energy bins[37]
# gtbin: WARNING: No spacecraft file: EXPOSURE keyword will be set equal to ontime.

# %% [markdown]
# [gtbin](https://fermi.gsfc.nasa.gov/ssc/data/analysis/scitools/help/gtbin.txt) takes the following as parameters:
# * Type of output file (CCUBE|CMAP|LC|PHA1|PHA2|HEALPIX)
# * Event data file name
# * Output file name
# * Spacecraft data file name
# * Size of the X axis in pixels
# * Size of the Y axis in pixels
# * Image scale (in degrees/pixel)
# * Coordindate system (CEL - celestial; GAL - galactic) (pick CEL or GAL)
# * First coordinate of image center in degrees (RA or galactic l)
# * Second coordinate of image center in degrees (DEC or galactic b)
# * Rotation angle of image axis, in degrees
# * Projection method (AIT|ARC|CAR|GLS|MER|NCP|SIN|STG|TAN)
# * Algorithm for defining energy bins (FILE|LIN|LOG)
# * Start value for first energy bin in MeV
# * Stop value for last energy bin in MeV
# * Number of logarithmically uniform energy bins

# %% [markdown]
# The counts cube generated in this step is provided [here](https://fermi.gsfc.nasa.gov/ssc/data/analysis/scitools/data/BinnedLikelihood/3C279_binned_ccube.fits).
#
# If you open the file with _ds9_, you see that it is made up of 37 images, one for each logarithmic energy bin. By playing through these images, it is easy to see how the PSF of the LAT changes with energy. You can also see that changing energy cuts could be helpful when trying to optimize the localization or spectral information for specific sources.
#
# Be sure to verify that there are no black corners on your counts cube. These corners correspond to regions with no data and will cause errors in your exposure calculations.

# %% [markdown]
# # 4. Download the latest diffuse model files
#
# When you use the current Galactic diffuse emission model ([`gll_iem_v07.fits`](https://fermi.gsfc.nasa.gov/ssc/data/analysis/software/aux/4fgl/gll_iem_v07.fits)) in a likelihood analysis, you also want to use the corresponding model for the extragalactic isotropic diffuse emission, which includes the residual cosmic-ray background. The recommended isotropic model for point source analysis is [`iso_P8R3_SOURCE_V3_v1.txt`](https://fermi.gsfc.nasa.gov/ssc/data/analysis/software/aux/iso_P8R3_SOURCE_V3_v1.txt).
#
# All the Pass 8 background models have been included in the Fermitools distribution, in the `$(FERMI_DIR)/refdata/fermi/galdiffuse/` directory. If you use that path in your model, you should not have to download the diffuse models individually.
#
# >**NOTE**: Keep in mind that the isotropic model needs to agree with both the event class and event type selections you are using in your analysis. The iso_P8R3_SOURCE_V3_v1.txt isotropic spectrum is valid only for the latest response functions and only for data sets with front + back events combined. All of the most up-to-date background models along with a description of the models are available [here](https://fermi.gsfc.nasa.gov/ssc/data/access/lat/BackgroundModels.html).

# %% [markdown]
# # 5. Create a source model XML file
#
# The [gtlike](https://fermi.gsfc.nasa.gov/ssc/data/analysis/scitools/help/gtlike.txt) tool reads the source model from an XML file. The model file contains your best guess at the locations and spectral forms for the sources in your data. A source model can be created using the [model editor](https://fermi.gsfc.nasa.gov/ssc/data/analysis/scitools/help/modeleditor.txt) tool, by using the user contributed package [LATSourceModel](https://github.com/physicsranger/make4FGLxml) (also available at the [user-contributed tools](https://fermi.gsfc.nasa.gov/ssc/data/analysis/user/) page), or by editing the file directly within a text editor. See Section 4 of the the [Unbinned Likelihood](https://github.com/fermi-lat/AnalysisThreads/blob/master/SourceAnalysis/2.UnbinnedLikelihood/likelihood_tutorial.ipynb) tutorial for a brief tutorial on installing this package.
#
# Here we cannot use the same source model that was used to analyze six months of data in the [Unbinned Likelihood](https://github.com/fermi-lat/AnalysisThreads/blob/master/SourceAnalysis/2.UnbinnedLikelihood/likelihood_tutorial.ipynb) tutorial, as the 2-year data set contains many more significant sources and will not converge. Instead, we will use the 4FGL-DR4 catalog to define our source model by running  the LATSourceModel package. To run the tool, you will need to download the current [LAT catalog file](https://fermi.gsfc.nasa.gov/ssc/data/access/lat/14yr_catalog/gll_psc_v32.xml) and place it in your working directory. Then, use the make4FGLxml tool to create an XML model file:

# %%
# !pip install LATSourceModel
# Out:
# Collecting LATSourceModel
#   Using cached LATSourceModel-1.10.11-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: numpy in /Users/nmirabal/miniconda3/envs/fermi-2.4.69/lib/python3.11/site-packages (from LATSourceModel) (1.26.4)
# Requirement already satisfied: pandas in /Users/nmirabal/miniconda3/envs/fermi-2.4.69/lib/python3.11/site-packages (from LATSourceModel) (2.3.3)
# Requirement already satisfied: astropy in /Users/nmirabal/miniconda3/envs/fermi-2.4.69/lib/python3.11/site-packages (from LATSourceModel) (7.2.0)
# Requirement already satisfied: pyerfa>=2.0.1.1 in /Users/nmirabal/miniconda3/envs/fermi-2.4.69/lib/python3.11/site-packages (from astropy->LATSourceModel) (2.0.1.5)
# Requirement already satisfied: astropy-iers-data>=0.2025.10.27.0.39.10 in /Users/nmirabal/miniconda3/envs/fermi-2.4.69/lib/python3.11/site-packages (from astropy->LATSourceModel) (0.2025.12.15.0.40.51)
# Requirement already satisfied: PyYAML>=6.0.0 in /Users/nmirabal/miniconda3/envs/fermi-2.4.69/lib/python3.11/site-packages (from astropy->LATSourceModel) (6.0.3)
# Requirement already satisfied: packaging>=22.0.0 in /Users/nmirabal/miniconda3/envs/fermi-2.4.69/lib/python3.11/site-packages (from astropy->LATSourceModel) (25.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/nmirabal/miniconda3/envs/fermi-2.4.69/lib/python3.11/site-packages (from pandas->LATSourceModel) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/nmirabal/miniconda3/envs/fermi-2.4.69/lib/python3.11/site-packages (from pandas->LATSourceModel) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/nmirabal/miniconda3/envs/fermi-2.4.69/lib/python3.11/site-packages (from pandas->LATSourceModel) (2025.3)
# Requirement already satisfied: six>=1.5 in /Users/nmirabal/miniconda3/envs/fermi-2.4.69/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas->LATSourceModel) (1.17.0)
# Using cached LATSourceModel-1.10.11-py3-none-any.whl (42 kB)
# Installing collected packages: LATSourceModel
# Successfully installed LATSourceModel-1.10.11

# %%
# !make4FGLxml ./data/gll_psc_v32.xml --event_file ./data/3C279_binned_gti.fits --output_name ./data/3C279_input_model.xml --free_radius 5.0 --norms_free_only True --sigma_to_free 25 --variable_free True
# Out:
# /Users/nmirabal/miniconda3/envs/fermi-2.4.69/lib/python3.11/site-packages/LATSourceModel/SourceList.py:154: UserWarning: Region XML model data/3C279_input_model.xml already exists, will be overwritten if you call the make_model method.
#   warnings.warn(f'Region XML model {str(self.output_name)} already exists, will be\
# Creating spatial and spectral model from the 4FGL DR-3 catalog: data/gll_psc_v32.xml.
# Added 284 point sources and 0 extended sources.
# Building ds9-style region file...done!
# File saved as data/ROI_3C279_input_model.reg.

# %% [markdown]
# Note that we are using a high level of significance so that we only fit the brightest sources, and we have forced the extended sources to be modeled as point sources.
#
# It is also necessary to specify the entire path to location of the diffuse model on your system. Clearly, the simple 4-source model we used for the 6-month [Unbinned Likelihood](https://github.com/fermi-lat/AnalysisThreads/blob/master/SourceAnalysis/2.UnbinnedLikelihood/likelihood_tutorial.ipynb) analysis would have been too simplistic.

# %% [markdown]
# This XML file uses the spectral model from the 4FGL catalog analysis for each source. (The catalog file is available at the [LAT 14-yr Catalog page](https://fermi.gsfc.nasa.gov/ssc/data/access/lat/14yr_catalog/).) However, that analysis used a subset of the available spectral models. A dedicated analysis of the region may indicate a different spectral model is preferred.
#
# For more details on the options available for your XML models, see:
# * Descriptions of available [Spectral and Spatial Models](https://fermi.gsfc.nasa.gov/ssc/data/analysis/scitools/source_models.html)
# * Examples of [XML Model Definitions for Likelihood](https://fermi.gsfc.nasa.gov/ssc/data/analysis/scitools/xml_model_defs.html)

# %% [markdown]
# Finally, the make4FGLxml tool automatically adds 10 degrees to your ROI to account for sources that lie outside your data region, but which may contribute photons to your data. In addition, it gives you the ability to free only some of the spectral parameters for sources within your ROI, and fixes them for the others. With hundreds of sources, there are too many free parameters to gain a good spectral fit. It is advisable to revise these values so that only sources near your source of interest, or very bright source, have all spectral parameters free. Farther away, you can fix the spectral form and free only the normalization parameter (or "prefactor"). If you are working in a crowded region, or have nested sources (e.g. a point source on top of an extended source), you will probably want to fix parameters for some sources even if they lie close to your source of interest.
#
# Only the normalization parameter will be left free (--norms_free_only True) for the remaining sources within the ROI. We have also used the significance parameter (--sigma_to_free 25) of make4FLGxml to free only the brightest sources in our ROI. In addition, we used the variability parameter (--variable_free True) to override that for sources that are significantly variable. We also use a limit of five degrees from the center of the search region (--free_radius 5.0) to reduce the number of sources with free parameters. These changes are necessary: having too many free parameters will not allow the fit to converge (see the section for the fitting step).
#
# The XML file used in this example can be found [here](https://fermi.gsfc.nasa.gov/ssc/data/analysis/scitools/data/BinnedLikelihood/3C279_input_model.xml). This file was made with an earlier version of the LAT catalog, so it will contain fewer sources and some of those sources will have different spectral shapes/parameter values. These changes may cause the likelihood analysis step to fail to reach convergence. For a discusssion of this issue and how to mitigate it, see the "Run the Likelihood Analysis" sectionof the [Likelihood Analysis with Python](https://github.com/fermi-lat/AnalysisThreads/blob/master/SourceAnalysis/3.PythonLikelihood/python_tutorial.ipynb) thread.

# %% [markdown]
# ### XML for Extended Sources
#
# In some regions, the make4FGLxml script may add one or more extended sources to your XML model.
#
# The script will provide the number of extended sources included in the model. In order to use these extended sources, you will need to downloaded the extended source templates from the [LAT Catalog](https://fermi.gsfc.nasa.gov/ssc/data/access/lat/14yr_catalog/) page (look for "Extended Source template archive").
#
# Extract the archive in the directory of your choice and note the path to the template files, which have names like `W44.fits` and `VelaX.fits`. You will need to provide the path to the template file to the script before you run it.
#
# Here is an example of the proper format for an extended source XML entry for Binned Likelihood analysis:
#
# ```xml
# <source name="SpatialMap_source" type="DiffuseSource">
# <spectrum type="PowerLaw2">
# <parameter free="1" max="1000.0" min="1e-05" name="Integral" scale="1e-06" value="1.0"/>
# <parameter free="1" max="-1.0" min="-5.0" name="Index" scale="1.0" value="-2.0"/>
# <parameter free="0" max="200000.0" min="20.0" name="LowerLimit" scale="1.0" value="20.0"/>
# <parameter free="0" max="200000.0" min="20.0" name="UpperLimit" scale="1.0" value="2e5"/>
# </spectrum>
# <spatialModel W44 file="$(PATH_TO_FILE)/W44.fits" type="SpatialMap" map_based_integral="true">
# <parameter free="0" max="1000.0" min="0.001" name="Normalization" scale= "1.0" value="1.0"/>
# </spatialModel>
# </source>
# ```

# %% [markdown]
# # 6. Compute livetimes and exposure
#
# To speed up the exposure calculations performed by Likelihood, it is helpful to pre-compute the livetime as a function of sky position and off-axis angle. The [gtltcube](https://raw.githubusercontent.com/fermi-lat/fermitools-fhelp/master/fhelp_files/gtltcube.txt) tool creates a livetime cube, which is a [HealPix](http://healpix.jpl.nasa.gov/) table, covering the entire sky, of the integrated livetime as a function of inclination with respect to the LAT z-axis.
#
# Here is an example of how to run [gtltcube](https://raw.githubusercontent.com/fermi-lat/fermitools-fhelp/master/fhelp_files/gtltcube.txt):

# %%
# %%bash
# gtltcube zmax=90
#     ./data/3C279_binned_gti.fits
#     ./data/L181126210218F4F0ED2738_SC00.fits
#     ./data/3C279_binned_ltcube.fits
#     0.025
#     1
# Out:
# Event data file[./data/3C279_binned_gti.fits] Spacecraft data file[./data/L181126210218F4F0ED2738_SC00.fits] Output file[./data/3C279_binned_ltcube.fits] Step size in cos(theta) (0.:1.) [0.025] Pixel size (degrees)[1]
# Working on file ./data/L181126210218F4F0ED2738_SC00.fits
# .....................!

# %% [markdown]
# >**Note**: Values such as "0.1" for "Step size in cos(theta) are known to give unexpected results. Use "0.09" instead.

# %% [markdown]
# The livetime cube generated from this analysis can be found [here](https://fermi.gsfc.nasa.gov/ssc/data/analysis/scitools/data/BinnedLikelihood/3C279_binned_ltcube.fits).
#
# For more information about the livetime cubes see the [likelihood documentation](https://fermi.gsfc.nasa.gov/ssc/data/analysis/likelihood/index.html) and also the explanation in the [Unbinned Likelihood](https://github.com/fermi-lat/AnalysisThreads/blob/master/SourceAnalysis/2.UnbinnedLikelihood/likelihood_tutorial.ipynb) tutorial.

# %% [markdown]
# # 7. Compute exposure map
#
# Next, you must apply the livetime calculated in the previous step to your region of interest. To do this, we use the [gtexpcube2](https://fermi.gsfc.nasa.gov/ssc/data/analysis/scitools/help/gtexpcube2.txt) tool, which is an updated version of the previous **gtexpcube**. This tool generates a binned exposure map, an accounting of the exposure at each position in the sky, that are a required input to the likelihood process.
#
# >**NOTE**: In the past, running **gtsrcmaps** calculated the exposure map for you, so most analyses skipped the binned exposure map generation step. With the introduction of **gtexpcube2**, this is no longer the case. You must explicitly command the creation of the exposure map as a separate analysis step.

# %% [markdown]
# In order to create an exposure map that accounts for contributions from all the sources in your analysis region, you must consider not just the sources included in the counts cube. The large PSF of the LAT means that at low energies, sources from well outside your counts cube could affect the sources you are analyzing. To compensate for this, you must create an exposure map that includes sources up to 10 degrees outside your ROI. (The ROI is determined by the radius you downloaded from the data server, here a 15 degree radius.) In addition, you should account for all the exposure that contributes to those additional sources. Since the exposure map uses square pixels, to match the binning in the counts cube, and to ensure we don't have errors, we generate a 300x300 pixel map.

# %% [markdown]
# If you provide [gtexpcube2](https://fermi.gsfc.nasa.gov/ssc/data/analysis/scitools/help/gtexpcube2.txt) a filename for your counts cube, it will use the information from that file to define the geometry of the exposure map. This is legacy behavior and will not give you the necessary 20° buffer you need to completely account for the exposure of nearby sources. (It will also cause an error in the next step.)
#
# Instead, you should specify the appropriate geometry for the exposure map, remembering that the counts cube used 0.2 degree pixel binning. To do that, enter `none` when asked for a Counts cube.
#
# **Note**: If you get a "`File not found`" error in the examples below, just put the IRF name in explicitly. The appropriate IRF for this data set is `P8R3_SOURCE_V3`.
#
# **Note**: Users must also specify evtype.
#
# First we show an example with counts map (cmap) set to none. In this case evtype=3 (Front and Back events)

# %%
# %system punlearn gtexpcube2
# Out:
# []

# %%
# %%bash
# gtexpcube2 chatter=4
#     ./data/3C279_binned_ltcube.fits
#     none
#     ./data/3C279_binned_expcube.fits
#     P8R3_SOURCE_V3
#     3
#     300
#     300
#     .2
#     193.98
#     -5.82
#     0
#     AIT
#     CEL
#     100
#     500000
#     37
# Out:
# This is gtexpcube2 version HEAD
# Livetime cube file[] Counts map file[] Output file name[] Response functions to use[CALDB] Event type selections - Must Specify[] Size of the X axis in pixels[INDEF] Size of the Y axis in pixels[INDEF] Image scale (in degrees/pixel)[INDEF] First coordinate of image center in degrees (RA or galactic l)[INDEF] Second coordinate of image center in degrees (DEC or galactic b)[INDEF] Rotation angle of image axis, in degrees[0.] Projection method e.g. AIT|ARC|CAR|GLS|MER|NCP|SIN|STG|TAN[CAR] Coordinate system (CEL - celestial, GAL -galactic) (CEL|GAL) [GAL] Start energy (MeV) of first bin[INDEF] Stop energy (MeV) of last bin[INDEF] Number of logarithmically-spaced energy bins[INDEF] Using evtype=3 (i.e., FRONT/BACK irfs)
# ResponseFunctions::load: IRF used: P8R3_SOURCE_V3
#   event_types:  0  1
# Computing binned exposure map....................!

# %%
# %system punlearn gtexpcube2
# Out:
# []

# %% [markdown]
# The gtexpcube2 tool can also be executed with a counts map. The following shows an example using evtype=3

# %%
# %%bash
# gtexpcube2 chatter=4
#     ./data/3C279_binned_ltcube.fits
#     ./data/3C279_binned_ccube.fits
#     ./data/3C279_binned_expcubewithcmap.fits
#     P8R3_SOURCE_V3
#     3
# Out:
# This is gtexpcube2 version HEAD
# Livetime cube file[] Counts map file[] Output file name[] Response functions to use[CALDB] Event type selections - Must Specify[] Using evtype=3 (i.e., FRONT/BACK irfs)
# ResponseFunctions::load: IRF used: P8R3_SOURCE_V3
#   event_types:  0  1
# Computing binned exposure map....................!

# %% [markdown]
# The generated exposure map can be found [here](https://fermi.gsfc.nasa.gov/ssc/data/analysis/scitools/data/BinnedLikelihood/3C279_binned_expcube.fits).
#
# At this point, you may decide it is easier to simply generate exposure maps for the entire sky. You may be right, as it certainly simplifies the step when scripting. However, making an all-sky map increases the processing time for this step, though the increase is modest.
#
# To generate an all-sky exposure map (rather than the exposure map we calculated above) you need to specify the proper binning and explicitly give the number of pixels for the entire sky (360°x180°) and evtype. In this case we use evytpe=3
#
# Here is an example:

# %%
# %%bash
# gtexpcube2
#     ./data/3C279_binned_ltcube.fits
#     none
#     ./data/3C279_binned_allsky_expcube.fits
#     P8R3_SOURCE_V3
#     3
#     1800
#     900
#     .2
#     193.98
#     -5.82
#     0
#     AIT
#     CEL
#     100
#     500000
#     37
# Out:
# Livetime cube file[./data/3C279_binned_ltcube.fits] Counts map file[none] Output file name[./data/3C279_binned_allsky_expcube.fits] Response functions to use[P8R3_SOURCE_V3] Event type selections - Must Specify[1800] Size of the X axis in pixels[900] Size of the Y axis in pixels[0] Image scale (in degrees/pixel)[100] First coordinate of image center in degrees (RA or galactic l)[500000] Second coordinate of image center in degrees (DEC or galactic b)[37] Rotation angle of image axis, in degrees[0] Projection method e.g. AIT|ARC|CAR|GLS|MER|NCP|SIN|STG|TAN[CAR] Coordinate system (CEL - celestial, GAL -galactic) (CEL|GAL) [GAL] Start energy (MeV) of first bin[INDEF] Stop energy (MeV) of last bin[INDEF] Number of logarithmically-spaced energy bins[INDEF]
# Computing binned exposure map....................!
# Using evtype=3 (i.e., FRONT/BACK irfs)

# %% [markdown]
# The all-sky exposure map can be found [here](https://fermi.gsfc.nasa.gov/ssc/data/analysis/scitools/data/BinnedLikelihood/3C279_binned_allsky_expcube.fits).
#
# Just as in the [Unbinned Likelihood](https://github.com/fermi-lat/AnalysisThreads/blob/master/SourceAnalysis/2.UnbinnedLikelihood/likelihood_tutorial.ipynb) analysis, the exposure needs to be recalculated if the ROI, zenith angle, time, event class, or energy selections applied to the data are changed. For the binned analysis, this also includes the spatial and energy binning of the 3D counts map (which affects the exposure map as well).

# %% [markdown]
# # 8. Compute source map
#
# The [gtsrcmaps](https://fermi.gsfc.nasa.gov/ssc/data/analysis/scitools/help/gtsrcmaps.txt) tool creates model counts maps for use with the binned likelihood analysis. To do this, it takes each source spectrum in the XML model, multiplies it by the exposure at the source position, and convolves that exposure with the effective PSF.
#
# This is an example of how to run the tool:

# %%
# %%bash
# gtsrcmaps
#     ./data/3C279_binned_ltcube.fits
#     ./data/3C279_binned_ccube.fits
#     ./data/3C279_input_model.xml
#     ./data/3C279_binned_allsky_expcube.fits
#     ./data/3C279_binned_srcmaps.fits
#     CALDB
# Out:
# Exposure hypercube file[./data/3C279_binned_ltcube.fits] Counts map file[./data/3C279_binned_ccube.fits] Source model file[./data/3C279_input_model.xml] Binned exposure map[./data/3C279_binned_allsky_expcube.fits] Source maps output file[./data/3C279_binned_srcmaps.fits] Response functions[CALDB]
# Generating SourceMap for 4FGL J1118.2-0415 38....................!
# Generating SourceMap for 4FGL J1118.6-1235 38....................!
# Generating SourceMap for 4FGL J1119.9-1007 38....................!
# Generating SourceMap for 4FGL J1121.3-0011 38....................!
# Generating SourceMap for 4FGL J1121.4-0553 38....................!
# Generating SourceMap for 4FGL J1122.0-0231 38....................!
# Generating SourceMap for 4FGL J1122.5-1440 38....................!
# Generating SourceMap for 4FGL J1124.1-1203 38....................!
# Generating SourceMap for 4FGL J1124.5-0658 38....................!
# Generating SourceMap for 4FGL J1124.6-0809 38....................!
# Generating SourceMap for 4FGL J1125.9-0742 38....................!
# Generating SourceMap for 4FGL J1128.3-1301 38....................!
# Generating SourceMap for 4FGL J1129.2-0529 38....................!
# Generating SourceMap for 4FGL J1129.2-1014 38....................!
# Generating SourceMap for 4FGL J1129.8-1447 38....................!
# Generating SourceMap for 4FGL J1131.1-0944 38....................!
# Generating SourceMap for 4FGL J1131.4-0504 38....................!
# Generating SourceMap for 4FGL J1132.1-1448 38....................!
# Generating SourceMap for 4FGL J1132.7+0034 38....................!
# Generating SourceMap for 4FGL J1133.8-2048 38....................!
# Generating SourceMap for 4FGL J1134.8-1729 38....................!
# Generating SourceMap for 4FGL J1135.7-0427 38....................!
# Generating SourceMap for 4FGL J1136.3-0501 38....................!
# Generating SourceMap for 4FGL J1137.3+0535 38....................!
# Generating SourceMap for 4FGL J1137.9-1708 38....................!
# Generating SourceMap for 4FGL J1140.4+0022 38....................!
# Generating SourceMap for 4FGL J1140.7-0129 38....................!
# Generating SourceMap for 4FGL J1141.5-1408 38....................!
# Generating SourceMap for 4FGL J1142.8+0120 38....................!
# Generating SourceMap for 4FGL J1143.7-1014 38....................!
# Generating SourceMap for 4FGL J1145.5-0340 38....................!
# Generating SourceMap for 4FGL J1145.7+0453 38....................!
# Generating SourceMap for 4FGL J1145.7-1528 38....................!
# Generating SourceMap for 4FGL J1146.0-0638 38....................!
# Generating SourceMap for 4FGL J1146.4-0926 38....................!
# Generating SourceMap for 4FGL J1147.8-0724 38....................!
# Generating SourceMap for 4FGL J1148.2-0029 38....................!
# Generating SourceMap for 4FGL J1150.0+1033 38....................!
# Generating SourceMap for 4FGL J1150.8-1905 38....................!
# Generating SourceMap for 4FGL J1151.3+0957 38....................!
# Generating SourceMap for 4FGL J1151.5-1347 38....................!
# Generating SourceMap for 4FGL J1151.6-2115 38....................!
# Generating SourceMap for 4FGL J1152.3-0839 38....................!
# Generating SourceMap for 4FGL J1153.2+0123 38....................!
# Generating SourceMap for 4FGL J1153.3-1104 38....................!
# Generating SourceMap for 4FGL J1153.6-2553 38....................!
# Generating SourceMap for 4FGL J1154.0-0010 38....................!
# Generating SourceMap for 4FGL J1155.2-1111 38....................!
# Generating SourceMap for 4FGL J1155.8-1217 38....................!
# Generating SourceMap for 4FGL J1156.6+0640 38....................!
# Generating SourceMap for 4FGL J1156.6-2248 38....................!
# Generating SourceMap for 4FGL J1156.8-1537 38....................!
# Generating SourceMap for 4FGL J1158.8-1430 38....................!
# Generating SourceMap for 4FGL J1158.9+0818 38....................!
# Generating SourceMap for 4FGL J1158.9+0956 38....................!
# Generating SourceMap for 4FGL J1159.0+0939 38....................!
# Generating SourceMap for 4FGL J1159.2-2227 38....................!
# Generating SourceMap for 4FGL J1159.3-2142 38....................!
# Generating SourceMap for 4FGL J1159.5-0723 38....................!
# Generating SourceMap for 4FGL J1200.2+0201 38....................!
# Generating SourceMap for 4FGL J1200.6+1229 38....................!
# Generating SourceMap for 4FGL J1200.8-1429 38....................!
# Generating SourceMap for 4FGL J1201.1-0332 38....................!
# Generating SourceMap for 4FGL J1201.7+1429 38....................!
# Generating SourceMap for 4FGL J1202.5-0528 38....................!
# Generating SourceMap for 4FGL J1203.3+1119 38....................!
# Generating SourceMap for 4FGL J1203.5-1748 38....................!
# Generating SourceMap for 4FGL J1204.0+1146 38....................!
# Generating SourceMap for 4FGL J1204.2-0709 38....................!
# Generating SourceMap for 4FGL J1204.8+0407 38....................!
# Generating SourceMap for 4FGL J1205.7-2635 38....................!
# Generating SourceMap for 4FGL J1207.2-0524 38....................!
# Generating SourceMap for 4FGL J1207.4-1840 38....................!
# Generating SourceMap for 4FGL J1207.7-0106 38....................!
# Generating SourceMap for 4FGL J1207.7-2229 38....................!
# Generating SourceMap for 4FGL J1208.2+1158 38....................!
# Generating SourceMap for 4FGL J1208.8-1751 38....................!
# Generating SourceMap for 4FGL J1208.8-2754 38....................!
# Generating SourceMap for 4FGL J1211.6-2735 38....................!
# Generating SourceMap for 4FGL J1212.0-2326 38....................!
# Generating SourceMap for 4FGL J1212.7-1402 38....................!
# Generating SourceMap for 4FGL J1213.1-1123 38....................!
# Generating SourceMap for 4FGL J1213.3-2618 38....................!
# Generating SourceMap for 4FGL J1213.6+1236 38....................!
# Generating SourceMap for 4FGL J1213.6+1306 38....................!
# Generating SourceMap for 4FGL J1214.5-2318 38....................!
# Generating SourceMap for 4FGL J1214.6-1926 38....................!
# Generating SourceMap for 4FGL J1215.0+1656 38....................!
# Generating SourceMap for 4FGL J1215.1+0731 38....................!
# Generating SourceMap for 4FGL J1215.8-1733 38....................!
# Generating SourceMap for 4FGL J1216.1+0930 38....................!
# Generating SourceMap for 4FGL J1216.1-0242 38....................!
# Generating SourceMap for 4FGL J1216.2+0537 38....................!
# Generating SourceMap for 4FGL J1216.2-0600 38....................!
# Generating SourceMap for 4FGL J1216.2-1550 38....................!
# Generating SourceMap for 4FGL J1216.3-1032 38....................!
# Generating SourceMap for 4FGL J1216.4-1358 38....................!
# Generating SourceMap for 4FGL J1217.2-2500 38....................!
# Generating SourceMap for 4FGL J1218.0-0028 38....................!
# Generating SourceMap for 4FGL J1218.5-0119 38....................!
# Generating SourceMap for 4FGL J1219.6+0550 38....................!
# Generating SourceMap for 4FGL J1219.7+0444 38....................!
# Generating SourceMap for 4FGL J1219.7-0313 38....................!
# Generating SourceMap for 4FGL J1219.8-2008 38....................!
# Generating SourceMap for 4FGL J1220.1-2458 38....................!
# Generating SourceMap for 4FGL J1220.5-2745 38....................!
# Generating SourceMap for 4FGL J1221.4-0634 38....................!
# Generating SourceMap for 4FGL J1222.5+0414 38....................!
# Generating SourceMap for 4FGL J1223.0+1100 38....................!
# Generating SourceMap for 4FGL J1223.3+1213 38....................!
# Generating SourceMap for 4FGL J1223.5+0818 38....................!
# Generating SourceMap for 4FGL J1223.9-0545 38....................!
# Generating SourceMap for 4FGL J1223.9-2220 38....................!
# Generating SourceMap for 4FGL J1225.0+0330 38....................!
# Generating SourceMap for 4FGL J1225.4-1550 38....................!
# Generating SourceMap for 4FGL J1225.5-2851 38....................!
# Generating SourceMap for 4FGL J1225.8-2941 38....................!
# Generating SourceMap for 4FGL J1226.7+0637 38....................!
# Generating SourceMap for 4FGL J1226.8-1329 38....................!
# Generating SourceMap for 4FGL J1228.7-0318 38....................!
# Generating SourceMap for 4FGL J1229.0+0202 38....................!
# Generating SourceMap for 4FGL J1230.8+1223 38....................!
# Generating SourceMap for 4FGL J1231.1-1412 38....................!
# Generating SourceMap for 4FGL J1231.5+1421 38....................!
# Generating SourceMap for 4FGL J1231.8-0450 38....................!
# Generating SourceMap for 4FGL J1233.0+1333 38....................!
# Generating SourceMap for 4FGL J1233.1+1703 38....................!
# Generating SourceMap for 4FGL J1233.7-0144 38....................!
# Generating SourceMap for 4FGL J1234.7-0434 38....................!
# Generating SourceMap for 4FGL J1235.1-1405 38....................!
# Generating SourceMap for 4FGL J1235.9+1136 38....................!
# Generating SourceMap for 4FGL J1238.3-1959 38....................!
# Generating SourceMap for 4FGL J1238.5-1201 38....................!
# Generating SourceMap for 4FGL J1239.4+0728 38....................!
# Generating SourceMap for 4FGL J1239.5+0443 38....................!
# Generating SourceMap for 4FGL J1240.4-2606 38....................!
# Generating SourceMap for 4FGL J1240.8-2918 38....................!
# Generating SourceMap for 4FGL J1241.8-1456 38....................!
# Generating SourceMap for 4FGL J1241.9+0636 38....................!
# Generating SourceMap for 4FGL J1243.7+1727 38....................!
# Generating SourceMap for 4FGL J1243.9-0218 38....................!
# Generating SourceMap for 4FGL J1244.5+1616 38....................!
# Generating SourceMap for 4FGL J1245.4-0701 38....................!
# Generating SourceMap for 4FGL J1245.8+0232 38....................!
# Generating SourceMap for 4FGL J1246.3+0112 38....................!
# Generating SourceMap for 4FGL J1246.7-2548 38....................!
# Generating SourceMap for 4FGL J1249.2-2809 38....................!
# Generating SourceMap for 4FGL J1249.3-0545 38....................!
# Generating SourceMap for 4FGL J1250.6+0217 38....................!
# Generating SourceMap for 4FGL J1251.2+1039 38....................!
# Generating SourceMap for 4FGL J1251.3-0201 38....................!
# Generating SourceMap for 4FGL J1251.3-1719 38....................!
# Generating SourceMap for 4FGL J1252.7-2520 38....................!
# Generating SourceMap for 4FGL J1253.8+0327 38....................!
# Generating SourceMap for 4FGL J1254.2-2205 38....................!
# Generating SourceMap for 4FGL J1254.9+1138 38....................!
# Generating SourceMap for 4FGL J1256.1-0547 38....................!
# Generating SourceMap for 4FGL J1256.2-1146 38....................!
# Generating SourceMap for 4FGL J1256.8-1333 38....................!
# Generating SourceMap for 4FGL J1258.6-1759 38....................!
# Generating SourceMap for 4FGL J1258.7-0452 38....................!
# Generating SourceMap for 4FGL J1258.8-2219 38....................!
# Generating SourceMap for 4FGL J1259.1-2311 38....................!
# Generating SourceMap for 4FGL J1300.0+1753 38....................!
# Generating SourceMap for 4FGL J1300.4+1416 38....................!
# Generating SourceMap for 4FGL J1301.6+0834 38....................!
# Generating SourceMap for 4FGL J1302.2-0032 38....................!
# Generating SourceMap for 4FGL J1304.2-2412 38....................!
# Generating SourceMap for 4FGL J1304.4+1203 38....................!
# Generating SourceMap for 4FGL J1304.6+0539 38....................!
# Generating SourceMap for 4FGL J1304.6-0348 38....................!
# Generating SourceMap for 4FGL J1304.9-2107 38....................!
# Generating SourceMap for 4FGL J1306.3+1113 38....................!
# Generating SourceMap for 4FGL J1306.7-2148 38....................!
# Generating SourceMap for 4FGL J1307.1-0344 38....................!
# Generating SourceMap for 4FGL J1308.7+0347 38....................!
# Generating SourceMap for 4FGL J1309.7+1153 38....................!
# Generating SourceMap for 4FGL J1310.1-0450 38....................!
# Generating SourceMap for 4FGL J1310.2-1158 38....................!
# Generating SourceMap for 4FGL J1311.0+0034 38....................!
# Generating SourceMap for 4FGL J1312.4-2156 38....................!
# Generating SourceMap for 4FGL J1312.6-1900 38....................!
# Generating SourceMap for 4FGL J1312.7+0050 38....................!
# Generating SourceMap for 4FGL J1312.8-0425 38....................!
# Generating SourceMap for 4FGL J1312.8-2350 38....................!
# Generating SourceMap for 4FGL J1313.6+0159 38....................!
# Generating SourceMap for 4FGL J1314.7-0901 38....................!
# Generating SourceMap for 4FGL J1315.5+1135 38....................!
# Generating SourceMap for 4FGL J1315.9-0732 38....................!
# Generating SourceMap for 4FGL J1317.5-0153 38....................!
# Generating SourceMap for 4FGL J1318.1-1740 38....................!
# Generating SourceMap for 4FGL J1318.3-1148 38....................!
# Generating SourceMap for 4FGL J1318.7-1234 38....................!
# Generating SourceMap for 4FGL J1319.5+1404 38....................!
# Generating SourceMap for 4FGL J1319.5-0045 38....................!
# Generating SourceMap for 4FGL J1321.3-2641 38....................!
# Generating SourceMap for 4FGL J1322.2+0842 38....................!
# Generating SourceMap for 4FGL J1322.3-0606 38....................!
# Generating SourceMap for 4FGL J1322.6-0936 38....................!
# Generating SourceMap for 4FGL J1322.6-1418 38....................!
# Generating SourceMap for 4FGL J1322.6-1617 38....................!
# Generating SourceMap for 4FGL J1322.9+0437 38....................!
# Generating SourceMap for 4FGL J1323.9+1405 38....................!
# Generating SourceMap for 4FGL J1324.5-2338 38....................!
# Generating SourceMap for 4FGL J1324.6-2525 38....................!
# Generating SourceMap for 4FGL J1325.6-0227 38....................!
# Generating SourceMap for 4FGL J1326.1+1232 38....................!
# Generating SourceMap for 4FGL J1326.6+0152 38....................!
# Generating SourceMap for 4FGL J1326.7-0503 38....................!
# Generating SourceMap for 4FGL J1328.6+1145 38....................!
# Generating SourceMap for 4FGL J1329.4-0530 38....................!
# Generating SourceMap for 4FGL J1329.8-1559 38....................!
# Generating SourceMap for 4FGL J1331.2-1325 38....................!
# Generating SourceMap for 4FGL J1331.6+1711 38....................!
# Generating SourceMap for 4FGL J1331.7-0343 38....................!
# Generating SourceMap for 4FGL J1331.7-0647 38....................!
# Generating SourceMap for 4FGL J1332.0-0509 38....................!
# Generating SourceMap for 4FGL J1332.6-1256 38....................!
# Generating SourceMap for 4FGL J1333.4+1540 38....................!
# Generating SourceMap for 4FGL J1336.5-1529 38....................!
# Generating SourceMap for 4FGL J1337.6-1257 38....................!
# Generating SourceMap for 4FGL J1337.9-1956 38....................!
# Generating SourceMap for 4FGL J1338.1-0931 38....................!
# Generating SourceMap for 4FGL J1338.9+1153 38....................!
# Generating SourceMap for 4FGL J1339.0-2400 38....................!
# Generating SourceMap for 4FGL J1339.1-2620 38....................!
# Generating SourceMap for 4FGL J1339.9-0138 38....................!
# Generating SourceMap for 4FGL J1340.0-1501 38....................!
# Generating SourceMap for 4FGL J1340.8-0409 38....................!
# Generating SourceMap for 4FGL J1341.8-2053 38....................!
# Generating SourceMap for 4FGL J1342.0+1043 38....................!
# Generating SourceMap for 4FGL J1342.6+0944 38....................!
# Generating SourceMap for 4FGL J1342.7+0505 38....................!
# Generating SourceMap for 4FGL J1344.2-1723 38....................!
# Generating SourceMap for 4FGL J1345.8+0706 38....................!
# Generating SourceMap for 4FGL J1345.9-2612 38....................!
# Generating SourceMap for 4FGL J1347.9-0618 38....................!
# Generating SourceMap for 4FGL J1348.9+0756 38....................!
# Generating SourceMap for 4FGL J1349.5-1131 38....................!
# Generating SourceMap for 4FGL J1351.0+0029 38....................!
# Generating SourceMap for 4FGL J1351.3+1115 38....................!
# Generating SourceMap for 4FGL J1351.4-1529 38....................!
# Generating SourceMap for 4FGL J1353.3+1434 38....................!
# Generating SourceMap for 4FGL J1354.2+0353 38....................!
# Generating SourceMap for 4FGL J1354.3-0206 38....................!
# Generating SourceMap for 4FGL J1354.7+0623 38....................!
# Generating SourceMap for 4FGL J1354.8-1041 38....................!
# Generating SourceMap for 4FGL J1356.2-1726 38....................!
# Generating SourceMap for 4FGL J1356.2-2454 38....................!
# Generating SourceMap for 4FGL J1356.6+0234 38....................!
# Generating SourceMap for 4FGL J1357.5+0127 38....................!
# Generating SourceMap for 4FGL J1358.0-0050 38....................!
# Generating SourceMap for 4FGL J1358.9-0703 38....................!
# Generating SourceMap for 4FGL J1359.1-1152 38....................!
# Generating SourceMap for 4FGL J1359.4+0202 38....................!
# Generating SourceMap for 4FGL J1400.0-2415 38....................!
# Generating SourceMap for 4FGL J1400.6-1432 38....................!
# Generating SourceMap for 4FGL J1401.2-0915 38....................!
# Generating SourceMap for 4FGL J1402.5-1827 38....................!
# Generating SourceMap for 4FGL J1404.8+0402 38....................!
# Generating SourceMap for 4FGL J1405.0-1544 38....................!
# Generating SourceMap for 4FGL J1405.3-0640 38....................!
# Generating SourceMap for 4FGL J1405.9-1853 38....................!
# Generating SourceMap for 4FGL J1406.4-1654 38....................!
# Generating SourceMap for 4FGL J1406.5-0054 38....................!
# Generating SourceMap for 4FGL J1407.4-0820 38....................!
# Generating SourceMap for 4FGL J1408.9-0751 38....................!
# Generating SourceMap for 4FGL J1410.1+0202 38....................!
# Generating SourceMap for 4FGL J1411.5-0723 38....................!
# Generating SourceMap for 4FGL J1414.5+0826 38....................!
# Generating SourceMap for 4FGL J1415.9-1002 38....................!
# Generating SourceMap for 4FGL J1415.9-1504 38....................!
# Generating SourceMap for 4FGL J1418.4-0233 38....................!
# Generating SourceMap for 4FGL J1419.3+0444 38....................!
# Generating SourceMap for 4FGL J1419.4-0838 38....................!
# Generating SourceMap for 4FGL J1420.3+0612 38....................!
# Generating SourceMap for 4FGL J1420.3-0438 38....................!
# Generating SourceMap for 4FGL J1421.1-1120 38....................!
# Generating SourceMap for 4FGL J1421.4-1655 38....................!
# Generating SourceMap for 4FGL J1424.1-1750 38....................!
# Generating SourceMap for 4FGL J1424.2+0433 38....................!
# Generating SourceMap for 4FGL J1425.4-0119 38....................!
# Generating SourceMap for 4FGL J1428.7-1017 38....................!
# Generating SourceMap for 4FGL J1429.8-0739 38....................!
# Generating SourceMap for gll_iem_v07 38....................!
# Generating SourceMap for iso_P8R3_SOURCE_V3_v1 38....................!

# %% [markdown]
# The output file from [gtsrcmaps](https://fermi.gsfc.nasa.gov/ssc/data/analysis/scitools/help/gtsrcmaps.txt) can be found [here](https://fermi.gsfc.nasa.gov/ssc/data/analysis/scitools/data/BinnedLikelihood/3C279_binned_srcmaps.fits).
#
# Because your model map can include sources outside your ROI, you may see a list of warnings at the beginning of the output. These are expected (because you have properly included sources outside your ROI in your XML file) and should cause no problem in your analysis. In addition, if your exposure map is too small for the region, you will see the following warning:
#
# ```
# Caught St13runtime_error at the top level:
# Request for exposure at a sky position that is outside of the map boundaries.
#
# The contribution of the diffuse source outside of the exposure
# and counts map boundaries is being computed to account for PSF
# leakage into the analysis region. To handle this, use an all-sky
# binned exposure map. Alternatively, to neglect contributions
# outside of the counts map region, use the emapbnds=no option when
# running gtsrcmaps.
# ```

# %% [markdown]
# In this situation, you should increase the dimensions of your exposure map, or just move to the all-sky version.
#
# Source map generation for the point sources is fairly quick, and maps for many point sources may take up a lot of disk space. If you are analyzing a single long data set, it may be preferable to pre-compute only the source maps for the diffuse components at this stage.
#
# [gtlike](https://fermi.gsfc.nasa.gov/ssc/data/analysis/scitools/help/gtlike.txt) will compute maps for the point sources on the fly if they appear in the XML definition and a corresponding map is not in the source maps FITS file. To skip generating source maps for point sources, specify "`ptsrc=no`" on the command line when running **gtsrcmaps**. However, if you expect to perform multiple fits on the same set of data, precomputing the source maps will probably save you time.

# %% [markdown]
# # 9. Run gtlike
#
# >NOTE: Prior to running **gtlike** for Unbinned Likelihood, it is necessary to calculate the diffuse response for each event (when that response is not precomputed). However, for Binned Likelihood analysis the diffuse response is calculated over the entire bin, so this step is not necessary.
#
# If you want to use the **energy dispersion correction** during your analysis, you must enable this feature using the environment variable `USE_BL_EDISP`. This may be set on the command line using:
#
# ```bash
# export USE_BL_EDISP=true
# ```
# or, depending on your shell,
#
# ```
# setenv USE_BL_EDISP=true
# ```
#
# To disable the use of energy dispersion, you must unset the variable:
# ```bash
# unset USE_BL_EDISP
# ```
# or
# ```
# unsetenv USE_BL_EDISP
# ```

# %% [markdown]
# ```bash
# export USE_BL_EDISP=true
# ```
# or, depending on your shell,
#
# ```
# setenv USE_BL_EDISP=true
# ```
#
# To disable the use of energy dispersion, you must unset the variable:
# ```bash
# unset USE_BL_EDISP
# ```
# or
# ```
# unsetenv USE_BL_EDISP
# ```

# %% [markdown]
# Now we are ready to run the [gtlike](https://fermi.gsfc.nasa.gov/ssc/data/analysis/scitools/help/gtlike.txt) application.
#
# Here, we request that the fitted parameters be saved to an output XML model file for use in later steps.

# %%
# !wget https://fermi.gsfc.nasa.gov/ssc/data/analysis/scitools/data/BinnedLikelihood/3C279_output_model.xml
# Out:
# --2025-12-17 08:59:12--  https://fermi.gsfc.nasa.gov/ssc/data/analysis/scitools/data/BinnedLikelihood/3C279_output_model.xml
# Resolving fermi.gsfc.nasa.gov (fermi.gsfc.nasa.gov)... 129.164.179.26
# Connecting to fermi.gsfc.nasa.gov (fermi.gsfc.nasa.gov)|129.164.179.26|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1825 (1.8K) [application/xml]
# Saving to: ‘3C279_output_model.xml.6’
#
# 3C279_output_model. 100%[===================>]   1.78K  --.-KB/s    in 0s
#
# 2025-12-17 08:59:13 (1.70 GB/s) - ‘3C279_output_model.xml.6’ saved [1825/1825]

# %%
# %%bash
# gtlike refit=no plot=no sfile=./data/3C279_binned_output.xml
#     BINNED
#     ./data/3C279_binned_srcmaps.fits
#     ./data/3C279_binned_allsky_expcube.fits
#     ./data/3C279_binned_ltcube.fits
#     ./data/3C279_input_model.xml
#     CALDB
#     NEWMINUIT
# Out:
# Statistic to use (BINNED|UNBINNED) [BINNED] Counts map file[./data/3C279_binned_srcmaps.fits] Binned exposure map[./data/3C279_binned_allsky_expcube.fits] Exposure hypercube file[./data/3C279_binned_ltcube.fits] Source model file[./data/3C279_input_model.xml] Response functions to use[CALDB] Optimizer (DRMNFB|NEWMINUIT|MINUIT|DRMNGB|LBFGS) [NEWMINUIT]
# Minuit did successfully converge.
# # of function calls: 226
# minimum function Value: 76574.86159483
# minimum edm: 0.003427174527551
# minimum internal state vector: LAVector parameters:
#      -1.568707780353
#      -1.566951620961
#      -1.572059917192
#      -1.570447134318
#      -1.567000219362
#      -1.566320946454
#      -1.566644967288
#      -1.569031436167
#      -1.569195828999
#      -1.568879964418
#     -0.0919738971074
#     -0.7817829733814
#
# minimum internal covariance matrix: LASymMatrix parameters:
#   5.3177405e-07  1.1547801e-09  2.1176705e-10 -4.5954387e-08 -1.9056625e-10  1.1371218e-09  5.0033415e-09  1.0567805e-08  1.3568398e-09  8.6174905e-10 -2.5780241e-07 -4.2190379e-07
#   1.1547801e-09  3.9491466e-06  3.1355526e-08  1.3568264e-08 -5.4358434e-09  8.8286626e-09   2.262961e-08  6.1787082e-08  5.7805191e-09 -3.5403982e-09  2.7495945e-07  5.8528637e-07
#   2.1176705e-10  3.1355526e-08  1.3932552e-07 -3.8685507e-10  6.8559925e-10 -5.9186687e-10  -1.879433e-09 -4.3195468e-09 -3.1847487e-10 -5.6869927e-13   1.146058e-07 -3.1538467e-08
#  -4.5954387e-08  1.3568264e-08 -3.8685507e-10  5.9655031e-06 -1.0664543e-09   2.323563e-09  8.6698462e-09  2.0137155e-08  3.3974793e-09  5.9747538e-09 -1.1189948e-06 -2.4594061e-06
#  -1.9056625e-10 -5.4358434e-09  6.8559925e-10 -1.0664543e-09  7.7307709e-10 -1.1712044e-09 -1.4248573e-09 -4.3048735e-09 -9.9105136e-11 -1.5924083e-10  3.0701422e-08  3.2787428e-08
#   1.1371218e-09  8.8286626e-09 -5.9186687e-10   2.323563e-09 -1.1712044e-09  2.9068736e-06  -3.985541e-09  1.3506563e-09  2.6171586e-10  4.8120833e-10 -2.9914644e-07 -7.8750267e-08
#   5.0033415e-09   2.262961e-08  -1.879433e-09  8.6698462e-09 -1.4248573e-09  -3.985541e-09  4.9723585e-06  -3.448878e-07 -2.7507002e-08  2.6265171e-09 -6.2555602e-07  -1.140315e-06
#   1.0567805e-08  6.1787082e-08 -4.3195468e-09  2.0137155e-08 -4.3048735e-09  1.3506563e-09  -3.448878e-07  9.0571808e-06 -2.2344506e-07  9.1509596e-10  2.4879084e-07 -1.3617263e-06
#   1.3568398e-09  5.7805191e-09 -3.1847487e-10  3.3974793e-09 -9.9105136e-11  2.6171586e-10 -2.7507002e-08 -2.2344506e-07    1.02159e-07  3.7247921e-10 -7.2835179e-08 -2.1170974e-07
#   8.6174905e-10 -3.5403982e-09 -5.6869927e-13  5.9747538e-09 -1.5924083e-10  4.8120833e-10  2.6265171e-09  9.1509596e-10  3.7247921e-10  2.8488181e-09  -2.647669e-07 -1.0890765e-06
#  -2.5780241e-07  2.7495945e-07   1.146058e-07 -1.1189948e-06  3.0701422e-08 -2.9914644e-07 -6.2555602e-07  2.4879084e-07 -7.2835179e-08  -2.647669e-07  9.8909676e-05  6.7042342e-05
#  -4.2190379e-07  5.8528637e-07 -3.1538467e-08 -2.4594061e-06  3.2787428e-08 -7.8750267e-08  -1.140315e-06 -1.3617263e-06 -2.1170974e-07 -1.0890765e-06  6.7042342e-05  0.00044434554
#
#
# # ext. ||   Name    ||   type  ||     Value     ||  Error +/-
#
#    0   ||    0_norm || limited ||      1.090506163925 ||0.5384710742573
#    1   ||1_Prefactor || limited ||      3.695436185447 ||2.701273362743
#    2   ||    2_norm || limited ||     0.3991651199575 ||0.1667541052464
#    3   ||    3_norm || limited ||    0.03048384611404 ||0.7456876610357
#    4   ||4_Prefactor || limited ||      3.602603583341 ||0.03731675410346
#    5   ||    5_norm || limited ||      5.007248942424 ||2.69771755243
#    6   ||6_Prefactor || limited ||      4.308440250678 ||3.272842749369
#    7   ||7_Prefactor || limited ||     0.7787095298584 ||1.877884026558
#    8   ||    8_norm || limited ||     0.6403981619441 ||0.1808623698307
#    9   ||9_Prefactor || limited ||      0.918110908632 ||0.03616302365894
#   10   ||  10_Index || limited ||   -0.09184428104471 ||0.007002632351042
#   11   ||11_Normalization || limited ||      1.485793526286 ||0.05283408890198
#
#
#
#
#
# # of function calls: 345
# function Value: 76574.86159483
# expected distance to the Minimum (edm): 0.003577887808543
# external parameters:
# # ext. ||   Name    ||   type  ||     Value     ||  Error +/-
#
#    0   ||    0_norm || limited ||      1.090506163925 ||0.5382755924044
#    1   ||1_Prefactor || limited ||      3.695436185447 ||2.698582040689
#    2   ||    2_norm || limited ||     0.3991651199575 ||0.1667577044506
#    3   ||    3_norm || limited ||    0.03048384611404 ||0.8348376328016
#    4   ||4_Prefactor || limited ||      3.602603583341 ||0.03727953598598
#    5   ||    5_norm || limited ||      5.007248942424 ||2.697446685879
#    6   ||6_Prefactor || limited ||      4.308440250678 ||3.270304357289
#    7   ||7_Prefactor || limited ||     0.7787095298584 ||1.867416715567
#    8   ||    8_norm || limited ||     0.6403981619441 ||0.1798600837155
#    9   ||9_Prefactor || limited ||      0.918110908632 ||0.03574796275663
#   10   ||  10_Index || limited ||   -0.09184428104471 ||0.006850980006435
#   11   ||11_Normalization || limited ||      1.485793526286 ||0.05270979774009
#
#
#
# covariance matrix status: 3
# covariance matrix:
# MnUserCovariance:
#
#      0.289741   0.00128451 -7.39719e-05  -0.00374944 -0.000180694   0.00127804   0.00524583   0.00439296  0.000570962  0.000400773 -0.000128095 -0.000738585
#    0.00128451      7.28235   -0.0187936   0.00210145   -0.0095955    0.0184011    0.0438055    0.0457302   0.00449527  -0.00304697  0.000215011   0.00182684
#  -7.39719e-05   -0.0187936    0.0278081  1.71328e-05 -0.000418187  0.000421901   0.00121946   0.00111195  8.52346e-05 -1.11555e-05 -3.52215e-05  5.11989e-05
#   -0.00374944   0.00210145  1.71328e-05     0.101796 -0.000158447  0.000404217   0.00146641   0.00135626  0.000223729  0.000458249 -8.71986e-05 -0.000702568
#  -0.000180694   -0.0095955 -0.000418187 -0.000158447   0.00138976  -0.00244114  -0.00274714  -0.00323791 -8.75242e-05 -0.000137007  2.72818e-05  0.000100365
#    0.00127804    0.0184011  0.000421901  0.000404217  -0.00244114      7.27622  -0.00886978   0.00124431  0.000227697  0.000435667  -0.00031999 -0.000207893
#    0.00524583    0.0438055   0.00121946   0.00146641  -0.00274714  -0.00886978      10.6949    -0.275435     -0.02312   0.00243426 -0.000602621  -0.00397898
#    0.00439296    0.0457302   0.00111195   0.00135626  -0.00323791   0.00124431    -0.275435      3.48725   -0.0704002  0.000441137  8.34273e-05  -0.00204292
#   0.000570962   0.00449527  8.52346e-05  0.000223729 -8.75242e-05  0.000227697     -0.02312   -0.0704002    0.0323497  0.000137441   -2.682e-05 -0.000299629
#   0.000400773  -0.00304697 -1.11555e-05  0.000458249 -0.000137007  0.000435667   0.00243426  0.000441137  0.000137441   0.00127792 -0.000113702   -0.0018238
#  -0.000128095  0.000215011 -3.52215e-05 -8.71986e-05  2.72818e-05  -0.00031999 -0.000602621  8.34273e-05   -2.682e-05 -0.000113702  4.69367e-05  0.000101986
#  -0.000738585   0.00182684  5.11989e-05 -0.000702568  0.000100365 -0.000207893  -0.00397898  -0.00204292 -0.000299629   -0.0018238  0.000101986   0.00277853
#
# MnUserCovariance Parameter correlations:
#
#             1  0.000884292 -0.000824092   -0.0218321  -0.00900468  0.000880212   0.00298003   0.00437029    0.0058975    0.0208278   -0.0347354   -0.0260309
#   0.000884292            1   -0.0417627   0.00244072   -0.0953809   0.00252787   0.00496369   0.00907457   0.00926158    -0.031585    0.0116297    0.0128428
#  -0.000824092   -0.0417627            1  0.000322015   -0.0672689  0.000937933   0.00223611   0.00357074   0.00284181  -0.00187133   -0.0308295   0.00582461
#    -0.0218321   0.00244072  0.000322015            1   -0.0133214  0.000469674    0.0014054   0.00227634   0.00389871    0.0401776   -0.0398922   -0.0417749
#   -0.00900468   -0.0953809   -0.0672689   -0.0133214            1   -0.0242756   -0.0225332   -0.0465106   -0.0130534    -0.102806     0.106819    0.0510747
#   0.000880212   0.00252787  0.000937933  0.000469674   -0.0242756            1  -0.00100548  0.000247021  0.000469321   0.00451804   -0.0173152  -0.00146211
#    0.00298003   0.00496369   0.00223611    0.0014054   -0.0225332  -0.00100548            1   -0.0451013   -0.0393066    0.0208222   -0.0268967   -0.0230822
#    0.00437029   0.00907457   0.00357074   0.00227634   -0.0465106  0.000247021   -0.0451013            1    -0.209603   0.00660817   0.00652095    -0.020754
#     0.0058975   0.00926158   0.00284181   0.00389871   -0.0130534  0.000469321   -0.0393066    -0.209603            1    0.0213762   -0.0217654    -0.031604
#     0.0208278    -0.031585  -0.00187133    0.0401776    -0.102806   0.00451804    0.0208222   0.00660817    0.0213762            1    -0.464261    -0.967875
#    -0.0347354    0.0116297   -0.0308295   -0.0398922     0.106819   -0.0173152   -0.0268967   0.00652095   -0.0217654    -0.464261            1     0.282408
#    -0.0260309    0.0128428   0.00582461   -0.0417749    0.0510747  -0.00146211   -0.0230822    -0.020754    -0.031604    -0.967875     0.282408            1
#
# global correlation coefficients :
# MnGlobalCorrelationCoeff:
#
#     0.0836599
#      0.179093
#     0.0973213
#     0.0723921
#      0.300093
#     0.0299761
#     0.0944661
#      0.247137
#      0.242376
#      0.989263
#      0.820239
#      0.987362
# ..............................................................................................................................................................................................................................................................................................!
# Computing TS values for each source (286 total)
#
# Photon fluxes are computed for the energy range 100 to 500000 MeV
#
# 4FGL J1118.2-0415:
# Prefactor: 1.21733
# Index: 2.65729
# Scale: 767.397
# Flux: 1.65385e-08 photons/cm^2/s
#
# 4FGL J1118.6-1235:
# Prefactor: 1.79297
# Index: 2.76938
# Scale: 625.569
# Flux: 1.62846e-08 photons/cm^2/s
#
# 4FGL J1119.9-1007:
# Prefactor: 8.26183
# Index: 2.2706
# Scale: 1646.44
# Flux: 3.76512e-09 photons/cm^2/s
#
# 4FGL J1121.3-0011:
# Prefactor: 8.42874
# Index: 1.91826
# Scale: 4117.39
# Flux: 1.14847e-09 photons/cm^2/s
#
# 4FGL J1121.4-0553:
# norm: 4.58502
# alpha: 2.33557
# beta: 0.144621
# Eb: 743.923
# Flux: 2.78332e-08 photons/cm^2/s
#
# 4FGL J1122.0-0231:
# Prefactor: 6.19836
# Index: 2.28883
# Scale: 2009.64
# Flux: 4.62525e-09 photons/cm^2/s
#
# 4FGL J1122.5-1440:
# Prefactor: 6.43062
# Index: 2.83306
# Scale: 703.196
# Flux: 8.82658e-09 photons/cm^2/s
#
# 4FGL J1124.1-1203:
# norm: 6.21635
# alpha: 2.26213
# beta: 0.356041
# Eb: 1877.42
# Flux: 8.87032e-10 photons/cm^2/s
#
# 4FGL J1124.5-0658:
# Prefactor: 4.35795
# Index: 2.43387
# Scale: 1791.34
# Flux: 3.41502e-09 photons/cm^2/s
#
# 4FGL J1124.6-0809:
# Prefactor: 1.54953
# Index: 2.09645
# Scale: 3274.88
# Flux: 2.1234e-09 photons/cm^2/s
#
# 4FGL J1125.9-0742:
# Prefactor: 3.47483
# Index: 1.9331
# Scale: 3611.28
# Flux: 3.82122e-09 photons/cm^2/s
#
# 4FGL J1128.3-1301:
# Prefactor: 6.89363
# Index: 2.04471
# Scale: 3489.47
# Flux: 9.42275e-10 photons/cm^2/s
#
# 4FGL J1129.2-0529:
# norm: 1.1598
# alpha: 2.50536
# beta: 0.106133
# Eb: 920.298
# Flux: 1.49832e-08 photons/cm^2/s
#
# 4FGL J1129.2-1014:
# Prefactor: 1.27055
# Index: 2.21839
# Scale: 2983.14
# Flux: 1.94977e-09 photons/cm^2/s
#
# 4FGL J1129.8-1447:
# norm: 5.53741
# alpha: 2.63222
# beta: 0.122453
# Eb: 744.629
# Flux: 5.09862e-08 photons/cm^2/s
#
# 4FGL J1131.1-0944:
# Prefactor: 1.90342
# Index: 2.06433
# Scale: 3337.41
# Flux: 2.49763e-09 photons/cm^2/s
#
# 4FGL J1131.4-0504:
# norm: 3.19151
# alpha: 2.36658
# beta: 0.250184
# Eb: 1307.5
# Flux: 4.34713e-09 photons/cm^2/s
#
# 4FGL J1132.1-1448:
# Prefactor: 2.7491
# Index: 2.1563
# Scale: 3097.59
# Flux: 3.90436e-09 photons/cm^2/s
#
# 4FGL J1132.7+0034:
# norm: 2.31059
# alpha: 2.08032
# beta: 0.0404932
# Eb: 1075.3
# Flux: 2.66434e-08 photons/cm^2/s
#
# 4FGL J1133.8-2048:
# norm: 1.83272
# alpha: 1.51095
# beta: 0.342274
# Eb: 3754.18
# Flux: 2.50063e-10 photons/cm^2/s
#
# 4FGL J1134.8-1729:
# Prefactor: 1.91696
# Index: 1.67832
# Scale: 8414.19
# Flux: 4.79453e-10 photons/cm^2/s
#
# 4FGL J1135.7-0427:
# Prefactor: 5.35366
# Index: 2.69627
# Scale: 808.157
# Flux: 8.84666e-09 photons/cm^2/s
#
# 4FGL J1136.3-0501:
# norm: 4.83984
# alpha: 2.54383
# beta: 0.253227
# Eb: 955.72
# Flux: 4.91443e-09 photons/cm^2/s
#
# 4FGL J1137.3+0535:
# Prefactor: 1.09776
# Index: 2.38031
# Scale: 1222.65
# Flux: 3.08427e-09 photons/cm^2/s
#
# 4FGL J1137.9-1708:
# norm: 1.51047
# alpha: 1.34921
# beta: 0.292904
# Eb: 5047.01
# Flux: 2.75525e-10 photons/cm^2/s
#
# 4FGL J1140.4+0022:
# Prefactor: 8.22699
# Index: 2.50782
# Scale: 1366.39
# Flux: 3.84871e-09 photons/cm^2/s
#
# 4FGL J1140.7-0129:
# Prefactor: 1.56018
# Index: 2.11597
# Scale: 2755.95
# Flux: 1.56097e-09 photons/cm^2/s
#
# 4FGL J1141.5-1408:
# Prefactor: 2.12083
# Index: 1.95784
# Scale: 3436.74
# Flux: 2.25355e-09 photons/cm^2/s
#
# 4FGL J1142.8+0120:
# Prefactor: 6.52057
# IndexS: 1.62688
# Scale: 1355.67
# ExpfactorS: 4.31477
# Index2: 0.666667
# Flux: 4.63683e-09 photons/cm^2/s
#
# 4FGL J1143.7-1014:
# norm: 4.9204
# alpha: 2.14728
# beta: 0.497019
# Eb: 1967
# Flux: 4.55488e-10 photons/cm^2/s
#
# 4FGL J1145.5-0340:
# Prefactor: 4.86152
# Index: 1.95808
# Scale: 4868.6
# Flux: 1.02226e-09 photons/cm^2/s
#
# 4FGL J1145.7+0453:
# Prefactor: 2.24203
# Index: 2.91383
# Scale: 407.445
# Flux: 7.03648e-09 photons/cm^2/s
#
# 4FGL J1145.7-1528:
# norm: 2.31281
# alpha: 2.37675
# beta: 0.430928
# Eb: 909.729
# Flux: 1.21891e-09 photons/cm^2/s
#
# 4FGL J1146.0-0638:
# norm: 2.13532
# alpha: 1.58103
# beta: 0.14119
# Eb: 4245.21
# Flux: 6.33849e-10 photons/cm^2/s
#
# 4FGL J1146.4-0926:
# Prefactor: 1.02745
# Index: 2.5
# Scale: 1000
# Flux: 2.16904e-09 photons/cm^2/s
#
# 4FGL J1147.8-0724:
# norm: 3.0369
# alpha: 2.42804
# beta: 0.101455
# Eb: 639.236
# Flux: 1.60961e-08 photons/cm^2/s
#
# 4FGL J1148.2-0029:
# Prefactor: 4.19141
# Index: 2.64541
# Scale: 753.288
# Flux: 5.33004e-09 photons/cm^2/s
#
# 4FGL J1150.0+1033:
# Prefactor: 4.31051
# Index: 2.03258
# Scale: 4527.48
# Flux: 9.69365e-10 photons/cm^2/s
#
# 4FGL J1150.8-1905:
# norm: 1.19764
# alpha: 1.44899
# beta: 0.382785
# Eb: 10726.2
# Flux: 4.19708e-11 photons/cm^2/s
#
# 4FGL J1151.3+0957:
# Prefactor: 1.40917
# Index: 2.37801
# Scale: 1790.66
# Flux: 9.77006e-09 photons/cm^2/s
#
# 4FGL J1151.5-1347:
# norm: 6.84868
# alpha: 1.76845
# beta: 0.0822869
# Eb: 2507.91
# Flux: 1.77783e-09 photons/cm^2/s
#
# 4FGL J1151.6-2115:
# Prefactor: 2.303
# Index: 2.01975
# Scale: 2973.42
# Flux: 2.13606e-09 photons/cm^2/s
#
# 4FGL J1152.3-0839:
# norm: 5.40447
# alpha: 2.31117
# beta: 0.120372
# Eb: 664.743
# Flux: 2.65457e-08 photons/cm^2/s
#
# 4FGL J1153.2+0123:
# Prefactor: 7.69486
# Index: 2.07439
# Scale: 3400.32
# Flux: 1.07715e-09 photons/cm^2/s
#
# 4FGL J1153.3-1104:
# norm: 5.66504
# alpha: 2.22633
# beta: 0.0934098
# Eb: 684.547
# Flux: 2.82637e-08 photons/cm^2/s
#
# 4FGL J1153.6-2553:
# norm: 3.77909
# alpha: 1.72438
# beta: 0.187839
# Eb: 3056.88
# Flux: 7.7855e-10 photons/cm^2/s
#
# 4FGL J1154.0-0010:
# Prefactor: 2.23737
# Index: 1.84453
# Scale: 4056.51
# Flux: 2.45057e-09 photons/cm^2/s
#
# 4FGL J1155.2-1111:
# norm: 4.22357
# alpha: 1.66803
# beta: 0.306927
# Eb: 6641.44
# Flux: 1.28115e-10 photons/cm^2/s
#
# 4FGL J1155.8-1217:
# Prefactor: 5.23437
# Index: 2.31584
# Scale: 1735.75
# Flux: 2.95508e-09 photons/cm^2/s
#
# 4FGL J1156.6+0640:
# Prefactor: 1.98028
# Index: 2.51564
# Scale: 1024.46
# Flux: 4.55815e-09 photons/cm^2/s
#
# 4FGL J1156.6-2248:
# Prefactor: 3.10118
# Index: 2.03685
# Scale: 3298.25
# Flux: 3.70301e-09 photons/cm^2/s
#
# 4FGL J1156.8-1537:
# Prefactor: 2.55123
# Index: 2.35674
# Scale: 1166.49
# Flux: 6.15316e-09 photons/cm^2/s
#
# 4FGL J1158.8-1430:
# Prefactor: 2.14761
# Index: 1.71674
# Scale: 9521.17
# Flux: 7.45869e-10 photons/cm^2/s
#
# 4FGL J1158.9+0818:
# Prefactor: 2.63872
# Index: 2.02477
# Scale: 2882.44
# Flux: 2.32622e-09 photons/cm^2/s
#
# 4FGL J1158.9+0956:
# norm: 1.53165
# alpha: 2.40846
# beta: 0.269619
# Eb: 728.794
# Flux: 7.74476e-09 photons/cm^2/s
#
# 4FGL J1159.0+0939:
# norm: 3.97967
# alpha: 1.64713
# beta: 0.231624
# Eb: 3553.49
# Flux: 7.61493e-10 photons/cm^2/s
#
# 4FGL J1159.2-2227:
# norm: 1.95797
# alpha: 2.31292
# beta: 0.159469
# Eb: 1067.9
# Flux: 2.23943e-08 photons/cm^2/s
#
# 4FGL J1159.3-2142:
# norm: 3.44226
# alpha: 2.49565
# beta: 0.0873405
# Eb: 824.127
# Flux: 3.59585e-08 photons/cm^2/s
#
# 4FGL J1159.5-0723:
# norm: 5.04758
# alpha: 1.66046
# beta: 0.232615
# Eb: 2949.48
# Flux: 7.95492e-10 photons/cm^2/s
#
# 4FGL J1200.2+0201:
# norm: 2.23243
# alpha: 1.85558
# beta: 0.13219
# Eb: 1663.16
# Flux: 2.98851e-09 photons/cm^2/s
#
# 4FGL J1200.6+1229:
# Prefactor: 4.62056
# Index: 2.50844
# Scale: 928.685
# Flux: 8.21508e-09 photons/cm^2/s
#
# 4FGL J1200.8-1429:
# Prefactor: 1.57626
# Index: 2.00422
# Scale: 3577.82
# Flux: 2.04068e-09 photons/cm^2/s
#
# 4FGL J1201.1-0332:
# Prefactor: 3.36974
# Index: 2.11
# Scale: 2225.32
# Flux: 2.11626e-09 photons/cm^2/s
#
# 4FGL J1201.7+1429:
# norm: 2.58164
# alpha: 2.17571
# beta: 0.325815
# Eb: 1107.43
# Flux: 1.75887e-09 photons/cm^2/s
#
# 4FGL J1202.5-0528:
# norm: 1.42613
# alpha: 2.75878
# beta: 0.193121
# Eb: 320.75
# Flux: 1.78464e-08 photons/cm^2/s
#
# 4FGL J1203.3+1119:
# Prefactor: 1.07332
# Index: 2.347
# Scale: 1360.76
# Flux: 3.65451e-09 photons/cm^2/s
#
# 4FGL J1203.5-1748:
# norm: 2.44416
# alpha: 2.09105
# beta: 0.251414
# Eb: 1338.92
# Flux: 2.33632e-09 photons/cm^2/s
#
# 4FGL J1204.0+1146:
# Prefactor: 1.25653
# Index: 1.79272
# Scale: 4409.96
# Flux: 1.40516e-09 photons/cm^2/s
#
# 4FGL J1204.2-0709:
# norm: 1.25767
# alpha: 1.72633
# beta: 0.0961203
# Eb: 2440.57
# Flux: 2.76144e-09 photons/cm^2/s
#
# 4FGL J1204.8+0407:
# Prefactor: 6.98445
# Index: 2.72626
# Scale: 610.586
# Flux: 5.62308e-09 photons/cm^2/s
#
# 4FGL J1205.7-2635:
# Prefactor: 1.50444
# Index: 2.53133
# Scale: 795.638
# Flux: 1.87475e-08 photons/cm^2/s
#
# 4FGL J1207.2-0524:
# norm: 1.8675
# alpha: 1.62132
# beta: 0.210875
# Eb: 3629.87
# Flux: 3.78555e-10 photons/cm^2/s
#
# 4FGL J1207.4-1840:
# Prefactor: 4.28163
# Index: 2.26491
# Scale: 1856.04
# Flux: 2.53049e-09 photons/cm^2/s
#
# 4FGL J1207.7-0106:
# norm: 1.11271
# alpha: 2.15754
# beta: 0.129287
# Eb: 903.53
# Flux: 8.17641e-09 photons/cm^2/s
#
# 4FGL J1207.7-2229:
# Prefactor: 3.58751
# Index: 2.04207
# Scale: 3075.53
# Flux: 3.7632e-09 photons/cm^2/s
#
# 4FGL J1208.2+1158:
# Prefactor: 7.74792
# Index: 2.26754
# Scale: 1631.62
# Flux: 3.43799e-09 photons/cm^2/s
#
# 4FGL J1208.8-1751:
# norm: 3.94047
# alpha: 1.7644
# beta: 0.349506
# Eb: 2507.24
# Flux: 4.32946e-10 photons/cm^2/s
#
# 4FGL J1208.8-2754:
# norm: 6.49259
# alpha: 1.77473
# beta: 0.357587
# Eb: 2512.91
# Flux: 7.09852e-10 photons/cm^2/s
#
# 4FGL J1211.6-2735:
# norm: 1.2827
# alpha: 2.61625
# beta: 0.100649
# Eb: 832.784
# Flux: 1.57446e-08 photons/cm^2/s
#
# 4FGL J1212.0-2326:
# Prefactor: 4.52525
# Index: 2.01614
# Scale: 3031.61
# Flux: 4.32669e-09 photons/cm^2/s
#
# 4FGL J1212.7-1402:
# Prefactor: 1.99665
# Index: 1.96959
# Scale: 6610.82
# Flux: 7.92516e-10 photons/cm^2/s
#
# 4FGL J1213.1-1123:
# Prefactor: 1.4986
# Index: 2.27428
# Scale: 2644.99
# Flux: 2.02227e-09 photons/cm^2/s
#
# 4FGL J1213.3-2618:
# Prefactor: 1.08402
# Index: 1.77889
# Scale: 5495.05
# Flux: 1.73128e-09 photons/cm^2/s
#
# 4FGL J1213.6+1236:
# Prefactor: 4.62228
# Index: 2.01729
# Scale: 4723.82
# Flux: 1.08429e-09 photons/cm^2/s
#
# 4FGL J1213.6+1306:
# norm: 2.46627
# alpha: 2.33389
# beta: 0.16924
# Eb: 685.522
# Flux: 1.21562e-08 photons/cm^2/s
#
# 4FGL J1214.5-2318:
# Prefactor: 2.54309
# Index: 2.19736
# Scale: 2570.43
# Flux: 2.66561e-09 photons/cm^2/s
#
# 4FGL J1214.6-1926:
# norm: 2.39767
# alpha: 2.39954
# beta: 0.504141
# Eb: 1058.07
# Flux: 1.39689e-09 photons/cm^2/s
#
# 4FGL J1215.0+1656:
# Prefactor: 1.07253
# Index: 2.40615
# Scale: 892.278
# Flux: 1.47894e-08 photons/cm^2/s
#
# 4FGL J1215.1+0731:
# Prefactor: 2.01669
# Index: 1.8612
# Scale: 4027.84
# Flux: 2.27408e-09 photons/cm^2/s
#
# 4FGL J1215.8-1733:
# Prefactor: 9.13463
# Index: 2.60761
# Scale: 732.43
# Flux: 1.02371e-08 photons/cm^2/s
#
# 4FGL J1216.1+0930:
# Prefactor: 6.6174
# Index: 2.04894
# Scale: 2285.21
# Flux: 3.8418e-09 photons/cm^2/s
#
# 4FGL J1216.1-0242:
# Prefactor: 7.41471
# Index: 2.01505
# Scale: 4442.9
# Flux: 1.52736e-09 photons/cm^2/s
#
# 4FGL J1216.2+0537:
# Prefactor: 2.63062
# Index: 1.90934
# Scale: 5319.01
# Flux: 5.70908e-10 photons/cm^2/s
#
# 4FGL J1216.2-0600:
# Prefactor: 8.13854
# Index: 2.51779
# Scale: 932.739
# Flux: 1.48456e-08 photons/cm^2/s
#
# 4FGL J1216.2-1550:
# Prefactor: 9.67702
# Index: 2.09216
# Scale: 3248.8
# Flux: 1.28974e-09 photons/cm^2/s
#
# 4FGL J1216.3-1032:
# norm: 1.44128
# alpha: 2.59214
# beta: 0.304705
# Eb: 662.36
# Flux: 7.03045e-09 photons/cm^2/s
#
# 4FGL J1216.4-1358:
# Prefactor: 3.00363
# Index: 2.15441
# Scale: 2474.21
# Flux: 2.61611e-09 photons/cm^2/s
#
# 4FGL J1217.2-2500:
# norm: 1.09793
# alpha: 2.19076
# beta: 0.302927
# Eb: 1710.86
# Flux: 1.46552e-09 photons/cm^2/s
#
# 4FGL J1218.0-0028:
# Prefactor: 1.64252
# Index: 2.34444
# Scale: 1606.47
# Flux: 8.21385e-09 photons/cm^2/s
#
# 4FGL J1218.5-0119:
# norm: 1.22438
# alpha: 2.01102
# beta: 0.103007
# Eb: 1296.05
# Flux: 1.50342e-08 photons/cm^2/s
#
# 4FGL J1219.6+0550:
# Prefactor: 3.3716
# Index: 2.17273
# Scale: 2429.65
# Flux: 2.94713e-09 photons/cm^2/s
#
# 4FGL J1219.7+0444:
# Prefactor: 3.42704
# Index: 2.08526
# Scale: 2786.57
# Flux: 3.25845e-09 photons/cm^2/s
#
# 4FGL J1219.7-0313:
# Prefactor: 4.02261
# Index: 1.95223
# Scale: 3239.8
# Flux: 3.75625e-09 photons/cm^2/s
#
# 4FGL J1219.8-2008:
# Prefactor: 6.87925
# Index: 1.95782
# Scale: 4221.01
# Flux: 1.09307e-09 photons/cm^2/s
#
# 4FGL J1220.1-2458:
# Prefactor: 1.15624
# Index: 2.07341
# Scale: 4220.46
# Flux: 2.52689e-09 photons/cm^2/s
#
# 4FGL J1220.5-2745:
# Prefactor: 5.22774
# Index: 2.73823
# Scale: 810.474
# Flux: 9.27581e-09 photons/cm^2/s
#
# 4FGL J1221.4-0634:
# Prefactor: 7.20056
# IndexS: 1.81368
# Scale: 1223.43
# ExpfactorS: 5.40006
# Index2: 0.666667
# Flux: 4.98223e-09 photons/cm^2/s
#
# 4FGL J1222.5+0414:
# norm: 1.24905
# alpha: 2.60685
# beta: 0.182167
# Eb: 489.876
# Flux: 3.89487e-08 photons/cm^2/s
#
# 4FGL J1223.0+1100:
# norm: 2.05921
# alpha: 1.50322
# beta: 0.302258
# Eb: 3880.81
# Flux: 3.1321e-10 photons/cm^2/s
#
# 4FGL J1223.3+1213:
# Prefactor: 6.74737
# Index: 2.70935
# Scale: 689.386
# Flux: 7.3922e-09 photons/cm^2/s
#
# 4FGL J1223.5+0818:
# Prefactor: 1.44914
# Index: 2.00425
# Scale: 3899.01
# Flux: 2.22905e-09 photons/cm^2/s
#
# 4FGL J1223.9-0545:
# Prefactor: 2.71093
# Index: 2.5992
# Scale: 894.175
# Flux: 5.04468e-09 photons/cm^2/s
#
# 4FGL J1223.9-2220:
# Prefactor: 1.73672
# Index: 2.59759
# Scale: 1000
# Flux: 4.31059e-09 photons/cm^2/s
#
# 4FGL J1225.0+0330:
# Prefactor: 4.76774
# Index: 2.62559
# Scale: 1163.28
# Flux: 1.84524e-08 photons/cm^2/s
#
# 4FGL J1225.4-1550:
# Prefactor: 4.32715
# Index: 1.69918
# Scale: 11697.4
# Flux: 2.01683e-10 photons/cm^2/s
#
# 4FGL J1225.5-2851:
# norm: 2.32941
# alpha: 2.22859
# beta: 0.283222
# Eb: 1170.89
# Flux: 2.02014e-09 photons/cm^2/s
#
# 4FGL J1225.8-2941:
# Prefactor: 7.34823
# Index: 2.42255
# Scale: 1491.17
# Flux: 3.6023e-09 photons/cm^2/s
#
# 4FGL J1226.7+0637:
# norm: 9.89258
# alpha: 1.48725
# beta: 0.182991
# Eb: 4846.27
# Flux: 2.57802e-10 photons/cm^2/s
#
# 4FGL J1226.8-1329:
# Prefactor: 1.35755
# Index: 2.03528
# Scale: 2138.08
# Flux: 6.6818e-09 photons/cm^2/s
#
# 4FGL J1228.7-0318:
# Prefactor: 7.09683
# Index: 2.05615
# Scale: 2283.2
# Flux: 4.17785e-09 photons/cm^2/s
#
# 4FGL J1229.0+0202:
# norm: 1.09428
# alpha: 2.64805
# beta: 0.100307
# Eb: 410.12
# Flux: 2.52738e-07 photons/cm^2/s
#
# 4FGL J1230.8+1223:
# norm: 1.01055
# alpha: 2.01542
# beta: 0.0351887
# Eb: 1315.15
# Flux: 1.58888e-08 photons/cm^2/s
#
# 4FGL J1231.1-1412:
# Prefactor: 9.11248
# IndexS: 1.83596
# Scale: 1587.74
# ExpfactorS: 7.86565
# Index2: 0.518825
# Flux: 7.24581e-08 photons/cm^2/s
#
# 4FGL J1231.5+1421:
# Prefactor: 1.24089
# Index: 1.87481
# Scale: 4894.78
# Flux: 2.08787e-09 photons/cm^2/s
#
# 4FGL J1231.8-0450:
# Prefactor: 2.45566
# Index: 1.5661
# Scale: 21680.4
# Flux: 1.9605e-10 photons/cm^2/s
#
# 4FGL J1233.0+1333:
# norm: 9.26263
# alpha: 2.42881
# beta: 0.154131
# Eb: 830.992
# Flux: 7.73037e-09 photons/cm^2/s
#
# 4FGL J1233.1+1703:
# norm: 1.38595
# alpha: 1.51161
# beta: 0.314893
# Eb: 4116.54
# Flux: 2.19481e-10 photons/cm^2/s
#
# 4FGL J1233.7-0144:
# Prefactor: 3.21416
# Index: 2.12
# Scale: 1719.04
# Flux: 1.19389e-08 photons/cm^2/s
#
# 4FGL J1234.7-0434:
# Prefactor: 1.17057
# Index: 2.06007
# Scale: 3645.49
# Flux: 1.82236e-09 photons/cm^2/s
#
# 4FGL J1235.1-1405:
# norm: 2.16169
# alpha: 1.46801
# beta: 0.333893
# Eb: 10685.2
# Flux: 8.34202e-11 photons/cm^2/s
#
# 4FGL J1235.9+1136:
# norm: 2.58624
# alpha: 2.1088
# beta: 0.27871
# Eb: 2520.63
# Flux: 5.42141e-10 photons/cm^2/s
#
# 4FGL J1238.3-1959:
# norm: 5.01075
# alpha: 2.02954
# beta: 0.0933475
# Eb: 1298.19
# Flux: 6.52595e-09 photons/cm^2/s
#
# 4FGL J1238.5-1201:
# norm: 6.55149
# alpha: 2.5529
# beta: 0.0991276
# Eb: 475.234
# Flux: 2.00189e-08 photons/cm^2/s
#
# 4FGL J1239.4+0728:
# norm: 2.93584
# alpha: 2.00821
# beta: 0.202841
# Eb: 1201.24
# Flux: 2.42986e-09 photons/cm^2/s
#
# 4FGL J1239.5+0443:
# norm: 3.53986
# alpha: 2.21596
# beta: 0.124267
# Eb: 503.437
# Flux: 8.98817e-08 photons/cm^2/s
#
# 4FGL J1240.4-2606:
# Prefactor: 5.20615
# Index: 2.24383
# Scale: 2044.16
# Flux: 3.6537e-09 photons/cm^2/s
#
# 4FGL J1240.8-2918:
# Prefactor: 9.51147
# Index: 2.77689
# Scale: 649.429
# Flux: 9.67701e-09 photons/cm^2/s
#
# 4FGL J1241.8-1456:
# norm: 5.56043
# alpha: 1.66354
# beta: 0.201226
# Eb: 2877.24
# Flux: 9.40571e-10 photons/cm^2/s
#
# 4FGL J1241.9+0636:
# Prefactor: 7.13803
# Index: 2.05043
# Scale: 4158.03
# Flux: 1.41862e-09 photons/cm^2/s
#
# 4FGL J1243.7+1727:
# Prefactor: 4.71985
# Index: 2.05816
# Scale: 4339.44
# Flux: 1.04646e-09 photons/cm^2/s
#
# 4FGL J1243.9-0218:
# norm: 1.09051 +/- 0.538276
# alpha: 2.09202
# beta: 0.168285
# Eb: 1313.3
# TS value: 5.7531
# Flux: 1.26948e-09 +/- 6.26565e-10 photons/cm^2/s
#
# 4FGL J1244.5+1616:
# Prefactor: 3.86451
# Index: 2.0962
# Scale: 2370.06
# Flux: 2.68693e-09 photons/cm^2/s
#
# 4FGL J1245.4-0701:
# Prefactor: 3.69544 +/- 2.69858
# Index: 2.32914
# Scale: 1776.77
# TS value: 2.24155
# Flux: 2.26533e-09 +/- 1.65247e-09 photons/cm^2/s
#
# 4FGL J1245.8+0232:
# norm: 3.42753
# alpha: 2.05545
# beta: 0.360049
# Eb: 1282.16
# Flux: 2.31095e-09 photons/cm^2/s
#
# 4FGL J1246.3+0112:
# Prefactor: 2.26179
# Index: 2.23086
# Scale: 2337.23
# Flux: 2.07978e-09 photons/cm^2/s
#
# 4FGL J1246.7-2548:
# norm: 2.81378
# alpha: 2.19964
# beta: 0.114165
# Eb: 641.629
# Flux: 1.15956e-07 photons/cm^2/s
#
# 4FGL J1249.2-2809:
# Prefactor: 7.58726
# Index: 2.04697
# Scale: 2547.87
# Flux: 5.48013e-09 photons/cm^2/s
#
# 4FGL J1249.3-0545:
# norm: 0.399165 +/- 0.166758
# alpha: 1.8463
# beta: 0.104405
# Eb: 2531.27
# TS value: 10.8047
# Flux: 1.08923e-09 +/- 4.55021e-10 photons/cm^2/s
#
# 4FGL J1250.6+0217:
# Prefactor: 6.06199
# Index: 2.01915
# Scale: 2608.55
# Flux: 4.31028e-09 photons/cm^2/s
#
# 4FGL J1251.2+1039:
# Prefactor: 2.88202
# Index: 2.11382
# Scale: 2482.58
# Flux: 2.30016e-09 photons/cm^2/s
#
# 4FGL J1251.3-0201:
# norm: 0.0304838 +/- 0.319055
# alpha: 2.00365
# beta: 0.153138
# Eb: 1272.79
# TS value: 0.022498
# Flux: 3.11668e-11 +/- 3.26177e-10 photons/cm^2/s
#
# 4FGL J1251.3-1719:
# Prefactor: 3.24128
# Index: 3.10425
# Scale: 363.848
# Flux: 8.51215e-09 photons/cm^2/s
#
# 4FGL J1252.7-2520:
# Prefactor: 3.94282
# Index: 2.73615
# Scale: 827.306
# Flux: 7.37732e-09 photons/cm^2/s
#
# 4FGL J1253.8+0327:
# Prefactor: 1.93326
# Index: 2.01989
# Scale: 1967.71
# Flux: 7.7912e-09 photons/cm^2/s
#
# 4FGL J1254.2-2205:
# Prefactor: 7.78402
# Index: 2.22179
# Scale: 2175.4
# Flux: 5.97481e-09 photons/cm^2/s
#
# 4FGL J1254.9+1138:
# Prefactor: 2.51493
# Index: 2.76453
# Scale: 483.026
# Flux: 1.11068e-08 photons/cm^2/s
#
# 4FGL J1256.1-0547:
# Prefactor: 3.6026 +/- 0.0372795
# IndexS: 2.28656
# Scale: 1004.64
# ExpfactorS: 1.48564
# Index2: 0.221034
# TS value: 27815
# Flux: 4.54713e-07 +/- 4.70211e-09 photons/cm^2/s
#
# 4FGL J1256.2-1146:
# Prefactor: 1.06489
# Index: 1.96772
# Scale: 2644.67
# Flux: 6.92655e-09 photons/cm^2/s
#
# 4FGL J1256.8-1333:
# Prefactor: 3.14281
# Index: 2.44974
# Scale: 2006.41
# Flux: 3.36649e-09 photons/cm^2/s
#
# 4FGL J1258.6-1759:
# norm: 3.42623
# alpha: 2.19996
# beta: 0.151045
# Eb: 685.078
# Flux: 1.51111e-08 photons/cm^2/s
#
# 4FGL J1258.7-0452:
# norm: 5.00725 +/- 2.69745
# alpha: 1.59911
# beta: 0.202868
# Eb: 6067.13
# TS value: 8.45189
# Flux: 1.77287e-10 +/- 9.55099e-11 photons/cm^2/s
#
# 4FGL J1258.8-2219:
# norm: 3.92097
# alpha: 2.32892
# beta: 0.0903001
# Eb: 841.503
# Flux: 3.40125e-08 photons/cm^2/s
#
# 4FGL J1259.1-2311:
# Prefactor: 1.22057
# Index: 2.04848
# Scale: 2609.67
# Flux: 9.29156e-09 photons/cm^2/s
#
# 4FGL J1300.0+1753:
# Prefactor: 2.65032
# Index: 2.49365
# Scale: 938.666
# Flux: 4.72876e-09 photons/cm^2/s
#
# 4FGL J1300.4+1416:
# norm: 8.83
# alpha: 2.54229
# beta: 0.13123
# Eb: 395.216
# Flux: 1.674e-08 photons/cm^2/s
#
# 4FGL J1301.6+0834:
# Prefactor: 1.6569
# IndexS: 1.84622
# Scale: 1018.88
# ExpfactorS: 6.25972
# Index2: 0.666667
# Flux: 8.49651e-09 photons/cm^2/s
#
# 4FGL J1302.2-0032:
# Prefactor: 2.27732
# Index: 2.58205
# Scale: 898.966
# Flux: 4.18294e-09 photons/cm^2/s
#
# 4FGL J1304.2-2412:
# norm: 2.00629
# alpha: 1.90642
# beta: 0.077338
# Eb: 1959.41
# Flux: 4.5764e-09 photons/cm^2/s
#
# 4FGL J1304.4+1203:
# norm: 2.72897
# alpha: 2.06237
# beta: 0.623972
# Eb: 1425.27
# Flux: 1.34168e-09 photons/cm^2/s
#
# 4FGL J1304.6+0539:
# norm: 5.77295
# alpha: 2.28683
# beta: 0.199698
# Eb: 849.081
# Flux: 3.81585e-09 photons/cm^2/s
#
# 4FGL J1304.6-0348:
# Prefactor: 1.62937
# Index: 2.20384
# Scale: 2289.24
# Flux: 1.3439e-09 photons/cm^2/s
#
# 4FGL J1304.9-2107:
# Prefactor: 9.31946
# Index: 2.29085
# Scale: 1917.86
# Flux: 6.27616e-09 photons/cm^2/s
#
# 4FGL J1306.3+1113:
# Prefactor: 4.96833
# Index: 1.87161
# Scale: 5351.95
# Flux: 9.79342e-10 photons/cm^2/s
#
# 4FGL J1306.7-2148:
# norm: 1.70951
# alpha: 1.97449
# beta: 0.201698
# Eb: 1888.14
# Flux: 2.60394e-09 photons/cm^2/s
#
# 4FGL J1307.1-0344:
# Prefactor: 4.30844 +/- 3.27031
# Index: 1.93029
# Scale: 4455.02
# TS value: 2.91298
# Flux: 7.05564e-10 +/- 5.35273e-10 photons/cm^2/s
#
# 4FGL J1308.7+0347:
# norm: 1.39434
# alpha: 1.90088
# beta: 0.24741
# Eb: 1576.69
# Flux: 1.3254e-09 photons/cm^2/s
#
# 4FGL J1309.7+1153:
# Prefactor: 2.9576
# Index: 2.20077
# Scale: 1401.83
# Flux: 8.23127e-09 photons/cm^2/s
#
# 4FGL J1310.1-0450:
# Prefactor: 0.77871 +/- 1.86742
# Index: 2.50812
# Scale: 1606.75
# TS value: 0.15135
# Flux: 5.47285e-10 +/- 1.31062e-09 photons/cm^2/s
#
# 4FGL J1310.2-1158:
# Prefactor: 5.03793
# Index: 2.01477
# Scale: 2753.39
# Flux: 3.95447e-09 photons/cm^2/s
#
# 4FGL J1311.0+0034:
# Prefactor: 3.427
# Index: 2.10367
# Scale: 3388.15
# Flux: 5.1393e-09 photons/cm^2/s
#
# 4FGL J1312.4-2156:
# norm: 1.07138
# alpha: 1.90448
# beta: 0.11267
# Eb: 1441.06
# Flux: 1.30936e-08 photons/cm^2/s
#
# 4FGL J1312.6-1900:
# Prefactor: 8.07161
# Index: 1.96706
# Scale: 4505.62
# Flux: 1.49512e-09 photons/cm^2/s
#
# 4FGL J1312.7+0050:
# Prefactor: 1.85355
# IndexS: 1.895
# Scale: 1352.83
# ExpfactorS: 8.16922
# Index2: 0.666667
# Flux: 1.30549e-08 photons/cm^2/s
#
# 4FGL J1312.8-0425:
# norm: 0.640398 +/- 0.17986
# alpha: 2.26297
# beta: 0.162864
# Eb: 797.902
# TS value: 18.8326
# Flux: 3.95e-09 +/- 1.10903e-09 photons/cm^2/s
#
# 4FGL J1312.8-2350:
# Prefactor: 6.5334
# Index: 1.86175
# Scale: 3101.01
# Flux: 4.53398e-09 photons/cm^2/s
#
# 4FGL J1313.6+0159:
# Prefactor: 1.45616
# Index: 2.56875
# Scale: 1106.06
# Flux: 4.4619e-09 photons/cm^2/s
#
# 4FGL J1314.7-0901:
# Prefactor: 4.016
# Index: 1.91
# Scale: 5508.15
# Flux: 9.33476e-10 photons/cm^2/s
#
# 4FGL J1315.5+1135:
# norm: 2.18883
# alpha: 1.57539
# beta: 0.169062
# Eb: 3635.64
# Flux: 4.83714e-10 photons/cm^2/s
#
# 4FGL J1315.9-0732:
# norm: 1.25398
# alpha: 1.78353
# beta: 0.13737
# Eb: 2152.43
# Flux: 2.15142e-09 photons/cm^2/s
#
# 4FGL J1317.5-0153:
# norm: 1.32718
# alpha: 2.10889
# beta: 0.438956
# Eb: 1680
# Flux: 1.11475e-09 photons/cm^2/s
#
# 4FGL J1318.1-1740:
# Prefactor: 7.31402
# Index: 2.28816
# Scale: 1749.19
# Flux: 3.96675e-09 photons/cm^2/s
#
# 4FGL J1318.3-1148:
# Prefactor: 8.78442
# Index: 2.01873
# Scale: 3770.32
# Flux: 1.31262e-09 photons/cm^2/s
#
# 4FGL J1318.7-1234:
# norm: 2.62101
# alpha: 2.03263
# beta: 0.0774115
# Eb: 1632.07
# Flux: 5.42257e-09 photons/cm^2/s
#
# 4FGL J1319.5+1404:
# Prefactor: 2.72941
# Index: 2.04368
# Scale: 2979.53
# Flux: 2.69412e-09 photons/cm^2/s
#
# 4FGL J1319.5-0045:
# norm: 1.02301
# alpha: 2.26633
# beta: 0.313498
# Eb: 763.704
# Flux: 4.47967e-09 photons/cm^2/s
#
# 4FGL J1321.3-2641:
# Prefactor: 3.42069
# Index: 2.65116
# Scale: 897.133
# Flux: 6.9699e-09 photons/cm^2/s
#
# 4FGL J1322.2+0842:
# Prefactor: 1.04315
# Index: 2.23383
# Scale: 1683.41
# Flux: 4.64069e-09 photons/cm^2/s
#
# 4FGL J1322.3-0606:
# norm: 8.30494
# alpha: 1.83686
# beta: 0.231402
# Eb: 2188.76
# Flux: 1.15265e-09 photons/cm^2/s
#
# 4FGL J1322.6-0936:
# norm: 6.36935
# alpha: 2.52166
# beta: 0.116135
# Eb: 486.917
# Flux: 1.96335e-08 photons/cm^2/s
#
# 4FGL J1322.6-1418:
# Prefactor: 8.41759
# Index: 1.98187
# Scale: 3742.29
# Flux: 1.12471e-09 photons/cm^2/s
#
# 4FGL J1322.6-1617:
# Prefactor: 2.01968
# Index: 2.07273
# Scale: 2944.48
# Flux: 2.08888e-09 photons/cm^2/s
#
# 4FGL J1322.9+0437:
# norm: 1.70519
# alpha: 1.67789
# beta: 0.389271
# Eb: 3873.44
# Flux: 2.50287e-10 photons/cm^2/s
#
# 4FGL J1323.9+1405:
# norm: 7.63215
# alpha: 1.66943
# beta: 0.142029
# Eb: 2689.18
# Flux: 1.46761e-09 photons/cm^2/s
#
# 4FGL J1324.5-2338:
# Prefactor: 1.05286
# Index: 2.28492
# Scale: 3564.07
# Flux: 2.88404e-09 photons/cm^2/s
#
# 4FGL J1324.6-2525:
# Prefactor: 3.4928
# Index: 2.01678
# Scale: 4887.89
# Flux: 8.76471e-10 photons/cm^2/s
#
# 4FGL J1325.6-0227:
# norm: 1.20505
# alpha: 1.7874
# beta: 0.300829
# Eb: 3994.67
# Flux: 2.51938e-10 photons/cm^2/s
#
# 4FGL J1326.1+1232:
# Prefactor: 6.23277
# Index: 2.00054
# Scale: 4031.78
# Flux: 1.01507e-09 photons/cm^2/s
#
# 4FGL J1326.6+0152:
# Prefactor: 2.93388
# Index: 1.89992
# Scale: 5776.35
# Flux: 7.24858e-10 photons/cm^2/s
#
# 4FGL J1326.7-0503:
# Prefactor: 6.19587
# Index: 1.76166
# Scale: 11743.5
# Flux: 3.59843e-10 photons/cm^2/s
#
# 4FGL J1328.6+1145:
# Prefactor: 2.35715
# Index: 1.74246
# Scale: 8243.74
# Flux: 6.91592e-10 photons/cm^2/s
#
# 4FGL J1329.4-0530:
# norm: 2.50076
# alpha: 2.17902
# beta: 0.351458
# Eb: 1533.07
# Flux: 2.49914e-09 photons/cm^2/s
#
# 4FGL J1329.8-1559:
# Prefactor: 1.6378
# Index: 2.16904
# Scale: 2651.6
# Flux: 1.71561e-09 photons/cm^2/s
#
# 4FGL J1331.2-1325:
# norm: 2.86644
# alpha: 2.47792
# beta: 0.173756
# Eb: 1510.41
# Flux: 7.77737e-09 photons/cm^2/s
#
# 4FGL J1331.6+1711:
# Prefactor: 1.6849
# Index: 2.30852
# Scale: 1456.96
# Flux: 6.25295e-09 photons/cm^2/s
#
# 4FGL J1331.7-0343:
# norm: 1.23355
# alpha: 2.5019
# beta: 0.415873
# Eb: 679.42
# Flux: 4.82768e-09 photons/cm^2/s
#
# 4FGL J1331.7-0647:
# norm: 2.70492
# alpha: 1.72653
# beta: 0.277227
# Eb: 3154.93
# Flux: 4.36751e-10 photons/cm^2/s
#
# 4FGL J1332.0-0509:
# norm: 1.2991
# alpha: 2.50209
# beta: 0.146471
# Eb: 633.043
# Flux: 6.78225e-08 photons/cm^2/s
#
# 4FGL J1332.6-1256:
# norm: 4.59756
# alpha: 2.41924
# beta: 0.110157
# Eb: 982.552
# Flux: 5.9549e-08 photons/cm^2/s
#
# 4FGL J1333.4+1540:
# Prefactor: 2.64546
# Index: 2.25479
# Scale: 2040.24
# Flux: 1.8941e-09 photons/cm^2/s
#
# 4FGL J1336.5-1529:
# Prefactor: 1.98652
# Index: 2.24983
# Scale: 1548.61
# Flux: 7.56517e-09 photons/cm^2/s
#
# 4FGL J1337.6-1257:
# norm: 6.94083
# alpha: 2.26055
# beta: 0.0977624
# Eb: 735.995
# Flux: 4.13391e-08 photons/cm^2/s
#
# 4FGL J1337.9-1956:
# Prefactor: 1.47022
# Index: 2.52454
# Scale: 1216.79
# Flux: 5.30311e-09 photons/cm^2/s
#
# 4FGL J1338.1-0931:
# Prefactor: 2.70807
# Index: 1.87968
# Scale: 5661.53
# Flux: 6.07092e-10 photons/cm^2/s
#
# 4FGL J1338.9+1153:
# Prefactor: 4.63196
# Index: 1.95094
# Scale: 2947.48
# Flux: 3.58537e-09 photons/cm^2/s
#
# 4FGL J1339.0-2400:
# norm: 1.01441
# alpha: 2.24277
# beta: 0.070097
# Eb: 1009.31
# Flux: 1.19696e-08 photons/cm^2/s
#
# 4FGL J1339.1-2620:
# Prefactor: 2.32961
# Index: 2.32427
# Scale: 1405.57
# Flux: 8.19772e-09 photons/cm^2/s
#
# 4FGL J1339.9-0138:
# norm: 4.17855
# alpha: 2.23085
# beta: 0.49184
# Eb: 1134.64
# Flux: 2.27352e-09 photons/cm^2/s
#
# 4FGL J1340.0-1501:
# Prefactor: 3.74807
# Index: 1.92385
# Scale: 5471.6
# Flux: 8.9564e-10 photons/cm^2/s
#
# 4FGL J1340.8-0409:
# Prefactor: 5.63165
# Index: 2.01834
# Scale: 2441.85
# Flux: 3.49811e-09 photons/cm^2/s
#
# 4FGL J1341.8-2053:
# Prefactor: 1.21138
# Index: 2.6786
# Scale: 672.102
# Flux: 1.18975e-08 photons/cm^2/s
#
# 4FGL J1342.0+1043:
# Prefactor: 1.99379
# Index: 2.30303
# Scale: 2245.15
# Flux: 1.98212e-09 photons/cm^2/s
#
# 4FGL J1342.6+0944:
# Prefactor: 4.28124
# Index: 2.02724
# Scale: 2622.62
# Flux: 3.13494e-09 photons/cm^2/s
#
# 4FGL J1342.7+0505:
# Prefactor: 9.03903
# Index: 2.20189
# Scale: 1839.74
# Flux: 4.5865e-09 photons/cm^2/s
#
# 4FGL J1344.2-1723:
# norm: 2.94
# alpha: 2.05319
# beta: 0.129185
# Eb: 900.473
# Flux: 1.89723e-08 photons/cm^2/s
#
# 4FGL J1345.8+0706:
# Prefactor: 1.88423
# Index: 2.46439
# Scale: 750.456
# Flux: 1.85009e-08 photons/cm^2/s
#
# 4FGL J1345.9-2612:
# norm: 3.93009
# alpha: 1.9214
# beta: 0.698277
# Eb: 1414.1
# Flux: 1.58248e-09 photons/cm^2/s
#
# 4FGL J1347.9-0618:
# norm: 3.58012
# alpha: 2.15217
# beta: 0.534937
# Eb: 2199.13
# Flux: 3.48186e-10 photons/cm^2/s
#
# 4FGL J1348.9+0756:
# Prefactor: 1.12574
# Index: 1.97162
# Scale: 4027.96
# Flux: 1.69318e-09 photons/cm^2/s
#
# 4FGL J1349.5-1131:
# norm: 7.15878
# alpha: 2.57393
# beta: 0.127683
# Eb: 1287.99
# Flux: 1.99675e-08 photons/cm^2/s
#
# 4FGL J1351.0+0029:
# Prefactor: 1.48436
# Index: 2.38082
# Scale: 1222.15
# Flux: 4.17015e-09 photons/cm^2/s
#
# 4FGL J1351.3+1115:
# norm: 1.74332
# alpha: 1.75513
# beta: 0.0815449
# Eb: 2233.55
# Flux: 3.73618e-09 photons/cm^2/s
#
# 4FGL J1351.4-1529:
# Prefactor: 6.85651
# Index: 2.15973
# Scale: 2331.14
# Flux: 5.317e-09 photons/cm^2/s
#
# 4FGL J1353.3+1434:
# Prefactor: 1.80783
# Index: 2.19762
# Scale: 1582.65
# Flux: 6.5313e-09 photons/cm^2/s
#
# 4FGL J1354.2+0353:
# Prefactor: 2.27049
# Index: 2.04467
# Scale: 6779.34
# Flux: 1.20658e-09 photons/cm^2/s
#
# 4FGL J1354.3-0206:
# norm: 1.86771
# alpha: 2.55211
# beta: 0.356062
# Eb: 577.305
# Flux: 6.25018e-09 photons/cm^2/s
#
# 4FGL J1354.7+0623:
# Prefactor: 1.16837
# Index: 2.02067
# Scale: 3377.89
# Flux: 1.40536e-09 photons/cm^2/s
#
# 4FGL J1354.8-1041:
# norm: 2.78984
# alpha: 2.34049
# beta: 0.139869
# Eb: 728.385
# Flux: 1.64726e-08 photons/cm^2/s
#
# 4FGL J1356.2-1726:
# norm: 2.17219
# alpha: 1.76553
# beta: 0.405678
# Eb: 3405.61
# Flux: 2.92457e-10 photons/cm^2/s
#
# 4FGL J1356.2-2454:
# Prefactor: 3.64022
# Index: 2.60597
# Scale: 836.278
# Flux: 5.75042e-09 photons/cm^2/s
#
# 4FGL J1356.6+0234:
# norm: 3.6576
# alpha: 2.00654
# beta: 0.527791
# Eb: 1184.3
# Flux: 1.60607e-09 photons/cm^2/s
#
# 4FGL J1357.5+0127:
# norm: 1.94805
# alpha: 2.03708
# beta: 0.0945919
# Eb: 1651.2
# Flux: 3.8838e-09 photons/cm^2/s
#
# 4FGL J1358.0-0050:
# norm: 1.60959
# alpha: 2.44905
# beta: 0.346614
# Eb: 1170.81
# Flux: 1.60185e-09 photons/cm^2/s
#
# 4FGL J1358.9-0703:
# norm: 7.31286
# alpha: 1.98171
# beta: 0.309714
# Eb: 1944.93
# Flux: 8.4977e-10 photons/cm^2/s
#
# 4FGL J1359.1-1152:
# Prefactor: 2.64947
# Index: 1.5718
# Scale: 17837.7
# Flux: 1.5897e-10 photons/cm^2/s
#
# 4FGL J1359.4+0202:
# norm: 1.88454
# alpha: 2.39494
# beta: 0.239413
# Eb: 1278.59
# Flux: 2.66579e-09 photons/cm^2/s
#
# 4FGL J1400.0-2415:
# norm: 3.36915
# alpha: 1.68646
# beta: 0.505359
# Eb: 1661.96
# Flux: 1.7342e-09 photons/cm^2/s
#
# 4FGL J1400.6-1432:
# Prefactor: 1.28313
# IndexS: 1.78314
# Scale: 1075.65
# ExpfactorS: 7.55791
# Index2: 0.666667
# Flux: 6.11405e-09 photons/cm^2/s
#
# 4FGL J1401.2-0915:
# norm: 1.08125
# alpha: 1.90307
# beta: 0.232496
# Eb: 1870.62
# Flux: 1.33923e-09 photons/cm^2/s
#
# 4FGL J1402.5-1827:
# Prefactor: 9.31496
# Index: 2.65661
# Scale: 696.184
# Flux: 9.7608e-09 photons/cm^2/s
#
# 4FGL J1404.8+0402:
# Prefactor: 1.13424
# Index: 1.96856
# Scale: 2394.7
# Flux: 6.07928e-09 photons/cm^2/s
#
# 4FGL J1405.0-1544:
# Prefactor: 2.79308
# Index: 2.50109
# Scale: 943.697
# Flux: 5.10999e-09 photons/cm^2/s
#
# 4FGL J1405.3-0640:
# Prefactor: 3.23652
# Index: 2.15059
# Scale: 2517.2
# Flux: 2.89927e-09 photons/cm^2/s
#
# 4FGL J1405.9-1853:
# Prefactor: 9.14485
# Index: 2.01667
# Scale: 3859.47
# Flux: 1.42461e-09 photons/cm^2/s
#
# 4FGL J1406.4-1654:
# Prefactor: 4.44965
# Index: 2.2148
# Scale: 1987.46
# Flux: 2.75214e-09 photons/cm^2/s
#
# 4FGL J1406.5-0054:
# Prefactor: 2.5501
# Index: 2.62072
# Scale: 881.541
# Flux: 4.72902e-09 photons/cm^2/s
#
# 4FGL J1407.4-0820:
# Prefactor: 4.39469
# Index: 2.8354
# Scale: 867.884
# Flux: 1.09904e-08 photons/cm^2/s
#
# 4FGL J1408.9-0751:
# norm: 8.27411
# alpha: 2.13997
# beta: 0.119694
# Eb: 937.46
# Flux: 6.5056e-08 photons/cm^2/s
#
# 4FGL J1410.1+0202:
# norm: 8.78861
# alpha: 2.20454
# beta: 0.0963684
# Eb: 940.467
# Flux: 7.98503e-09 photons/cm^2/s
#
# 4FGL J1411.5-0723:
# Prefactor: 4.3679
# Index: 1.85475
# Scale: 6619.81
# Flux: 1.21771e-09 photons/cm^2/s
#
# 4FGL J1414.5+0826:
# Prefactor: 1.52872
# Index: 2.86459
# Scale: 451.422
# Flux: 6.16288e-09 photons/cm^2/s
#
# 4FGL J1415.9-1002:
# norm: 1.46679
# alpha: 2.46379
# beta: 0.396928
# Eb: 571.763
# Flux: 4.22466e-09 photons/cm^2/s
#
# 4FGL J1415.9-1504:
# Prefactor: 4.39779
# Index: 2.31194
# Scale: 2110.83
# Flux: 3.87107e-09 photons/cm^2/s
#
# 4FGL J1418.4-0233:
# norm: 7.71434
# alpha: 1.65181
# beta: 0.0766058
# Eb: 1917.54
# Flux: 1.15704e-08 photons/cm^2/s
#
# 4FGL J1419.3+0444:
# Prefactor: 1.50656
# Index: 1.93637
# Scale: 3957.33
# Flux: 1.9943e-09 photons/cm^2/s
#
# 4FGL J1419.4-0838:
# norm: 6.70606
# alpha: 2.11566
# beta: 0.098623
# Eb: 717.423
# Flux: 3.23868e-08 photons/cm^2/s
#
# 4FGL J1420.3+0612:
# Prefactor: 2.01273
# Index: 2.49242
# Scale: 1062.25
# Flux: 4.87836e-09 photons/cm^2/s
#
# 4FGL J1420.3-0438:
# Prefactor: 2.64708
# Index: 2.41963
# Scale: 2183.97
# Flux: 3.24795e-09 photons/cm^2/s
#
# 4FGL J1421.1-1120:
# norm: 6.21957
# alpha: 2.24617
# beta: 0.121483
# Eb: 990.772
# Flux: 6.21049e-09 photons/cm^2/s
#
# 4FGL J1421.4-1655:
# Prefactor: 2.38799
# Index: 1.80104
# Scale: 7406.57
# Flux: 6.93961e-10 photons/cm^2/s
#
# 4FGL J1424.1-1750:
# Prefactor: 1.26265
# Index: 1.94691
# Scale: 4350.86
# Flux: 2.0665e-09 photons/cm^2/s
#
# 4FGL J1424.2+0433:
# norm: 5.88936
# alpha: 1.9617
# beta: 0.131018
# Eb: 1272.9
# Flux: 6.04932e-09 photons/cm^2/s
#
# 4FGL J1425.4-0119:
# norm: 4.96631
# alpha: 1.69087
# beta: 0.334624
# Eb: 5863.22
# Flux: 1.26622e-10 photons/cm^2/s
#
# 4FGL J1428.7-1017:
# norm: 2.81618
# alpha: 1.36715
# beta: 0.259393
# Eb: 9395.22
# Flux: 1.04514e-10 photons/cm^2/s
#
# 4FGL J1429.8-0739:
# norm: 1.73122
# alpha: 2.10929
# beta: 0.5101
# Eb: 1532.9
# Flux: 1.14514e-09 photons/cm^2/s
#
# gll_iem_v07:
# Prefactor: 0.918111 +/- 0.035748
# Index: -0.0918443 +/- 0.00685103
# Scale: 100
# Flux: 0.000435555 +/- 1.58044e-05 photons/cm^2/s
#
# iso_P8R3_SOURCE_V3_v1:
# Normalization: 1.48579 +/- 0.0527117
# Flux: 0.00018255 +/- 6.47521e-06 photons/cm^2/s
# WARNING: Fit may be bad in range [100, 251.124] (MeV)
# WARNING: Fit may be bad in range [316.126, 1583.67] (MeV)
# WARNING: Fit may be bad in range [1993.6, 2509.63] (MeV)
# WARNING: Fit may be bad in range [39744.4, 50032.1] (MeV)
# Total number of observed counts: 207751
# Total number of model events: 201829
#
# -log(Likelihood): 76574.86159
#
# Writing fitted model to ./data/3C279_binned_output.xml
# Elapsed CPU time: 22.597773

# %% [markdown]
# Most of the entries prompted for are fairly obvious. In addition to the various XML and FITS files, the user is prompted for a choice of IRFs, the type of statistic to use, and the optimizer.

# %% [markdown]
# The statistics available are:
# * **UNBINNED**: This should be used for short timescale or low source count data. If this option is chosen then parameters for the spacecraft file, event file, and exposure file must be given. See explanation in: [Likelihood Tutorial]()
#
# * **BINNED**: This is a standard binned analysis as described in this tutorial. This analysis is used for long timescale or high-density data (such as in the Galactic plane) which can cause memory errors in the unbinned analysis. If this option is chosen then parameters for the source map file, livetime file, and exposure file must be given.

# %% [markdown]
# There are five optimizers from which to choose: `DRMNGB`, `DRMNFB`, `NEWMINUIT`, `MINUIT` and `LBFGS`. Generally speaking, the faster way to find the parameter estimates is to use `DRMNGB` (or `DRMNFB`) to find initial values and then use `MINUIT` (or `NEWMINUIT`) to find more accurate results. If you have trouble achieving convergence at first, you can loosen your tolerance by setting the hidden parameter `ftol` on the command line. (The default value for `ftol` is `0.001`.)

# %% [markdown]
# Analyzing a 2-year dataset will take some time. The required running time will be higher if your source is in the Galactic plane. Here is some output from our fit, where 4FGL J1229.0+0202 and 4FGL J1256.1-0547 corresponds to 3C 273 and 3C 279, respectively:

# %% [markdown]
# Since we selected `plot=yes` in the command line, a plot of the fitted data appears.
#
# <img src="https://fermi.gsfc.nasa.gov/ssc/data/analysis/scitools/images/BinnedLikelihood/3C279_binned_spectral_fit.png">

# %% [markdown]
# In the first plot, the counts/MeV vs MeV are plotted. The points are the data, and the lines are the models. Error bars on the points represent sqrt(Nobs) in that band, where Nobs is the observed number of counts. The black line is the sum of the models for all sources.
#
# The colored lines follow the sources as follows:
# * Black - summed model
# * Red - first source (see below)
# * Green - second source
# * Blue - third source
# * Magenta - fourth source
# * Cyan - the fifth source
#
# If you have more sources, the colors are reused in the same order. In our case we have, in order of decreasing value on the y-axis: summed model (black), the extragalactic background (black), the galactic background (cyan), 3C 273 (red), and 3C 279 (black).
#
# The second plot gives the residuals between your model and the data. Error bars here represent (sqrt(Nopbs))/Npred, where Npred is the predicted number of counts in each band based on the fitted model.

# %% [markdown]
# To assess the quality of the fit, look first for the words at the top of the output `<Optimizer> did successfully converge.` Successful convergence is a minimum requirement for a good fit.
#
# Next, look at the energy ranges that are generating warnings of bad fits. If any of these ranges affect your source of interest, you may need to revise the source model and refit. You can also look at the residuals on the plot (bottom panel). If the residuals indicate a poor fit overall (e.g., the points trending all low or all high) you should consider changing your model file, perhaps by using a different source model definition, and refit the data.
#
# If the fits and spectral shapes are good, but could be improved, you may wish to simply update your model file to hold some of the spectral parameters fixed. For example, by fixing the spectral model for 3C 273, you may get a better quality fit for 3C 279. Close the plot and you will be asked if you wish to refit the data.

# %% [markdown]
# ```
# Refit? [y] n
# Elapsed CPU time: 1571.805872
# ```

# %% [markdown]
# Here, hitting `return` will instruct the application to fit again. We are happy with the result, so we type `n` and end the fit.

# %% [markdown]
# ### Results
#
# When it completes, **gtlike** generates a standard output XML file. If you re-run the tool in the same directory, these files will be overwritten by default. Use the `clobber=no` option on the command line to keep from overwriting the output files.
#
# Unfortunately, the fit details and the value for the `-log(likelihood)` are not recorded in the automatic output files.
#
# You should consider logging the output to a text file for your records by using `> fit_data.txt` (or something similar) with your **gtlike** command.
#
# Be aware, however, that this will make it impossible to request a refit when the likelihood process completes.

# %% [markdown]
# In this example, we used the `sfile` parameter to request that the model results be written to an output XML file. This file contains the source model results that were written to `results.dat` at the completion of the fit.
#
# >    **Note**: If you have specified an output XML model file and you wish to modify your model while waiting at the `Refit? [y]` prompt, you will need to copy the results of the output model file to your input model before making those modifications.

# %% [markdown]
# The results of the likelihood analysis have to be scaled by the quantity called "scale" in the XML model in order to obtain the total photon flux (photons cm-2 s-1) of the source. You must refer to the model formula of your source for the interpretation of each parameter. In our example the 'prefactor' of our power law model of the first fitted source (4FGLJ1119.9-1007) has to be scaled by the factor 'scale'=10-14. For example the total flux of 4FGLJ1159.5-0723 is the integral between 100 MeV and 500000 MeV of:

# %% [markdown]
# $Prefactor \cdot scale \cdot (E /100)^{index}=(8.26x10-14) \cdot (E/100)^{-2.2706}$

# %% [markdown]
# Errors reported with each value in the `results.dat` file are 1Ïƒ estimates (based on inverse-Hessian at the optimum of the log-likelihood surface).

# %% [markdown]
# ### Other Useful Hidden Parameters
#
# If you are scripting and wish to generate multiple output files without overwriting, the `results` and `specfile` parameters allow you to specify output filenames for the `results.dat` and `counts_spectra.fits` files respectively.
#
# If you do not specify a source model output file with the `sfile` parameter, then the input model file will be overwritten with the latest fit. This is convenient as it allows the user to edit that file while the application is waiting at the `Refit? [y]` prompt so that parameters can be adjusted and set free or fixed. This would be similar to the use of the "newpar", "freeze", and "thaw" commands in [XSPEC](http://heasarc.gsfc.nasa.gov/docs/xanadu/xspec/index.html).

# %% [markdown]
# # 10. Create a model map
#
# For comparison to the counts map data, we create a model map of the region based on the fit parameters.
#
# This map is essentially an infinite-statistics counts map of the region-of-interest based on our model fit.
#
# The [gtmodel](https://fermi.gsfc.nasa.gov/ssc/data/analysis/scitools/help/gtmodel.txt) application reads in the fitted model, applies the proper scaling to the source maps, and adds them together to get the final map.

# %%
# %%bash
# gtmodel
#     ./data/3C279_binned_srcmaps.fits
#     ./data/3C279_binned_output.xml
#     ./data/3C279_model_map.fits
#     CALDB
#     ./data/3C279_binned_ltcube.fits
#     ./data/3C279_binned_allsky_expcube.fits
# Out:
# Source maps (or counts map) file[./data/3C279_binned_srcmaps.fits] Source model file[./data/3C279_binned_output.xml] Output file[./data/3C279_model_map.fits] Response functions[CALDB] Exposure cube[./data/3C279_binned_ltcube.fits] Binned exposure map[./data/3C279_binned_allsky_expcube.fits]

# %% [markdown]
# To understand how well the fit matches the data, we want to compare the [model map](https://fermi.gsfc.nasa.gov/ssc/data/analysis/scitools/data/BinnedLikelihood/3C279_model_map.fits) just created with the counts map over the same field of view. First we have to create the [new counts map](https://fermi.gsfc.nasa.gov/ssc/data/analysis/scitools/data/BinnedLikelihood/3C279_binned_cmap_small.fits) that matches in size the model map (the one generated in encircles the ROI, while the model map is completely inscribed within the ROI): We will use again the [gtbin](https://fermi.gsfc.nasa.gov/ssc/data/analysis/scitools/help/gtbin.txt) tool with the option `CMAP` as shown below:

# %%
# %%bash
# gtbin
#     CMAP
#     ./data/3C279_binned_gti.fits
#     ./data/3C279_binned_cmap_small.fits
#     NONE
#     100
#     100
#     0.2
#     CEL
#     193.98
#     -5.82
#     0.0
#     STG
# Out:
# This is gtbin version HEAD
# Type of output file (CCUBE|CMAP|LC|PHA1|PHA2|HEALPIX) [CCUBE] Event data file name[./data/3C279_binned_gti.fits] Output file name[./data/3C279_binned_ccube.fits] Spacecraft data file name[NONE] Size of the X axis in pixels[100] Size of the Y axis in pixels[100] Image scale (in degrees/pixel)[0.2] Coordinate system (CEL - celestial, GAL -galactic) (CEL|GAL) [CEL] First coordinate of image center in degrees (RA or galactic l)[193.98] Second coordinate of image center in degrees (DEC or galactic b)[-5.82] Rotation angle of image axis, in degrees[0] Projection method e.g. AIT|ARC|CAR|GLS|MER|NCP|SIN|STG|TAN:[AIT]
# gtbin: WARNING: No spacecraft file: EXPOSURE keyword will be set equal to ontime.

# %% [markdown]
# Here we've plotted the model map next to the the energy-summed counts map for the data.
#
# <img src='https://fermi.gsfc.nasa.gov/ssc/data/analysis/scitools/images/BinnedLikelihood/3C279_binned_map_comparison.png'>

# %% [markdown]
# Finally we want to create the [residual map](https://fermi.gsfc.nasa.gov/ssc/data/analysis/scitools/data/BinnedLikelihood/3C279_residual.fits) by using the FTOOL **farith** to check if we can improve the model. For this section you need to install [FTOOLS](https://heasarc.gsfc.nasa.gov/ftools/) separately. A possible sequence is farith
#     ./data/3C279_binned_cmap_small.fits
#     ./data/3C279_model_map.fits
#     ./data/3C279_residual.fits
#     SUB

# %% [markdown]
# The residual map is shown below. As you can see, the binning we chose probably used pixels that were too large.
#
# The primary sources, 3C 273 and 3C 279, have some positive pixels next to some negative ones. This effect could be lessened by either using a smaller pixel size or by offsetting the central position slightly from the position of the blazar (or both).
#
# If your residual map contains bright sources, the next step would be to iterate the analysis with the additional sources included in the XML model file.
#
# <img src='https://fermi.gsfc.nasa.gov/ssc/data/analysis/scitools/images/BinnedLikelihood/3C279_binned_residuals.png'>
