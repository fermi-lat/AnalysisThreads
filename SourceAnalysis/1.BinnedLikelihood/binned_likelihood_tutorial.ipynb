# %% [markdown]
# # Binned Likelihood Tutorial
#
# The detection, flux determination, and spectral modeling of Fermi LAT sources is accomplished by a maximum likelihood optimization technique as described in the [Likelihood Overview](https://fermi.gsfc.nasa.gov/ssc/data/analysis/likelihood/likelihood_overview.html) (see also, e.g., [Abdo, A. A. et al. 2009, ApJS, 183, 46](http://adsabs.harvard.edu/abs/2009ApJS..183...46A)).
#
# To illustrate how to use the Likelihood software, this tutorial gives a step-by-step description for performing a binned likelihood analysis.

# %% [markdown]
# ## Binned vs Unbinned Likelihood
#
# Binned likelihood analysis is the preferred method for most types of LAT analysis (see [Likelihood Overview](https://fermi.gsfc.nasa.gov/ssc/data/analysis/likelihood/likelihood_overview.html)).
#
# However, when analyzing data over short time periods (with few events), it is better to use the **unbinned** analysis.
#
# To perform an unbinned likelihood analysis, see the [Unbinned Likelihood](https://github.com/fermi-lat/AnalysisThreads/blob/master/SourceAnalysis/2.UnbinnedLikelihood/likelihood_tutorial.ipynb) tutorial.
#
# **Additional references**:
# * [SciTools References](https://fermi.gsfc.nasa.gov/ssc/data/analysis/scitools/references.html)
# * Descriptions of available [Spectral and Spatial Models](https://fermi.gsfc.nasa.gov/ssc/data/analysis/scitools/source_models.html)
# * Examples of [XML Model Definitions for Likelihood](https://fermi.gsfc.nasa.gov/ssc/data/analysis/scitools/xml_model_defs.html#xmlModelDefinitions):
#     * [Power Law](https://fermi.gsfc.nasa.gov/ssc/data/analysis/scitools/xml_model_defs.html#powerlaw)
#     * [Broken Power Law](https://fermi.gsfc.nasa.gov/ssc/data/analysis/scitools/xml_model_defs.html#brokenPowerLaw)
#     * [Broken Power Law 2](https://fermi.gsfc.nasa.gov/ssc/data/analysis/scitools/xml_model_defs.html#powerLaw2)
#     * [Log Parabola](https://fermi.gsfc.nasa.gov/ssc/data/analysis/scitools/xml_model_defs.html#logParabola)
#     * [Exponential Cutoff](https://fermi.gsfc.nasa.gov/ssc/data/analysis/scitools/xml_model_defs.html#expCutoff)
#     * [BPL Exponential Cutoff](https://fermi.gsfc.nasa.gov/ssc/data/analysis/scitools/xml_model_defs.html#bplExpCutoff)
#     * [Gaussian](https://fermi.gsfc.nasa.gov/ssc/data/analysis/scitools/xml_model_defs.html#gaussian)
#     * [Constant Value](https://fermi.gsfc.nasa.gov/ssc/data/analysis/scitools/xml_model_defs.html#constantValue)
#     * [File Function](https://fermi.gsfc.nasa.gov/ssc/data/analysis/scitools/xml_model_defs.html#fileFunction)
#     * [Band Function](https://fermi.gsfc.nasa.gov/ssc/data/analysis/scitools/xml_model_defs.html#bandFunction)
#     * [PL Super Exponential Cutoff](https://fermi.gsfc.nasa.gov/ssc/data/analysis/scitools/xml_model_defs.html#plSuperExpCutoff)

# %% [markdown]
# # Prerequisites
#
# You will need an **event** data file, a **spacecraft** data file (also referred to as the "pointing and livetime history" file), and the current **background models** (available for [download](https://fermi.gsfc.nasa.gov/ssc/data/access/lat/BackgroundModels.html)). They are also found in code cells below.
#
# You may choose to select your own data files, or to use the files provided within this tutorial.
#
# Custom data sets may be retrieved from the [Lat Data Server](http://fermi.gsfc.nasa.gov/cgi-bin/ssc/LAT/LATDataQuery.cgi).

# %% [markdown]
# # Outline
#
# 1. **Make Subselections from the Event Data**
#
#     Since there is computational overhead for each event associated with each diffuse component, it is useful to filter out any events that are not within the extraction region used for the analysis.
#
#
# 2. **Make Counts Maps from the Event Files**
#
#     By making simple FITS images, we can inspect our data and pick out obvious sources.
#
#
# 3. **Download the latest diffuse models**
#
#     The recommended models for a normal point source analysis are `gll_iem_v07.fits` (a very large file) and `iso_P8R3_SOURCE_V3_v1.txt`. All of the background models along with a description of the models are available [here](https://fermi.gsfc.nasa.gov/ssc/data/access/lat/BackgroundModels.html).
#
#
# 4. **Create a Source Model XML File**
#
#     The source model XML file contains the various sources and their model parameters to be fit using the **gtlike** tool.
#
#
# 5. **Create a 3D Counts Cube**
#
#     The binned counts cube is used to reduce computation requirements in regions with large numbers of events.
#
#
# 6. **Compute Livetimes**
#
#     Precomputing the livetime for the dataset speeds up the exposure calculation.
#
#
# 7. **Compute Exposure Cube**
#
#     This accounts for exposure as a function of energy, based on the cuts made. The exposure map must be recomputed if any change is made to the data selection or binning.
#
#
# 8. **Compute Source Maps**
#
#     Here the exposure calculation is applied to each of the sources described in the model.
#
#
# 9. **Perform the Likelihood Fit**
#
#     Fitting the data to the model provides flux, errors, spectral indices, and other information.
#
#
# 10. **Create a Model Map**
#
#     This can be compared to the counts map to verify the quality of the fit and to make a residual map.

# %% [markdown]
# # 1. Make subselections from the event data
#
# For this case we will use two years of LAT Pass 8 data.
#
# >**NOTE**: The ROI used by the binned likelihood analysis is defined by the 3D counts map boundary. The region selection used in the data extraction step, which is conical, must fully contain the 3D counts map spatial boundary, which is square.
#
# Selection of data:
#
#     Search Center (RA, DEC) =(193.98, -5.82)
#     Radius = 15 degrees
#     Start Time (MET) = 239557417 seconds (2008-08-04 T15:43:37)
#     Stop Time (MET) = 302572802 seconds (2010-08-04 T00:00:00)
#     Minimum Energy = 100 MeV
#     Maximum Energy = 500000 MeV
#
# This two-year dataset generates numerous data files. We provide the user with the original event data files and the accompanying spacecraft file:
#
# * L181126210218F4F0ED2738_PH00.fits (5.0 MB)
# * L181126210218F4F0ED2738_PH01.fits (10.5 MB)
# * L181126210218F4F0ED2738_PH02.fits (6.5 MB)
# * L181126210218F4F0ED2738_PH03.fits (9.2 MB)
# * L181126210218F4F0ED2738_PH04.fits (7.4 MB)
# * L181126210218F4F0ED2738_PH05.fits (6.2 MB)
# * L181126210218F4F0ED2738_PH06.fits (4.5 MB)
# * L181126210218F4F0ED2738_SC00.fits (256 MB spacecraft file)

# %%
# !wget https://fermi.gsfc.nasa.gov/ssc/data/analysis/scitools/data/BinnedLikelihood/L181126210218F4F0ED2738_PH00.fits
# !wget https://fermi.gsfc.nasa.gov/ssc/data/analysis/scitools/data/BinnedLikelihood/L181126210218F4F0ED2738_PH01.fits
# !wget https://fermi.gsfc.nasa.gov/ssc/data/analysis/scitools/data/BinnedLikelihood/L181126210218F4F0ED2738_PH02.fits
# !wget https://fermi.gsfc.nasa.gov/ssc/data/analysis/scitools/data/BinnedLikelihood/L181126210218F4F0ED2738_PH03.fits
# !wget https://fermi.gsfc.nasa.gov/ssc/data/analysis/scitools/data/BinnedLikelihood/L181126210218F4F0ED2738_PH04.fits
# !wget https://fermi.gsfc.nasa.gov/ssc/data/analysis/scitools/data/BinnedLikelihood/L181126210218F4F0ED2738_PH05.fits
# !wget https://fermi.gsfc.nasa.gov/ssc/data/analysis/scitools/data/BinnedLikelihood/L181126210218F4F0ED2738_PH06.fits
# !wget https://fermi.gsfc.nasa.gov/ssc/data/analysis/scitools/data/BinnedLikelihood/L181126210218F4F0ED2738_SC00.fits
# Out:
# --2026-01-22 11:53:25--  https://fermi.gsfc.nasa.gov/ssc/data/analysis/scitools/data/BinnedLikelihood/L181126210218F4F0ED2738_PH00.fits
# Resolving fermi.gsfc.nasa.gov (fermi.gsfc.nasa.gov)... 129.164.179.26
# Connecting to fermi.gsfc.nasa.gov (fermi.gsfc.nasa.gov)|129.164.179.26|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5189760 (4.9M) [application/fits]
# Saving to: ‘L181126210218F4F0ED2738_PH00.fits’
#
# L181126210218F4F0ED 100%[===================>]   4.95M  2.03MB/s    in 2.4s
#
# 2026-01-22 11:53:27 (2.03 MB/s) - ‘L181126210218F4F0ED2738_PH00.fits’ saved [5189760/5189760]
#
# --2026-01-22 11:53:28--  https://fermi.gsfc.nasa.gov/ssc/data/analysis/scitools/data/BinnedLikelihood/L181126210218F4F0ED2738_PH01.fits
# Resolving fermi.gsfc.nasa.gov (fermi.gsfc.nasa.gov)... 129.164.179.26
# Connecting to fermi.gsfc.nasa.gov (fermi.gsfc.nasa.gov)|129.164.179.26|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 10995840 (10M) [application/fits]
# Saving to: ‘L181126210218F4F0ED2738_PH01.fits’
#
# L181126210218F4F0ED 100%[===================>]  10.49M  2.14MB/s    in 5.8s
#
# 2026-01-22 11:53:34 (1.79 MB/s) - ‘L181126210218F4F0ED2738_PH01.fits’ saved [10995840/10995840]
#
# --2026-01-22 11:53:34--  https://fermi.gsfc.nasa.gov/ssc/data/analysis/scitools/data/BinnedLikelihood/L181126210218F4F0ED2738_PH02.fits
# Resolving fermi.gsfc.nasa.gov (fermi.gsfc.nasa.gov)... 129.164.179.26
# Connecting to fermi.gsfc.nasa.gov (fermi.gsfc.nasa.gov)|129.164.179.26|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6799680 (6.5M) [application/fits]
# Saving to: ‘L181126210218F4F0ED2738_PH02.fits’
#
# L181126210218F4F0ED 100%[===================>]   6.48M  1.93MB/s    in 3.4s
#
# 2026-01-22 11:53:38 (1.90 MB/s) - ‘L181126210218F4F0ED2738_PH02.fits’ saved [6799680/6799680]
#
# --2026-01-22 11:53:38--  https://fermi.gsfc.nasa.gov/ssc/data/analysis/scitools/data/BinnedLikelihood/L181126210218F4F0ED2738_PH03.fits
# Resolving fermi.gsfc.nasa.gov (fermi.gsfc.nasa.gov)... 129.164.179.26
# Connecting to fermi.gsfc.nasa.gov (fermi.gsfc.nasa.gov)|129.164.179.26|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 9676800 (9.2M) [application/fits]
# Saving to: ‘L181126210218F4F0ED2738_PH03.fits’
#
# L181126210218F4F0ED 100%[===================>]   9.23M  2.23MB/s    in 4.6s
#
# 2026-01-22 11:53:43 (2.02 MB/s) - ‘L181126210218F4F0ED2738_PH03.fits’ saved [9676800/9676800]
#
# --2026-01-22 11:53:43--  https://fermi.gsfc.nasa.gov/ssc/data/analysis/scitools/data/BinnedLikelihood/L181126210218F4F0ED2738_PH04.fits
# Resolving fermi.gsfc.nasa.gov (fermi.gsfc.nasa.gov)... 129.164.179.26
# Connecting to fermi.gsfc.nasa.gov (fermi.gsfc.nasa.gov)|129.164.179.26|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 7793280 (7.4M) [application/fits]
# Saving to: ‘L181126210218F4F0ED2738_PH04.fits’
#
# L181126210218F4F0ED 100%[===================>]   7.43M  2.04MB/s    in 3.8s
#
# 2026-01-22 11:53:47 (1.95 MB/s) - ‘L181126210218F4F0ED2738_PH04.fits’ saved [7793280/7793280]
#
# --2026-01-22 11:53:47--  https://fermi.gsfc.nasa.gov/ssc/data/analysis/scitools/data/BinnedLikelihood/L181126210218F4F0ED2738_PH05.fits
# Resolving fermi.gsfc.nasa.gov (fermi.gsfc.nasa.gov)... 129.164.179.26
# Connecting to fermi.gsfc.nasa.gov (fermi.gsfc.nasa.gov)|129.164.179.26|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6497280 (6.2M) [application/fits]
# Saving to: ‘L181126210218F4F0ED2738_PH05.fits’
#
# L181126210218F4F0ED 100%[===================>]   6.20M  2.01MB/s    in 3.1s
#
# 2026-01-22 11:53:50 (2.01 MB/s) - ‘L181126210218F4F0ED2738_PH05.fits’ saved [6497280/6497280]
#
# --2026-01-22 11:53:51--  https://fermi.gsfc.nasa.gov/ssc/data/analysis/scitools/data/BinnedLikelihood/L181126210218F4F0ED2738_PH06.fits
# Resolving fermi.gsfc.nasa.gov (fermi.gsfc.nasa.gov)... 129.164.179.26
# Connecting to fermi.gsfc.nasa.gov (fermi.gsfc.nasa.gov)|129.164.179.26|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4746240 (4.5M) [application/fits]
# Saving to: ‘L181126210218F4F0ED2738_PH06.fits’
#
# L181126210218F4F0ED 100%[===================>]   4.53M  2.10MB/s    in 2.2s
#
# 2026-01-22 11:53:53 (2.10 MB/s) - ‘L181126210218F4F0ED2738_PH06.fits’ saved [4746240/4746240]
#
# --2026-01-22 11:53:53--  https://fermi.gsfc.nasa.gov/ssc/data/analysis/scitools/data/BinnedLikelihood/L181126210218F4F0ED2738_SC00.fits
# Resolving fermi.gsfc.nasa.gov (fermi.gsfc.nasa.gov)... 129.164.179.26
# Connecting to fermi.gsfc.nasa.gov (fermi.gsfc.nasa.gov)|129.164.179.26|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 268153920 (256M) [application/fits]
# Saving to: ‘L181126210218F4F0ED2738_SC00.fits’
#
# L181126210218F4F0ED 100%[===================>] 255.73M  2.19MB/s    in 1m 55s
#
# 2026-01-22 11:55:49 (2.21 MB/s) - ‘L181126210218F4F0ED2738_SC00.fits’ saved [268153920/268153920]

# %%
# !mkdir ./data
# !mv *.fits ./data
# !ls ./data
# Out:
# mkdir: ./data: File exists
# 3C279_binned_allsky_expcube.fits  binned_events.txt
# 3C279_binned_ccube.fits           counts_spectra.fits
# 3C279_binned_cmap_small.fits      gll_psc_v32.xml
# 3C279_binned_cmap.fits            L181126210218F4F0ED2738_PH00.fits
# 3C279_binned_expcube.fits         L181126210218F4F0ED2738_PH01.fits
# 3C279_binned_expcubewithcmap.fits L181126210218F4F0ED2738_PH02.fits
# 3C279_binned_exptest.fits         L181126210218F4F0ED2738_PH03.fits
# 3C279_binned_filtered.fits        L181126210218F4F0ED2738_PH04.fits
# 3C279_binned_gti.fits             L181126210218F4F0ED2738_PH05.fits
# 3C279_binned_ltcube.fits          L181126210218F4F0ED2738_PH06.fits
# 3C279_binned_output.xml           L181126210218F4F0ED2738_SC00.fits
# 3C279_binned_srcmaps.fits         ROI_3C279_input_model.reg
# 3C279_model_map.fits              test.fits

# %% [markdown]
# In order to combine the two events files for your analysis, you must first generate a text file listing the events files to be included.
#
# If you do not wish to download all the individual files, you can skip to the next step and retrieve the combined, filtered event file. However, you will need the spacecraft file to complete the analysis, so you should retrieve that now.
#
# To generate the file list, type:

# %%
# !ls ./data/*_PH* > ./data/binned_events.txt

# %% [markdown]
# When analyzing point sources, it is recommended that you include events with high probability of being photons. To do this, you should use **gtselect** to cut on the event class, keeping only the SOURCE class events (event class 128).
#
# In addition, since we do not wish to cut on any of the three event types (conversion type, PSF, or EDISP), we will use `evtype=3` (which corresponds to standard analysis in Pass 7). Note that `INDEF` is the default for evtype in gtselect.

# %% [markdown]
# ```bash
# gtselect evclass=128 evtype=3
# ```

# %% [markdown]
# Be aware that `evclass` and `evtype` are hidden parameters. So, to use them, you must type them on the command line.
#
# The text file you made (`binned_events.txt`) will be used in place of the input fits filename when running gtselect. The syntax requires that you use an @ before the filename to indicate that this is a text file input rather than a fits file.
#
# We perform a selection to the data we want to analyze. For this example, we consider the source class photons within our 15 degree region of interest (ROI) centered on the blazar 3C 279. For some of the selections that we made with the data server and don't want to modify, we can use "INDEF" to instruct the tool to read those values from the data file header. Here, we are only filtering on event class (not on event type) and applying a zenith cut, so many of the parameters are designated as "INDEF".

# %% [markdown]
# We apply the **gtselect** tool to the data file as follows:

# %%
# %%bash
# gtselect evclass=128 evtype=3
#     @./data/binned_events.txt
#     ./data/3C279_binned_filtered.fits
#     INDEF
#     INDEF
#     INDEF
#     INDEF
#     INDEF
#     100
#     500000
#     90
# Out:
# Input FT1 file[@./data/binned_events.txt] Output FT1 file[./data/3C279_binned_filtered.fits] RA for new search center (degrees) (0:360) [INDEF] Dec for new search center (degrees) (-90:90) [INDEF] radius of new search region (degrees) (0:180) [INDEF] start time (MET in s) (0:) [INDEF] end time (MET in s) (0:) [INDEF] lower energy limit (MeV) (0:) [100] upper energy limit (MeV) (0:) [500000] maximum zenith angle value (degrees) (0:180) [90] Done.

# %% [markdown]
# In the last step we also selected the energy range and the maximum zenith angle value (90 degrees) as recommended by the LAT instrument team.
#
# The Earth's limb is a strong source of background gamma rays and we can filter them out with a zenith-angle cut. The use of "zmax" in calculating the exposure allows for a more selective method than just using the ROI cuts in controlling the Earth limb contamination. The filtered data from the above steps are provided [here](https://fermi.gsfc.nasa.gov/ssc/data/analysis/scitools/data/BinnedLikelihood/3C279_binned_filtered.fits).

# %% [markdown]
# After the data selection is made, we need to select the good time intervals in which the satellite was working in standard data taking mode and the data quality was good. For this task we use **gtmktime** to select GTIs by filtering on information provided in the spacecraft file. The current **gtmktime** filter expression recommended by the LAT team is:

# %% [markdown]
# ```
# (DATA_QUAL>0)&&(LAT_CONFIG==1)
# ```

# %% [markdown]
# This excludes time periods when some spacecraft event has affected the quality of the data; it ensures the LAT instrument was in normal science data-taking mode.
#
# Here is an example of running **gtmktime** for our analysis of the region surrounding 3C 279.

# %%
# %%bash
# gtmktime
#     @./data/L181126210218F4F0ED2738_SC00.fits
#     (DATA_QUAL>0)&&(LAT_CONFIG==1)
#     no
#     ./data/3C279_binned_filtered.fits
#     ./data/3C279_binned_gti.fits
# Out:
# Spacecraft data file[@./data/L181126210218F4F0ED2738_SC00.fits] Filter expression[(DATA_QUAL>0)&&(LAT_CONFIG==1)] Apply ROI-based zenith angle cut[no] Event data file[./data/3C279_binned_filtered.fits] Output event file name[./data/3C279_binned_gti.fits]

# %% [markdown]
# The data file with all the cuts described above is provided in this [link](https://fermi.gsfc.nasa.gov/ssc/data/analysis/scitools/data/BinnedLikelihood/3C279_binned_gti.fits). A more detailed discussion of data selection can be found in the [Data Preparation](https://github.com/fermi-lat/AnalysisThreads/blob/master/DataSelection/2.DataPreparation/data_preparation.ipynb) analysis thread.
#
# To view the DSS keywords in a given extension of a data file, use the **gtvcut** tool and review the data cuts on the EVENTS extension. This provides a listing of the keywords reflecting each cut applied to the data file and their values, including the entire list of GTIs. (Use the option `suppress_gtis=no` to view the entire list.)

# %% [markdown]
# With **gtvcut** you can see the event class and event type, the location and radius of the data selection, as well as the energy range in MeV, the zenith angle cut, and the fact that the time cuts to be used in the exposure calculation are defined by the GTI table.
#
# Various Fermitools will be unable to run if you have multiple copies of a particular DSS keyword. This can happen if the position used in extracting the data from the data server is different than the position used with **gtselect**. It is wise to review the keywords for duplicates before proceeding. If you do have keyword duplication, it is advisable to regenerate the data file with consistent cuts.

# %% [markdown]
# # 2. Make a counts map from the event data
#
# Next, we create a counts map of the ROI, summed over photon energies, in order to identify candidate sources and to ensure that the field looks sensible as a simple sanity check. For creating the counts map, we will use the [gtbin](https://fermi.gsfc.nasa.gov/ssc/data/analysis/scitools/help/gtbin.txt) tool with the option "CMAP" (no spacecraft file is necessary for this step).
#
# Then we will view the output file, as shown below:

# %%
# %%bash
# gtbin
#     CMAP
#     ./data/3C279_binned_gti.fits
#     ./data/3C279_binned_cmap.fits
#     NONE
#     150
#     150
#     0.2
#     CEL
#     193.98
#     -5.82
#     0.0
#     AIT
# Out:
# This is gtbin version HEAD
# Type of output file (CCUBE|CMAP|LC|PHA1|PHA2|HEALPIX) [CMAP] Event data file name[./data/3C279_binned_gti.fits] Output file name[./data/3C279_binned_cmap_small.fits] Spacecraft data file name[NONE] Size of the X axis in pixels[100] Size of the Y axis in pixels[100] Image scale (in degrees/pixel)[0.2] Coordinate system (CEL - celestial, GAL -galactic) (CEL|GAL) [CEL] First coordinate of image center in degrees (RA or galactic l)[193.98] Second coordinate of image center in degrees (DEC or galactic b)[-5.82] Rotation angle of image axis, in degrees[0] Projection method e.g. AIT|ARC|CAR|GLS|MER|NCP|SIN|STG|TAN:[STG]
# gtbin: WARNING: No spacecraft file: EXPOSURE keyword will be set equal to ontime.

# %% [markdown]
# We chose an ROI of 15 degrees, corresponding to 30 degrees in diameter. Since we want a pixel size of 0.2 degrees/pixel, then we must select 30/0.2=150 pixels for the size of the x and y axes. The last command launches the visualization tool _ds9_ and produces a display of the generated [counts](https://fermi.gsfc.nasa.gov/ssc/data/analysis/scitools/data/BinnedLikelihood/3C279_binned_cmap.fits) map.

# %% [markdown]
# <img src='https://fermi.gsfc.nasa.gov/ssc/data/analysis/scitools/images/BinnedLikelihood/3C279_binned_counts_map.png'>
#
# You can see several strong sources and a number of weaker sources in this map. Mousing over the positions of these sources shows that two of them are likely 3C 279 and 3C 273.
#
# It is important to inspect your data prior to proceeding to verify that the contents are as you expect. A malformed data query or improper data selection can generate a non-circular region, or a file with zero events. By inspecting your data prior to analysis, you have an opportunity to detect such issues early in the analysis.
#
# A more detailed discussion of data exploration can be found in the [Explore LAT Data](https://github.com/fermi-lat/AnalysisThreads/blob/master/DataSelection/3.ExploreLATData/explore_latdata.ipynb) analysis thread.

# %% [markdown]
# # 3. Create a 3-D (binned) counts map
#
# Since the counts map shows the expected data, you are ready to prepare your data set for analysis. For binned likelihood analysis, the data input is a three-dimensional counts map with an energy axis, called a counts cube. The gtbin tool performs this task as well by using the `CCUBE` option.
#
# <img src="https://fermi.gsfc.nasa.gov/ssc/data/analysis/scitools/images/BinnedLikelihood/square_in_circle.png">
#
# The binning of the counts map determines the binning of the exposure calculation. The likelihood analysis may lose accuracy if the energy bins are not sufficiently narrow to accommodate more rapid variations in the effective area with decreasing energy below a few hundred MeV. For a typical analysis, ten logarithmically spaced bins per decade in energy are recommended. The analysis is less sensitive to the spatial binning and 0.2 deg bins are a reasonable standard.
#
# This counts cube is a square binned region that must fit within the circular acceptance cone defined during the data extraction step, and visible in the counts map above. To find the maximum size of the region your data will support, find the side of a square that can be fully inscribed within your circular acceptance region (multiply the radius of the acceptance cone by sqrt(2)). For this example, the maximum length for a side is 21.21 degrees.

# %% [markdown]
# To create the counts cube, we run [gtbin](https://fermi.gsfc.nasa.gov/ssc/data/analysis/scitools/help/gtbin.txt) as follows:

# %%
# %%bash
# gtbin
#     CCUBE
#     ./data/3C279_binned_gti.fits
#     ./data/3C279_binned_ccube.fits
#     NONE
#     100
#     100
#     0.2
#     CEL
#     193.98
#     -5.82
#     0.0
#     AIT
#     LOG
#     100
#     500000
#     37
# Out:
# This is gtbin version HEAD
# Type of output file (CCUBE|CMAP|LC|PHA1|PHA2|HEALPIX) [CMAP] Event data file name[./data/3C279_binned_gti.fits] Output file name[./data/3C279_binned_cmap.fits] Spacecraft data file name[NONE] Size of the X axis in pixels[150] Size of the Y axis in pixels[150] Image scale (in degrees/pixel)[0.2] Coordinate system (CEL - celestial, GAL -galactic) (CEL|GAL) [CEL] First coordinate of image center in degrees (RA or galactic l)[193.98] Second coordinate of image center in degrees (DEC or galactic b)[-5.82] Rotation angle of image axis, in degrees[0] Projection method e.g. AIT|ARC|CAR|GLS|MER|NCP|SIN|STG|TAN:[AIT] Algorithm for defining energy bins (FILE|LIN|LOG) [LOG] Start value for first energy bin in MeV[100] Stop value for last energy bin in MeV[500000] Number of logarithmically uniform energy bins[37]
# gtbin: WARNING: No spacecraft file: EXPOSURE keyword will be set equal to ontime.

# %% [markdown]
# [gtbin](https://fermi.gsfc.nasa.gov/ssc/data/analysis/scitools/help/gtbin.txt) takes the following as parameters:
# * Type of output file (CCUBE|CMAP|LC|PHA1|PHA2|HEALPIX)
# * Event data file name
# * Output file name
# * Spacecraft data file name
# * Size of the X axis in pixels
# * Size of the Y axis in pixels
# * Image scale (in degrees/pixel)
# * Coordindate system (CEL - celestial; GAL - galactic) (pick CEL or GAL)
# * First coordinate of image center in degrees (RA or galactic l)
# * Second coordinate of image center in degrees (DEC or galactic b)
# * Rotation angle of image axis, in degrees
# * Projection method (AIT|ARC|CAR|GLS|MER|NCP|SIN|STG|TAN)
# * Algorithm for defining energy bins (FILE|LIN|LOG)
# * Start value for first energy bin in MeV
# * Stop value for last energy bin in MeV
# * Number of logarithmically uniform energy bins

# %% [markdown]
# The counts cube generated in this step is provided [here](https://fermi.gsfc.nasa.gov/ssc/data/analysis/scitools/data/BinnedLikelihood/3C279_binned_ccube.fits).
#
# If you open the file with _ds9_, you see that it is made up of 37 images, one for each logarithmic energy bin. By playing through these images, it is easy to see how the PSF of the LAT changes with energy. You can also see that changing energy cuts could be helpful when trying to optimize the localization or spectral information for specific sources.
#
# Be sure to verify that there are no black corners on your counts cube. These corners correspond to regions with no data and will cause errors in your exposure calculations.

# %% [markdown]
# # 4. Download the latest diffuse model files
#
# When you use the current Galactic diffuse emission model ([`gll_iem_v07.fits`](https://fermi.gsfc.nasa.gov/ssc/data/analysis/software/aux/4fgl/gll_iem_v07.fits)) in a likelihood analysis, you also want to use the corresponding model for the extragalactic isotropic diffuse emission, which includes the residual cosmic-ray background. The recommended isotropic model for point source analysis is [`iso_P8R3_SOURCE_V3_v1.txt`](https://fermi.gsfc.nasa.gov/ssc/data/analysis/software/aux/iso_P8R3_SOURCE_V3_v1.txt).
#
# All the Pass 8 background models have been included in the Fermitools distribution, in the `$(FERMI_DIR)/refdata/fermi/galdiffuse/` directory. If you use that path in your model, you should not have to download the diffuse models individually.
#
# >**NOTE**: Keep in mind that the isotropic model needs to agree with both the event class and event type selections you are using in your analysis. The iso_P8R3_SOURCE_V3_v1.txt isotropic spectrum is valid only for the latest response functions and only for data sets with front + back events combined. All of the most up-to-date background models along with a description of the models are available [here](https://fermi.gsfc.nasa.gov/ssc/data/access/lat/BackgroundModels.html).

# %% [markdown]
# # 5. Create a source model XML file
#
# The [gtlike](https://fermi.gsfc.nasa.gov/ssc/data/analysis/scitools/help/gtlike.txt) tool reads the source model from an XML file. The model file contains your best guess at the locations and spectral forms for the sources in your data. A source model can be created using the [model editor](https://fermi.gsfc.nasa.gov/ssc/data/analysis/scitools/help/modeleditor.txt) tool, by using the user contributed package [LATSourceModel](https://github.com/physicsranger/make4FGLxml) (also available at the [user-contributed tools](https://fermi.gsfc.nasa.gov/ssc/data/analysis/user/) page), or by editing the file directly within a text editor. See Section 4 of the the [Unbinned Likelihood](https://github.com/fermi-lat/AnalysisThreads/blob/master/SourceAnalysis/2.UnbinnedLikelihood/likelihood_tutorial.ipynb) tutorial for a brief tutorial on installing this package.
#
# Here we cannot use the same source model that was used to analyze six months of data in the [Unbinned Likelihood](https://github.com/fermi-lat/AnalysisThreads/blob/master/SourceAnalysis/2.UnbinnedLikelihood/likelihood_tutorial.ipynb) tutorial, as the 2-year data set contains many more significant sources and will not converge. Instead, we will use the latest source catalog to define our source model by running  the LATSourceModel package. To run the tool, you will need to download the current [LAT catalog file](https://fermi.gsfc.nasa.gov/ssc/data/access/lat/fl16y/gll_psc_16yr_v38.xml) and place it in your working directory. Then, use the make4FGLxml tool to create an XML model file:

# %%
# !wget https://fermi.gsfc.nasa.gov/ssc/data/access/lat/fl16y/gll_psc_16yr_v38.xml
# !cp gll_psc_16yr_v38.xml ./data
# Out:
# --2026-01-22 11:56:07--  https://fermi.gsfc.nasa.gov/ssc/data/access/lat/fl16y/gll_psc_16yr_v38.xml
# Resolving fermi.gsfc.nasa.gov (fermi.gsfc.nasa.gov)... 129.164.179.26
# Connecting to fermi.gsfc.nasa.gov (fermi.gsfc.nasa.gov)|129.164.179.26|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 13126347 (13M) [application/xml]
# Saving to: ‘gll_psc_16yr_v38.xml’
#
# gll_psc_16yr_v38.xm 100%[===================>]  12.52M  2.25MB/s    in 5.8s
#
# 2026-01-22 11:56:13 (2.15 MB/s) - ‘gll_psc_16yr_v38.xml’ saved [13126347/13126347]

# %%
# !pip install LATSourceModel
# Out:
# Requirement already satisfied: LATSourceModel in /Users/nmirabal/miniconda3/envs/fermi-2.5.0/lib/python3.11/site-packages (1.10.11)
# Requirement already satisfied: numpy in /Users/nmirabal/miniconda3/envs/fermi-2.5.0/lib/python3.11/site-packages (from LATSourceModel) (1.26.4)
# Requirement already satisfied: pandas in /Users/nmirabal/miniconda3/envs/fermi-2.5.0/lib/python3.11/site-packages (from LATSourceModel) (2.3.3)
# Requirement already satisfied: astropy in /Users/nmirabal/miniconda3/envs/fermi-2.5.0/lib/python3.11/site-packages (from LATSourceModel) (7.2.0)
# Requirement already satisfied: pyerfa>=2.0.1.1 in /Users/nmirabal/miniconda3/envs/fermi-2.5.0/lib/python3.11/site-packages (from astropy->LATSourceModel) (2.0.1.5)
# Requirement already satisfied: astropy-iers-data>=0.2025.10.27.0.39.10 in /Users/nmirabal/miniconda3/envs/fermi-2.5.0/lib/python3.11/site-packages (from astropy->LATSourceModel) (0.2026.1.19.0.42.31)
# Requirement already satisfied: PyYAML>=6.0.0 in /Users/nmirabal/miniconda3/envs/fermi-2.5.0/lib/python3.11/site-packages (from astropy->LATSourceModel) (6.0.3)
# Requirement already satisfied: packaging>=22.0.0 in /Users/nmirabal/miniconda3/envs/fermi-2.5.0/lib/python3.11/site-packages (from astropy->LATSourceModel) (25.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/nmirabal/miniconda3/envs/fermi-2.5.0/lib/python3.11/site-packages (from pandas->LATSourceModel) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/nmirabal/miniconda3/envs/fermi-2.5.0/lib/python3.11/site-packages (from pandas->LATSourceModel) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/nmirabal/miniconda3/envs/fermi-2.5.0/lib/python3.11/site-packages (from pandas->LATSourceModel) (2025.3)
# Requirement already satisfied: six>=1.5 in /Users/nmirabal/miniconda3/envs/fermi-2.5.0/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas->LATSourceModel) (1.17.0)

# %%
# !make4FGLxml ./data/gll_psc_16yr_v38.xml --event_file ./data/3C279_binned_gti.fits --output_name ./data/3C279_input_model.xml --free_radius 5.0 --norms_free_only True --sigma_to_free 25 --variable_free True
# Out:
# Creating spatial and spectral model from the 4FGL DR-3 catalog: data/gll_psc_16yr_v38.xml.
# Added 294 point sources and 0 extended sources.
# Building ds9-style region file...done!
# File saved as data/ROI_3C279_input_model.reg.

# %% [markdown]
# Note that we are using a high level of significance so that we only fit the brightest sources, and we have forced the extended sources to be modeled as point sources.
#
# It is also necessary to specify the entire path to location of the diffuse model on your system. Clearly, the simple 4-source model we used for the 6-month [Unbinned Likelihood](https://github.com/fermi-lat/AnalysisThreads/blob/master/SourceAnalysis/2.UnbinnedLikelihood/likelihood_tutorial.ipynb) analysis would have been too simplistic.

# %% [markdown]
# This XML file uses the spectral model from the latest catalog analysis for each source. (The catalog file is available at the [FL16Y page](https://fermi.gsfc.nasa.gov/ssc/data/access/lat/fl16y/).) However, that analysis used a subset of the available spectral models. A dedicated analysis of the region may indicate a different spectral model is preferred.
#
# For more details on the options available for your XML models, see:
# * Descriptions of available [Spectral and Spatial Models](https://fermi.gsfc.nasa.gov/ssc/data/analysis/scitools/source_models.html)
# * Examples of [XML Model Definitions for Likelihood](https://fermi.gsfc.nasa.gov/ssc/data/analysis/scitools/xml_model_defs.html)

# %% [markdown]
# Finally, the make4FGLxml tool automatically adds 10 degrees to your ROI to account for sources that lie outside your data region, but which may contribute photons to your data. In addition, it gives you the ability to free only some of the spectral parameters for sources within your ROI, and fixes them for the others. With hundreds of sources, there are too many free parameters to gain a good spectral fit. It is advisable to revise these values so that only sources near your source of interest, or very bright source, have all spectral parameters free. Farther away, you can fix the spectral form and free only the normalization parameter (or "prefactor"). If you are working in a crowded region, or have nested sources (e.g. a point source on top of an extended source), you will probably want to fix parameters for some sources even if they lie close to your source of interest.
#
# Only the normalization parameter will be left free (--norms_free_only True) for the remaining sources within the ROI. We have also used the significance parameter (--sigma_to_free 25) of make4FLGxml to free only the brightest sources in our ROI. In addition, we used the variability parameter (--variable_free True) to override that for sources that are significantly variable. We also use a limit of five degrees from the center of the search region (--free_radius 5.0) to reduce the number of sources with free parameters. These changes are necessary: having too many free parameters will not allow the fit to converge (see the section for the fitting step).
#
# The XML file used in this example can be found [here](https://fermi.gsfc.nasa.gov/ssc/data/analysis/scitools/data/BinnedLikelihood/3C279_input_model.xml). This file was made with an earlier version of the LAT catalog, so it will contain fewer sources and some of those sources will have different spectral shapes/parameter values. These changes may cause the likelihood analysis step to fail to reach convergence. For a discusssion of this issue and how to mitigate it, see the "Run the Likelihood Analysis" sectionof the [Likelihood Analysis with Python](https://github.com/fermi-lat/AnalysisThreads/blob/master/SourceAnalysis/3.PythonLikelihood/python_tutorial.ipynb) thread.

# %% [markdown]
# ### XML for Extended Sources
#
# In some regions, the make4FGLxml script may add one or more extended sources to your XML model.
#
# The script will provide the number of extended sources included in the model. In order to use these extended sources, you will need to downloaded the extended source templates from the [LAT Catalog](https://fermi.gsfc.nasa.gov/ssc/data/access/lat/14yr_catalog/) page (look for "Extended Source template archive").
#
# Extract the archive in the directory of your choice and note the path to the template files, which have names like `W44.fits` and `VelaX.fits`. You will need to provide the path to the template file to the script before you run it.
#
# Here is an example of the proper format for an extended source XML entry for Binned Likelihood analysis:
#
# ```xml
# <source name="SpatialMap_source" type="DiffuseSource">
# <spectrum type="PowerLaw2">
# <parameter free="1" max="1000.0" min="1e-05" name="Integral" scale="1e-06" value="1.0"/>
# <parameter free="1" max="-1.0" min="-5.0" name="Index" scale="1.0" value="-2.0"/>
# <parameter free="0" max="200000.0" min="20.0" name="LowerLimit" scale="1.0" value="20.0"/>
# <parameter free="0" max="200000.0" min="20.0" name="UpperLimit" scale="1.0" value="2e5"/>
# </spectrum>
# <spatialModel W44 file="$(PATH_TO_FILE)/W44.fits" type="SpatialMap" map_based_integral="true">
# <parameter free="0" max="1000.0" min="0.001" name="Normalization" scale= "1.0" value="1.0"/>
# </spatialModel>
# </source>
# ```

# %% [markdown]
# # 6. Compute livetimes and exposure
#
# To speed up the exposure calculations performed by Likelihood, it is helpful to pre-compute the livetime as a function of sky position and off-axis angle. The [gtltcube](https://raw.githubusercontent.com/fermi-lat/fermitools-fhelp/master/fhelp_files/gtltcube.txt) tool creates a livetime cube, which is a [HealPix](http://healpix.jpl.nasa.gov/) table, covering the entire sky, of the integrated livetime as a function of inclination with respect to the LAT z-axis.
#
# Here is an example of how to run [gtltcube](https://raw.githubusercontent.com/fermi-lat/fermitools-fhelp/master/fhelp_files/gtltcube.txt):

# %%
# %%bash
# gtltcube zmax=90
#     ./data/3C279_binned_gti.fits
#     ./data/L181126210218F4F0ED2738_SC00.fits
#     ./data/3C279_binned_ltcube.fits
#     0.025
#     1
# Out:
# Event data file[./data/3C279_binned_gti.fits] Spacecraft data file[./data/L181126210218F4F0ED2738_SC00.fits] Output file[./data/3C279_binned_ltcube.fits] Step size in cos(theta) (0.:1.) [0.025] Pixel size (degrees)[1]
# Working on file ./data/L181126210218F4F0ED2738_SC00.fits
# .....................!

# %% [markdown]
# >**Note**: Values such as "0.1" for "Step size in cos(theta) are known to give unexpected results. Use "0.09" instead.

# %% [markdown]
# The livetime cube generated from this analysis can be found [here](https://fermi.gsfc.nasa.gov/ssc/data/analysis/scitools/data/BinnedLikelihood/3C279_binned_ltcube.fits).
#
# For more information about the livetime cubes see the [likelihood documentation](https://fermi.gsfc.nasa.gov/ssc/data/analysis/likelihood/index.html) and also the explanation in the [Unbinned Likelihood](https://github.com/fermi-lat/AnalysisThreads/blob/master/SourceAnalysis/2.UnbinnedLikelihood/likelihood_tutorial.ipynb) tutorial.

# %% [markdown]
# # 7. Compute exposure map
#
# Next, you must apply the livetime calculated in the previous step to your region of interest. To do this, we use the [gtexpcube2](https://fermi.gsfc.nasa.gov/ssc/data/analysis/scitools/help/gtexpcube2.txt) tool, which is an updated version of the previous **gtexpcube**. This tool generates a binned exposure map, an accounting of the exposure at each position in the sky, that are a required input to the likelihood process.
#
# >**NOTE**: In the past, running **gtsrcmaps** calculated the exposure map for you, so most analyses skipped the binned exposure map generation step. With the introduction of **gtexpcube2**, this is no longer the case. You must explicitly command the creation of the exposure map as a separate analysis step.

# %% [markdown]
# In order to create an exposure map that accounts for contributions from all the sources in your analysis region, you must consider not just the sources included in the counts cube. The large PSF of the LAT means that at low energies, sources from well outside your counts cube could affect the sources you are analyzing. To compensate for this, you must create an exposure map that includes sources up to 10 degrees outside your ROI. (The ROI is determined by the radius you downloaded from the data server, here a 15 degree radius.) In addition, you should account for all the exposure that contributes to those additional sources. Since the exposure map uses square pixels, to match the binning in the counts cube, and to ensure we don't have errors, we generate a 300x300 pixel map.

# %% [markdown]
# If you provide [gtexpcube2](https://fermi.gsfc.nasa.gov/ssc/data/analysis/scitools/help/gtexpcube2.txt) a filename for your counts cube, it will use the information from that file to define the geometry of the exposure map. This is legacy behavior and will not give you the necessary 20° buffer you need to completely account for the exposure of nearby sources. (It will also cause an error in the next step.)
#
# Instead, you should specify the appropriate geometry for the exposure map, remembering that the counts cube used 0.2 degree pixel binning. To do that, enter `none` when asked for a Counts cube.
#
# **Note**: If you get a "`File not found`" error in the examples below, just put the IRF name in explicitly. The appropriate IRF for this data set is `P8R3_SOURCE_V3`.
#
# **Note**: Users must also specify evtype.
#
# First we show an example with counts map (cmap) set to none. In this case evtype=3 (Front and Back events)

# %%
# %system punlearn gtexpcube2
# Out:
# []

# %%
# %%bash
# gtexpcube2 chatter=4
#     ./data/3C279_binned_ltcube.fits
#     none
#     ./data/3C279_binned_expcube.fits
#     P8R3_SOURCE_V3
#     3
#     300
#     300
#     .2
#     193.98
#     -5.82
#     0
#     AIT
#     CEL
#     100
#     500000
#     37
# Out:
# This is gtexpcube2 version HEAD
# Livetime cube file[] Counts map file[] Output file name[] Response functions to use[CALDB] Event type selections - Must Specify[] Size of the X axis in pixels[INDEF] Size of the Y axis in pixels[INDEF] Image scale (in degrees/pixel)[INDEF] First coordinate of image center in degrees (RA or galactic l)[INDEF] Second coordinate of image center in degrees (DEC or galactic b)[INDEF] Rotation angle of image axis, in degrees[0.] Projection method e.g. AIT|ARC|CAR|GLS|MER|NCP|SIN|STG|TAN[CAR] Coordinate system (CEL - celestial, GAL -galactic) (CEL|GAL) [GAL] Start energy (MeV) of first bin[INDEF] Stop energy (MeV) of last bin[INDEF] Number of logarithmically-spaced energy bins[INDEF] Using evtype=3 (i.e., FRONT/BACK irfs)
# ResponseFunctions::load: IRF used: P8R3_SOURCE_V3
#   event_types:  0  1
# Computing binned exposure map....................!

# %%
# %system punlearn gtexpcube2
# Out:
# []

# %% [markdown]
# The gtexpcube2 tool can also be executed with a counts map. The following shows an example using evtype=3

# %%
# %%bash
# gtexpcube2 chatter=4
#     ./data/3C279_binned_ltcube.fits
#     ./data/3C279_binned_ccube.fits
#     ./data/3C279_binned_expcubewithcmap.fits
#     P8R3_SOURCE_V3
#     3
# Out:
# This is gtexpcube2 version HEAD
# Livetime cube file[] Counts map file[] Output file name[] Response functions to use[CALDB] Event type selections - Must Specify[] Using evtype=3 (i.e., FRONT/BACK irfs)
# ResponseFunctions::load: IRF used: P8R3_SOURCE_V3
#   event_types:  0  1
# Computing binned exposure map....................!

# %% [markdown]
# The generated exposure map can be found [here](https://fermi.gsfc.nasa.gov/ssc/data/analysis/scitools/data/BinnedLikelihood/3C279_binned_expcube.fits).
#
# At this point, you may decide it is easier to simply generate exposure maps for the entire sky. You may be right, as it certainly simplifies the step when scripting. However, making an all-sky map increases the processing time for this step, though the increase is modest.
#
# To generate an all-sky exposure map (rather than the exposure map we calculated above) you need to specify the proper binning and explicitly give the number of pixels for the entire sky (360°x180°) and evtype. In this case we use evytpe=3
#
# Here is an example:

# %%
# %%bash
# gtexpcube2
#     ./data/3C279_binned_ltcube.fits
#     none
#     ./data/3C279_binned_allsky_expcube.fits
#     P8R3_SOURCE_V3
#     3
#     1800
#     900
#     .2
#     193.98
#     -5.82
#     0
#     AIT
#     CEL
#     100
#     500000
#     37
# Out:
# Livetime cube file[./data/3C279_binned_ltcube.fits] Counts map file[./data/3C279_binned_ccube.fits] Output file name[./data/3C279_binned_expcubewithcmap.fits] Response functions to use[P8R3_SOURCE_V3] Event type selections - Must Specify[3] Size of the X axis in pixels[INDEF] Size of the Y axis in pixels[INDEF] Image scale (in degrees/pixel)[INDEF] First coordinate of image center in degrees (RA or galactic l)[INDEF] Second coordinate of image center in degrees (DEC or galactic b)[INDEF] Rotation angle of image axis, in degrees[0] Projection method e.g. AIT|ARC|CAR|GLS|MER|NCP|SIN|STG|TAN[CAR] Coordinate system (CEL - celestial, GAL -galactic) (CEL|GAL) [GAL] Start energy (MeV) of first bin[INDEF] Stop energy (MeV) of last bin[INDEF] Number of logarithmically-spaced energy bins[INDEF]
# Computing binned exposure map....................!
# Using evtype=3 (i.e., FRONT/BACK irfs)

# %% [markdown]
# The all-sky exposure map can be found [here](https://fermi.gsfc.nasa.gov/ssc/data/analysis/scitools/data/BinnedLikelihood/3C279_binned_allsky_expcube.fits).
#
# Just as in the [Unbinned Likelihood](https://github.com/fermi-lat/AnalysisThreads/blob/master/SourceAnalysis/2.UnbinnedLikelihood/likelihood_tutorial.ipynb) analysis, the exposure needs to be recalculated if the ROI, zenith angle, time, event class, or energy selections applied to the data are changed. For the binned analysis, this also includes the spatial and energy binning of the 3D counts map (which affects the exposure map as well).

# %% [markdown]
# # 8. Compute source map
#
# The [gtsrcmaps](https://fermi.gsfc.nasa.gov/ssc/data/analysis/scitools/help/gtsrcmaps.txt) tool creates model counts maps for use with the binned likelihood analysis. To do this, it takes each source spectrum in the XML model, multiplies it by the exposure at the source position, and convolves that exposure with the effective PSF.
#
# This is an example of how to run the tool:

# %%
# %%bash
# gtsrcmaps
#     ./data/3C279_binned_ltcube.fits
#     ./data/3C279_binned_ccube.fits
#     ./data/3C279_input_model.xml
#     ./data/3C279_binned_allsky_expcube.fits
#     ./data/3C279_binned_srcmaps.fits
#     CALDB
# Out:
# Exposure hypercube file[./data/3C279_binned_ltcube.fits] Counts map file[./data/3C279_binned_ccube.fits] Source model file[./data/3C279_input_model.xml] Binned exposure map[./data/3C279_binned_allsky_expcube.fits] Source maps output file[./data/3C279_binned_srcmaps.fits] Response functions[CALDB]
# Generating SourceMap for FL16Y J1118.2-0413 38....................!
# Generating SourceMap for FL16Y J1118.7-1236 38....................!
# Generating SourceMap for FL16Y J1119.9-1007 38....................!
# Generating SourceMap for FL16Y J1121.2-0011 38....................!
# Generating SourceMap for FL16Y J1121.4-0553 38....................!
# Generating SourceMap for FL16Y J1122.1-0229 38....................!
# Generating SourceMap for FL16Y J1123.8-1201 38....................!
# Generating SourceMap for FL16Y J1124.6-0657 38....................!
# Generating SourceMap for FL16Y J1124.6-0808 38....................!
# Generating SourceMap for FL16Y J1125.4-1422 38....................!
# Generating SourceMap for FL16Y J1125.8-0742 38....................!
# Generating SourceMap for FL16Y J1128.3-1300 38....................!
# Generating SourceMap for FL16Y J1129.2-0529 38....................!
# Generating SourceMap for FL16Y J1129.2-1015 38....................!
# Generating SourceMap for FL16Y J1130.1-1449 38....................!
# Generating SourceMap for FL16Y J1131.0-0944 38....................!
# Generating SourceMap for FL16Y J1131.4-0500 38....................!
# Generating SourceMap for FL16Y J1132.1-1449 38....................!
# Generating SourceMap for FL16Y J1132.7+0034 38....................!
# Generating SourceMap for FL16Y J1133.8-2048 38....................!
# Generating SourceMap for FL16Y J1134.2+0051 38....................!
# Generating SourceMap for FL16Y J1134.8-1728 38....................!
# Generating SourceMap for FL16Y J1136.0-0428 38....................!
# Generating SourceMap for FL16Y J1136.2-0507 38....................!
# Generating SourceMap for FL16Y J1137.8-1709 38....................!
# Generating SourceMap for FL16Y J1140.7-0129 38....................!
# Generating SourceMap for FL16Y J1141.6-1407 38....................!
# Generating SourceMap for FL16Y J1142.8+0120 38....................!
# Generating SourceMap for FL16Y J1143.7-1016 38....................!
# Generating SourceMap for FL16Y J1145.5-0341 38....................!
# Generating SourceMap for FL16Y J1146.0-0638 38....................!
# Generating SourceMap for FL16Y J1146.1+0451 38....................!
# Generating SourceMap for FL16Y J1146.4-0926 38....................!
# Generating SourceMap for FL16Y J1147.8-0725 38....................!
# Generating SourceMap for FL16Y J1148.3-0022 38....................!
# Generating SourceMap for FL16Y J1149.9+1034 38....................!
# Generating SourceMap for FL16Y J1150.8-1904 38....................!
# Generating SourceMap for FL16Y J1151.2+0958 38....................!
# Generating SourceMap for FL16Y J1151.5-1347 38....................!
# Generating SourceMap for FL16Y J1151.6-2114 38....................!
# Generating SourceMap for FL16Y J1152.2-0840 38....................!
# Generating SourceMap for FL16Y J1153.3+0123 38....................!
# Generating SourceMap for FL16Y J1153.3-1104 38....................!
# Generating SourceMap for FL16Y J1153.6-2553 38....................!
# Generating SourceMap for FL16Y J1154.0-0010 38....................!
# Generating SourceMap for FL16Y J1155.2-1111 38....................!
# Generating SourceMap for FL16Y J1155.9-1216 38....................!
# Generating SourceMap for FL16Y J1156.6-2250 38....................!
# Generating SourceMap for FL16Y J1156.7+0641 38....................!
# Generating SourceMap for FL16Y J1156.8-1537 38....................!
# Generating SourceMap for FL16Y J1158.8+0820 38....................!
# Generating SourceMap for FL16Y J1158.8+0953 38....................!
# Generating SourceMap for FL16Y J1158.9+0938 38....................!
# Generating SourceMap for FL16Y J1159.1-1430 38....................!
# Generating SourceMap for FL16Y J1159.2-2228 38....................!
# Generating SourceMap for FL16Y J1159.4-2142 38....................!
# Generating SourceMap for FL16Y J1159.5-0723 38....................!
# Generating SourceMap for FL16Y J1200.2+0202 38....................!
# Generating SourceMap for FL16Y J1200.7+1230 38....................!
# Generating SourceMap for FL16Y J1200.9-1430 38....................!
# Generating SourceMap for FL16Y J1201.1-0333 38....................!
# Generating SourceMap for FL16Y J1201.9+1429 38....................!
# Generating SourceMap for FL16Y J1202.5-0529 38....................!
# Generating SourceMap for FL16Y J1203.2+1118 38....................!
# Generating SourceMap for FL16Y J1203.6-1324 38....................!
# Generating SourceMap for FL16Y J1203.6-1748 38....................!
# Generating SourceMap for FL16Y J1204.1+1146 38....................!
# Generating SourceMap for FL16Y J1204.2-0710 38....................!
# Generating SourceMap for FL16Y J1204.8+0402 38....................!
# Generating SourceMap for FL16Y J1205.6-2635 38....................!
# Generating SourceMap for FL16Y J1207.3-0525 38....................!
# Generating SourceMap for FL16Y J1207.6-0107 38....................!
# Generating SourceMap for FL16Y J1207.6-2230 38....................!
# Generating SourceMap for FL16Y J1208.4+1159 38....................!
# Generating SourceMap for FL16Y J1208.5+0956 38....................!
# Generating SourceMap for FL16Y J1208.7-1754 38....................!
# Generating SourceMap for FL16Y J1208.9-2755 38....................!
# Generating SourceMap for FL16Y J1211.5-2734 38....................!
# Generating SourceMap for FL16Y J1211.9+0305 38....................!
# Generating SourceMap for FL16Y J1212.0-2328 38....................!
# Generating SourceMap for FL16Y J1212.7-1401 38....................!
# Generating SourceMap for FL16Y J1213.1-1122 38....................!
# Generating SourceMap for FL16Y J1213.3-2618 38....................!
# Generating SourceMap for FL16Y J1213.5+1306 38....................!
# Generating SourceMap for FL16Y J1213.6+1236 38....................!
# Generating SourceMap for FL16Y J1213.8-1659 38....................!
# Generating SourceMap for FL16Y J1214.5-2320 38....................!
# Generating SourceMap for FL16Y J1214.6-1925 38....................!
# Generating SourceMap for FL16Y J1215.0+1655 38....................!
# Generating SourceMap for FL16Y J1215.1+0731 38....................!
# Generating SourceMap for FL16Y J1215.3-0627 38....................!
# Generating SourceMap for FL16Y J1215.7-1731 38....................!
# Generating SourceMap for FL16Y J1216.0-0243 38....................!
# Generating SourceMap for FL16Y J1216.1+0929 38....................!
# Generating SourceMap for FL16Y J1216.1-1550 38....................!
# Generating SourceMap for FL16Y J1216.4-0558 38....................!
# Generating SourceMap for FL16Y J1216.4-1030 38....................!
# Generating SourceMap for FL16Y J1216.8-1355 38....................!
# Generating SourceMap for FL16Y J1217.2-2459 38....................!
# Generating SourceMap for FL16Y J1218.1-0028 38....................!
# Generating SourceMap for FL16Y J1218.5-0119 38....................!
# Generating SourceMap for FL16Y J1219.4+0549 38....................!
# Generating SourceMap for FL16Y J1219.7+0445 38....................!
# Generating SourceMap for FL16Y J1219.7-0313 38....................!
# Generating SourceMap for FL16Y J1219.8-2008 38....................!
# Generating SourceMap for FL16Y J1220.2+0200 38....................!
# Generating SourceMap for FL16Y J1220.2-2459 38....................!
# Generating SourceMap for FL16Y J1220.4-2740 38....................!
# Generating SourceMap for FL16Y J1221.4-0633 38....................!
# Generating SourceMap for FL16Y J1221.6+0820 38....................!
# Generating SourceMap for FL16Y J1222.5+0414 38....................!
# Generating SourceMap for FL16Y J1223.0+0045 38....................!
# Generating SourceMap for FL16Y J1223.0+1059 38....................!
# Generating SourceMap for FL16Y J1223.5+0819 38....................!
# Generating SourceMap for FL16Y J1223.7+1203 38....................!
# Generating SourceMap for FL16Y J1223.9-0545 38....................!
# Generating SourceMap for FL16Y J1225.0+0330 38....................!
# Generating SourceMap for FL16Y J1225.4-2851 38....................!
# Generating SourceMap for FL16Y J1225.9-2941 38....................!
# Generating SourceMap for FL16Y J1226.8+0637 38....................!
# Generating SourceMap for FL16Y J1226.8-1329 38....................!
# Generating SourceMap for FL16Y J1228.5-0316 38....................!
# Generating SourceMap for FL16Y J1229.0+0203 38....................!
# Generating SourceMap for FL16Y J1230.8+1223 38....................!
# Generating SourceMap for FL16Y J1231.1-1411 38....................!
# Generating SourceMap for FL16Y J1231.5+1421 38....................!
# Generating SourceMap for FL16Y J1232.9+1335 38....................!
# Generating SourceMap for FL16Y J1233.1+1702 38....................!
# Generating SourceMap for FL16Y J1233.7-0144 38....................!
# Generating SourceMap for FL16Y J1234.7-0436 38....................!
# Generating SourceMap for FL16Y J1235.1-1405 38....................!
# Generating SourceMap for FL16Y J1236.0+1134 38....................!
# Generating SourceMap for FL16Y J1238.2-1158 38....................!
# Generating SourceMap for FL16Y J1238.3-1959 38....................!
# Generating SourceMap for FL16Y J1239.4+0728 38....................!
# Generating SourceMap for FL16Y J1239.5+0443 38....................!
# Generating SourceMap for FL16Y J1240.5-2607 38....................!
# Generating SourceMap for FL16Y J1240.8-2919 38....................!
# Generating SourceMap for FL16Y J1241.8+0635 38....................!
# Generating SourceMap for FL16Y J1241.8-1456 38....................!
# Generating SourceMap for FL16Y J1243.7+1727 38....................!
# Generating SourceMap for FL16Y J1243.8-0218 38....................!
# Generating SourceMap for FL16Y J1244.6+1615 38....................!
# Generating SourceMap for FL16Y J1245.8+0231 38....................!
# Generating SourceMap for FL16Y J1246.1+0114 38....................!
# Generating SourceMap for FL16Y J1246.7-2548 38....................!
# Generating SourceMap for FL16Y J1247.8+0711 38....................!
# Generating SourceMap for FL16Y J1249.2-2808 38....................!
# Generating SourceMap for FL16Y J1249.3-0545 38....................!
# Generating SourceMap for FL16Y J1250.6+0217 38....................!
# Generating SourceMap for FL16Y J1251.2+1038 38....................!
# Generating SourceMap for FL16Y J1251.3-0201 38....................!
# Generating SourceMap for FL16Y J1251.5-1719 38....................!
# Generating SourceMap for FL16Y J1253.8+0327 38....................!
# Generating SourceMap for FL16Y J1254.3-2205 38....................!
# Generating SourceMap for FL16Y J1254.4-1958 38....................!
# Generating SourceMap for FL16Y J1254.9+1139 38....................!
# Generating SourceMap for FL16Y J1256.1-0547 38....................!
# Generating SourceMap for FL16Y J1256.2-1146 38....................!
# Generating SourceMap for FL16Y J1256.8-1333 38....................!
# Generating SourceMap for FL16Y J1258.4-0934 38....................!
# Generating SourceMap for FL16Y J1258.6-1759 38....................!
# Generating SourceMap for FL16Y J1258.7-0450 38....................!
# Generating SourceMap for FL16Y J1258.8-2219 38....................!
# Generating SourceMap for FL16Y J1259.1-2311 38....................!
# Generating SourceMap for FL16Y J1259.8+1751 38....................!
# Generating SourceMap for FL16Y J1300.3+1416 38....................!
# Generating SourceMap for FL16Y J1301.6+0835 38....................!
# Generating SourceMap for FL16Y J1302.1+0536 38....................!
# Generating SourceMap for FL16Y J1302.1-0030 38....................!
# Generating SourceMap for FL16Y J1303.9+1848 38....................!
# Generating SourceMap for FL16Y J1304.2-2412 38....................!
# Generating SourceMap for FL16Y J1304.5+1201 38....................!
# Generating SourceMap for FL16Y J1304.7+0541 38....................!
# Generating SourceMap for FL16Y J1304.9-2106 38....................!
# Generating SourceMap for FL16Y J1306.4+1114 38....................!
# Generating SourceMap for FL16Y J1306.7-2148 38....................!
# Generating SourceMap for FL16Y J1306.8-1720 38....................!
# Generating SourceMap for FL16Y J1307.1-0343 38....................!
# Generating SourceMap for FL16Y J1308.9+0348 38....................!
# Generating SourceMap for FL16Y J1309.6+1154 38....................!
# Generating SourceMap for FL16Y J1310.2-0450 38....................!
# Generating SourceMap for FL16Y J1310.2-1158 38....................!
# Generating SourceMap for FL16Y J1310.9+0034 38....................!
# Generating SourceMap for FL16Y J1312.4-2156 38....................!
# Generating SourceMap for FL16Y J1312.6-1859 38....................!
# Generating SourceMap for FL16Y J1312.7+0050 38....................!
# Generating SourceMap for FL16Y J1312.7-2350 38....................!
# Generating SourceMap for FL16Y J1312.9-0425 38....................!
# Generating SourceMap for FL16Y J1313.7+0200 38....................!
# Generating SourceMap for FL16Y J1314.7-0902 38....................!
# Generating SourceMap for FL16Y J1315.5+1134 38....................!
# Generating SourceMap for FL16Y J1315.9-0732 38....................!
# Generating SourceMap for FL16Y J1317.6-0200 38....................!
# Generating SourceMap for FL16Y J1318.0-1142 38....................!
# Generating SourceMap for FL16Y J1318.1-1738 38....................!
# Generating SourceMap for FL16Y J1318.7-1235 38....................!
# Generating SourceMap for FL16Y J1319.5+1405 38....................!
# Generating SourceMap for FL16Y J1319.6-0046 38....................!
# Generating SourceMap for FL16Y J1321.2-2636 38....................!
# Generating SourceMap for FL16Y J1322.2+0843 38....................!
# Generating SourceMap for FL16Y J1322.3-0606 38....................!
# Generating SourceMap for FL16Y J1322.5-1417 38....................!
# Generating SourceMap for FL16Y J1322.7-0937 38....................!
# Generating SourceMap for FL16Y J1322.7-1616 38....................!
# Generating SourceMap for FL16Y J1323.0+0438 38....................!
# Generating SourceMap for FL16Y J1323.9+1405 38....................!
# Generating SourceMap for FL16Y J1324.5-2338 38....................!
# Generating SourceMap for FL16Y J1324.6-2524 38....................!
# Generating SourceMap for FL16Y J1325.7-0227 38....................!
# Generating SourceMap for FL16Y J1326.1+1231 38....................!
# Generating SourceMap for FL16Y J1326.6+0153 38....................!
# Generating SourceMap for FL16Y J1326.7-0503 38....................!
# Generating SourceMap for FL16Y J1328.5+1145 38....................!
# Generating SourceMap for FL16Y J1329.5-0530 38....................!
# Generating SourceMap for FL16Y J1329.8-1558 38....................!
# Generating SourceMap for FL16Y J1331.3-1325 38....................!
# Generating SourceMap for FL16Y J1331.6+1711 38....................!
# Generating SourceMap for FL16Y J1331.6-0343 38....................!
# Generating SourceMap for FL16Y J1331.6-0647 38....................!
# Generating SourceMap for FL16Y J1332.0-0509 38....................!
# Generating SourceMap for FL16Y J1332.3-2301 38....................!
# Generating SourceMap for FL16Y J1332.6-1256 38....................!
# Generating SourceMap for FL16Y J1333.5+1539 38....................!
# Generating SourceMap for FL16Y J1334.0-1150 38....................!
# Generating SourceMap for FL16Y J1336.6-1528 38....................!
# Generating SourceMap for FL16Y J1337.2+0036 38....................!
# Generating SourceMap for FL16Y J1337.6-1256 38....................!
# Generating SourceMap for FL16Y J1337.9-1959 38....................!
# Generating SourceMap for FL16Y J1338.0-0931 38....................!
# Generating SourceMap for FL16Y J1338.9+1153 38....................!
# Generating SourceMap for FL16Y J1339.0-2359 38....................!
# Generating SourceMap for FL16Y J1339.3-2619 38....................!
# Generating SourceMap for FL16Y J1339.9-0136 38....................!
# Generating SourceMap for FL16Y J1340.0-1501 38....................!
# Generating SourceMap for FL16Y J1340.6-0411 38....................!
# Generating SourceMap for FL16Y J1341.9-2055 38....................!
# Generating SourceMap for FL16Y J1342.0+1043 38....................!
# Generating SourceMap for FL16Y J1342.6+0941 38....................!
# Generating SourceMap for FL16Y J1342.7+0503 38....................!
# Generating SourceMap for FL16Y J1344.2-1724 38....................!
# Generating SourceMap for FL16Y J1345.8+0707 38....................!
# Generating SourceMap for FL16Y J1345.9-2611 38....................!
# Generating SourceMap for FL16Y J1347.9-0615 38....................!
# Generating SourceMap for FL16Y J1348.9+0756 38....................!
# Generating SourceMap for FL16Y J1349.1-1113 38....................!
# Generating SourceMap for FL16Y J1349.5-1132 38....................!
# Generating SourceMap for FL16Y J1350.0+0404 38....................!
# Generating SourceMap for FL16Y J1351.1+0030 38....................!
# Generating SourceMap for FL16Y J1351.2-1529 38....................!
# Generating SourceMap for FL16Y J1351.3+1114 38....................!
# Generating SourceMap for FL16Y J1352.3-0015 38....................!
# Generating SourceMap for FL16Y J1353.3+1434 38....................!
# Generating SourceMap for FL16Y J1354.1-0205 38....................!
# Generating SourceMap for FL16Y J1354.2+0353 38....................!
# Generating SourceMap for FL16Y J1354.7+0622 38....................!
# Generating SourceMap for FL16Y J1354.8-1041 38....................!
# Generating SourceMap for FL16Y J1356.2-2455 38....................!
# Generating SourceMap for FL16Y J1356.3-1725 38....................!
# Generating SourceMap for FL16Y J1356.6+0232 38....................!
# Generating SourceMap for FL16Y J1357.6+0127 38....................!
# Generating SourceMap for FL16Y J1358.9-0701 38....................!
# Generating SourceMap for FL16Y J1359.2-1152 38....................!
# Generating SourceMap for FL16Y J1359.3+0200 38....................!
# Generating SourceMap for FL16Y J1400.1-2415 38....................!
# Generating SourceMap for FL16Y J1400.6-1432 38....................!
# Generating SourceMap for FL16Y J1401.3-0915 38....................!
# Generating SourceMap for FL16Y J1402.0-0023 38....................!
# Generating SourceMap for FL16Y J1402.6-1829 38....................!
# Generating SourceMap for FL16Y J1404.8+0402 38....................!
# Generating SourceMap for FL16Y J1405.1-0640 38....................!
# Generating SourceMap for FL16Y J1405.1-1550 38....................!
# Generating SourceMap for FL16Y J1405.8-1853 38....................!
# Generating SourceMap for FL16Y J1406.5-1654 38....................!
# Generating SourceMap for FL16Y J1408.9-0751 38....................!
# Generating SourceMap for FL16Y J1410.1+0202 38....................!
# Generating SourceMap for FL16Y J1410.1+0516 38....................!
# Generating SourceMap for FL16Y J1411.5-0724 38....................!
# Generating SourceMap for FL16Y J1414.7+0825 38....................!
# Generating SourceMap for FL16Y J1415.8-1503 38....................!
# Generating SourceMap for FL16Y J1416.1-1008 38....................!
# Generating SourceMap for FL16Y J1418.4-0233 38....................!
# Generating SourceMap for FL16Y J1419.3+0445 38....................!
# Generating SourceMap for FL16Y J1419.4-0838 38....................!
# Generating SourceMap for FL16Y J1420.3+0613 38....................!
# Generating SourceMap for FL16Y J1421.1-1119 38....................!
# Generating SourceMap for FL16Y J1421.4-1655 38....................!
# Generating SourceMap for FL16Y J1423.7-0534 38....................!
# Generating SourceMap for FL16Y J1424.0-1751 38....................!
# Generating SourceMap for FL16Y J1424.1+0433 38....................!
# Generating SourceMap for FL16Y J1425.4-0119 38....................!
# Generating SourceMap for FL16Y J1427.7+0001 38....................!
# Generating SourceMap for FL16Y J1428.8-1017 38....................!
# Generating SourceMap for FL16Y J1429.7-0736 38....................!
# Generating SourceMap for gll_iem_v07 38....................!
# Generating SourceMap for iso_P8R3_SOURCE_V3_v1 38....................!

# %% [markdown]
# The output file from [gtsrcmaps](https://fermi.gsfc.nasa.gov/ssc/data/analysis/scitools/help/gtsrcmaps.txt) can be found [here](https://fermi.gsfc.nasa.gov/ssc/data/analysis/scitools/data/BinnedLikelihood/3C279_binned_srcmaps.fits).
#
# Because your model map can include sources outside your ROI, you may see a list of warnings at the beginning of the output. These are expected (because you have properly included sources outside your ROI in your XML file) and should cause no problem in your analysis. In addition, if your exposure map is too small for the region, you will see the following warning:
#
# ```
# Caught St13runtime_error at the top level:
# Request for exposure at a sky position that is outside of the map boundaries.
#
# The contribution of the diffuse source outside of the exposure
# and counts map boundaries is being computed to account for PSF
# leakage into the analysis region. To handle this, use an all-sky
# binned exposure map. Alternatively, to neglect contributions
# outside of the counts map region, use the emapbnds=no option when
# running gtsrcmaps.
# ```

# %% [markdown]
# In this situation, you should increase the dimensions of your exposure map, or just move to the all-sky version.
#
# Source map generation for the point sources is fairly quick, and maps for many point sources may take up a lot of disk space. If you are analyzing a single long data set, it may be preferable to pre-compute only the source maps for the diffuse components at this stage.
#
# [gtlike](https://fermi.gsfc.nasa.gov/ssc/data/analysis/scitools/help/gtlike.txt) will compute maps for the point sources on the fly if they appear in the XML definition and a corresponding map is not in the source maps FITS file. To skip generating source maps for point sources, specify "`ptsrc=no`" on the command line when running **gtsrcmaps**. However, if you expect to perform multiple fits on the same set of data, precomputing the source maps will probably save you time.

# %% [markdown]
# # 9. Run gtlike
#
# >NOTE: Prior to running **gtlike** for Unbinned Likelihood, it is necessary to calculate the diffuse response for each event (when that response is not precomputed). However, for Binned Likelihood analysis the diffuse response is calculated over the entire bin, so this step is not necessary.
#
# If you want to use the **energy dispersion correction** during your analysis, you must enable this feature using the environment variable `USE_BL_EDISP`. This may be set on the command line using:
#
# ```bash
# export USE_BL_EDISP=true
# ```
# or, depending on your shell,
#
# ```
# setenv USE_BL_EDISP=true
# ```
#
# To disable the use of energy dispersion, you must unset the variable:
# ```bash
# unset USE_BL_EDISP
# ```
# or
# ```
# unsetenv USE_BL_EDISP
# ```

# %% [markdown]
# ```bash
# export USE_BL_EDISP=true
# ```
# or, depending on your shell,
#
# ```
# setenv USE_BL_EDISP=true
# ```
#
# To disable the use of energy dispersion, you must unset the variable:
# ```bash
# unset USE_BL_EDISP
# ```
# or
# ```
# unsetenv USE_BL_EDISP
# ```

# %% [markdown]
# Now we are ready to run the [gtlike](https://fermi.gsfc.nasa.gov/ssc/data/analysis/scitools/help/gtlike.txt) application.

# %%
# %%bash
# gtlike refit=no plot=no sfile=./data/3C279_binned_output.xml
#     BINNED
#     ./data/3C279_binned_srcmaps.fits
#     ./data/3C279_binned_allsky_expcube.fits
#     ./data/3C279_binned_ltcube.fits
#     ./data/3C279_input_model.xml
#     CALDB
#     NEWMINUIT
# Out:
# Statistic to use (BINNED|UNBINNED) [BINNED] Counts map file[./data/3C279_binned_srcmaps.fits] Binned exposure map[./data/3C279_binned_allsky_expcube.fits] Exposure hypercube file[./data/3C279_binned_ltcube.fits] Source model file[./data/3C279_input_model.xml] Response functions to use[CALDB] Optimizer (DRMNFB|NEWMINUIT|MINUIT|DRMNGB|LBFGS) [NEWMINUIT]
# Minuit did successfully converge.
# # of function calls: 214
# minimum function Value: 76964.13017656
# minimum edm: 0.0002499702099726
# minimum internal state vector: LAVector parameters:
#      -1.568596659811
#      -1.566988382324
#      -1.570557568881
#      -1.567004546993
#      -1.569226446644
#      -1.566113368116
#      -1.569010010418
#      -1.569184793701
#      -1.569226364698
#       -1.56888131499
#    -0.09673797720996
#     -0.7741989182438
#
# minimum internal covariance matrix: LASymMatrix parameters:
#   6.1281387e-07 -2.7906362e-09  -5.966277e-08 -1.7513882e-10  4.0481017e-09  1.1279537e-09  2.2741304e-09   1.058301e-08  1.4141762e-09  9.3575511e-10 -2.9179523e-07 -4.3994296e-07
#  -2.7906362e-09  9.2569473e-07 -3.4968311e-09 -3.9619434e-09  2.4794516e-09  3.0918671e-09  3.3541877e-09  1.9283174e-08  1.5197219e-09 -7.3060432e-10 -1.4036626e-07  2.1397966e-07
#   -5.966277e-08 -3.4968311e-09  9.9655855e-06 -1.3576464e-09  1.2272911e-08   3.170844e-09  3.8064444e-09  2.4940379e-08  4.2606751e-09  7.5325606e-09 -1.3404078e-06 -3.1026027e-06
#  -1.7513882e-10 -3.9619434e-09 -1.3576464e-09  7.8172047e-10 -6.5630383e-10 -8.2353265e-10 -6.8545237e-10 -3.9524818e-09 -8.6697647e-11 -1.6198564e-10  3.0841485e-08  3.2985188e-08
#   4.0481017e-09  2.4794516e-09  1.2272911e-08 -6.5630383e-10  1.1702767e-06  1.6929344e-09  2.9729555e-09  6.5562533e-09  1.4234359e-09 -4.8552704e-10 -1.7509711e-07  4.5372193e-08
#   1.1279537e-09  3.0918671e-09   3.170844e-09 -8.2353265e-10  1.6929344e-09  3.0544342e-06 -8.5389104e-10  2.0620993e-09  3.2088547e-10  4.7661167e-10 -2.7046616e-07  -8.825604e-08
#   2.2741304e-09  3.3541877e-09  3.8064444e-09 -6.8545237e-10  2.9729555e-09 -8.5389104e-10  7.3058521e-07 -1.5134123e-07 -1.2353848e-08  1.0882264e-09 -2.2634313e-07 -4.9747288e-07
#    1.058301e-08  1.9283174e-08  2.4940379e-08 -3.9524818e-09  6.5562533e-09  2.0620993e-09 -1.5134123e-07  8.1341984e-06 -2.2652749e-07  1.0828824e-09  1.6761444e-07 -1.3282122e-06
#   1.4141762e-09  1.5197219e-09  4.2606751e-09 -8.6697647e-11  1.4234359e-09  3.2088547e-10 -1.2353848e-08 -2.2652749e-07  1.0589623e-07  3.8139295e-10 -7.4649727e-08 -2.1080646e-07
#   9.3575511e-10 -7.3060432e-10  7.5325606e-09 -1.6198564e-10 -4.8552704e-10  4.7661167e-10  1.0882264e-09  1.0828824e-09  3.8139295e-10  2.8811607e-09 -2.5775162e-07 -1.0925862e-06
#  -2.9179523e-07 -1.4036626e-07 -1.3404078e-06  3.0841485e-08 -1.7509711e-07 -2.7046616e-07 -2.2634313e-07  1.6761444e-07 -7.4649727e-08 -2.5775162e-07  9.9962513e-05  6.3045328e-05
#  -4.3994296e-07  2.1397966e-07 -3.1026027e-06  3.2985188e-08  4.5372193e-08  -8.825604e-08 -4.9747288e-07 -1.3282122e-06 -2.1080646e-07 -1.0925862e-06  6.3045328e-05  0.00044202806
#
#
# # ext. ||   Name    ||   type  ||     Value     ||  Error +/-
#
#    0   ||    0_norm || limited ||      1.209633222532 ||0.6088017103223
#    1   ||1_Prefactor || limited ||      3.625105893745 ||1.295324036837
#    2   ||    2_norm || limited ||    0.01425133527855 ||1.24569762916
#    3   ||3_Prefactor || limited ||      3.594394210715 ||0.03748200527731
#    4   ||4_Prefactor || limited ||     0.6161307957719 ||0.6004343927057
#    5   ||    5_norm || limited ||      5.482515476551 ||2.893603489096
#    6   ||6_Prefactor || limited ||      0.797731337765 ||0.5398194964368
#    7   ||7_Prefactor || limited ||     0.6492595873153 ||1.624991646187
#    8   ||    8_norm || limited ||     0.6161951200401 ||0.1806276581084
#    9   ||9_Prefactor || limited ||      0.916817273211 ||0.03634209294612
#   10   ||  10_Index || limited ||   -0.09658716498681 ||0.007036629325486
#   11   ||11_Normalization || limited ||      1.512778011526 ||0.05309139323663
#
#
#
#
#
# # of function calls: 339
# function Value: 76964.13017656
# expected distance to the Minimum (edm): 0.0002251893062395
# external parameters:
# # ext. ||   Name    ||   type  ||     Value     ||  Error +/-
#
#    0   ||    0_norm || limited ||      1.209633222532 ||0.6087495610374
#    1   ||1_Prefactor || limited ||      3.625105893745 ||1.294880910024
#    2   ||    2_norm || limited ||    0.01425133527855 ||0.1233532683775
#    3   ||3_Prefactor || limited ||      3.594394210715 ||0.03744758286794
#    4   ||4_Prefactor || limited ||     0.6161307957719 ||0.6001129250477
#    5   ||    5_norm || limited ||      5.482515476551 ||2.893408182214
#    6   ||6_Prefactor || limited ||      0.797731337765 ||0.5393754814176
#    7   ||7_Prefactor || limited ||     0.6492595873153 ||1.615181726589
#    8   ||    8_norm || limited ||     0.6161951200401 ||0.1794917141307
#    9   ||9_Prefactor || limited ||      0.916817273211 ||0.03596924019744
#   10   ||  10_Index || limited ||   -0.09658716498681 ||0.006889867195761
#   11   ||11_Normalization || limited ||      1.512778011526 ||0.05303126493685
#
#
#
# covariance matrix status: 3
# covariance matrix:
# MnUserCovariance:
#
#      0.370576   -0.0027718  -0.00158354 -0.000166866   0.00165403   0.00138929   0.00108926   0.00418115  0.000610652  0.000451133 -0.000151764 -0.000802335
#    -0.0027718      1.67672 -0.000211961  -0.00706386   0.00179044   0.00678691   0.00281836    0.0131432   0.00118555 -0.000686521 -0.000135625  0.000772269
#   -0.00158354 -0.000211961    0.0070318 -5.84238e-05  0.000195133   0.00011174  2.59071e-05  0.000354063  6.16174e-05   0.00010289 -1.77176e-05 -0.000173832
#  -0.000166866  -0.00706386 -5.84238e-05   0.00140232 -0.000469231  -0.00179593 -0.000572808  -0.00270269 -7.80003e-05 -0.000139471  2.73599e-05  0.000102443
#    0.00165403   0.00179044  0.000195133 -0.000469231     0.360136   0.00150402  0.000998327   0.00185082  0.000432303 -0.000173605 -6.86295e-05   6.1367e-05
#    0.00138929   0.00678691   0.00011174  -0.00179593   0.00150402      8.37182 -0.000862528   0.00177196  0.000292028  0.000458901 -0.000302661 -0.000271575
#    0.00108926   0.00281836  2.59071e-05 -0.000572808  0.000998327 -0.000862528     0.290926   -0.0476017  -0.00444315   0.00043882 -9.37028e-05 -0.000762728
#    0.00418115    0.0131432  0.000354063  -0.00270269   0.00185082   0.00177196   -0.0476017      2.60882   -0.0636609  0.000452151  4.80054e-05  -0.00182061
#   0.000610652   0.00118555  6.16174e-05 -7.80003e-05  0.000432303  0.000292028  -0.00444315   -0.0636609    0.0322173  0.000138479 -2.70124e-05 -0.000296119
#   0.000451133 -0.000686521   0.00010289 -0.000139471 -0.000173605  0.000458901   0.00043882  0.000452151  0.000138479   0.00129379 -0.000110314  -0.00184674
#  -0.000151764 -0.000135625 -1.77176e-05  2.73599e-05 -6.86295e-05 -0.000302661 -9.37028e-05  4.80054e-05 -2.70124e-05 -0.000110314   4.7471e-05  9.58342e-05
#  -0.000802335  0.000772269 -0.000173832  0.000102443   6.1367e-05 -0.000271575 -0.000762728  -0.00182061 -0.000296119  -0.00184674  9.58342e-05   0.00281252
#
# MnUserCovariance Parameter correlations:
#
#             1  -0.00351637   -0.0310211   -0.0073199   0.00452765  0.000788761   0.00331742   0.00425241    0.0055887    0.0206032    -0.036184   -0.0248524
#   -0.00351637            1  -0.00195206    -0.145676   0.00230408   0.00181148    0.0040353   0.00628418   0.00510089   -0.0147398   -0.0152018    0.0112458
#    -0.0310211  -0.00195206            1   -0.0186051   0.00387761  0.000460537  0.000572788   0.00261412    0.0040938     0.034112   -0.0306659   -0.0390885
#    -0.0073199    -0.145676   -0.0186051            1     -0.02088   -0.0165751   -0.0283592   -0.0446839   -0.0116045    -0.103545     0.106041    0.0515834
#    0.00452765   0.00230408   0.00387761     -0.02088            1  0.000866184   0.00308424   0.00190946   0.00401339  -0.00804261   -0.0165983   0.00192821
#   0.000788761   0.00181148  0.000460537   -0.0165751  0.000866184            1 -0.000552678  0.000379161  0.000562303   0.00440939   -0.0151821  -0.00176983
#    0.00331742    0.0040353  0.000572788   -0.0283592   0.00308424 -0.000552678            1   -0.0546399   -0.0458939    0.0226185   -0.0252143   -0.0266643
#    0.00425241   0.00628418   0.00261412   -0.0446839   0.00190946  0.000379161   -0.0546399            1    -0.219587    0.0077827   0.00431374   -0.0212543
#     0.0055887   0.00510089    0.0040938   -0.0116045   0.00401339  0.000562303   -0.0458939    -0.219587            1     0.021449   -0.0218426   -0.0311081
#     0.0206032   -0.0147398     0.034112    -0.103545  -0.00804261   0.00440939    0.0226185    0.0077827     0.021449            1    -0.445129    -0.968115
#     -0.036184   -0.0152018   -0.0306659     0.106041   -0.0165983   -0.0151821   -0.0252143   0.00431374   -0.0218426    -0.445129            1     0.262276
#    -0.0248524    0.0112458   -0.0390885    0.0515834   0.00192821  -0.00176983   -0.0266643   -0.0212543   -0.0311081    -0.968115     0.262276            1
#
# global correlation coefficients :
# MnGlobalCorrelationCoeff:
#
#     0.0848461
#      0.170554
#     0.0827084
#      0.310781
#      0.074806
#     0.0223993
#      0.112786
#      0.258204
#      0.252635
#      0.989253
#      0.817098
#      0.987483
# ........................................................................................................................................................................................................................................................................................................!
# Computing TS values for each source (296 total)
#
# Photon fluxes are computed for the energy range 100 to 500000 MeV
#
# FL16Y J1118.2-0413:
# Prefactor: 1.69944
# Index: 2.71139
# Scale: 650.215
# Flux: 1.59315e-08 photons/cm^2/s
#
# FL16Y J1118.7-1236:
# Prefactor: 1.42064
# Index: 2.7454
# Scale: 661.498
# Flux: 1.45908e-08 photons/cm^2/s
#
# FL16Y J1119.9-1007:
# Prefactor: 6.65233
# Index: 2.20932
# Scale: 1854
# Flux: 3.4871e-09 photons/cm^2/s
#
# FL16Y J1121.2-0011:
# Prefactor: 9.08712
# Index: 1.91918
# Scale: 4117.39
# Flux: 1.24117e-09 photons/cm^2/s
#
# FL16Y J1121.4-0553:
# norm: 5.10458
# alpha: 2.31833
# beta: 0.153828
# Eb: 688.03
# Flux: 2.55846e-08 photons/cm^2/s
#
# FL16Y J1122.1-0229:
# Prefactor: 7.99046
# Index: 2.25007
# Scale: 1903.42
# Flux: 4.84278e-09 photons/cm^2/s
#
# FL16Y J1123.8-1201:
# Prefactor: 4.21578
# Index: 2.33507
# Scale: 1991.52
# Flux: 3.41612e-09 photons/cm^2/s
#
# FL16Y J1124.6-0657:
# Prefactor: 1.19462
# Index: 2.2402
# Scale: 2767.12
# Flux: 1.63896e-09 photons/cm^2/s
#
# FL16Y J1124.6-0808:
# Prefactor: 1.56376
# Index: 2.13673
# Scale: 3274.88
# Flux: 2.37898e-09 photons/cm^2/s
#
# FL16Y J1125.4-1422:
# Prefactor: 3.52983
# Index: 2.6896
# Scale: 897.401
# Flux: 7.65398e-09 photons/cm^2/s
#
# FL16Y J1125.8-0742:
# Prefactor: 4.01944
# Index: 1.93279
# Scale: 3556.61
# Flux: 4.28827e-09 photons/cm^2/s
#
# FL16Y J1128.3-1300:
# Prefactor: 7.71098
# Index: 2.13371
# Scale: 3249.5
# Flux: 1.14473e-09 photons/cm^2/s
#
# FL16Y J1129.2-0529:
# norm: 1.19412
# alpha: 2.52134
# beta: 0.0837867
# Eb: 931.821
# Flux: 1.72449e-08 photons/cm^2/s
#
# FL16Y J1129.2-1015:
# Prefactor: 9.60239
# Index: 2.18663
# Scale: 3162.57
# Flux: 1.54334e-09 photons/cm^2/s
#
# FL16Y J1130.1-1449:
# norm: 1.29681
# alpha: 2.61403
# beta: 0.126806
# Eb: 653.668
# Flux: 8.56346e-08 photons/cm^2/s
#
# FL16Y J1131.0-0944:
# Prefactor: 2.3261
# Index: 2.05712
# Scale: 3123.69
# Flux: 2.61492e-09 photons/cm^2/s
#
# FL16Y J1131.4-0500:
# norm: 3.78539
# alpha: 2.29706
# beta: 0.235493
# Eb: 1237.32
# Flux: 4.43976e-09 photons/cm^2/s
#
# FL16Y J1132.1-1449:
# Prefactor: 1.59169
# Index: 2.22122
# Scale: 3680.28
# Flux: 3.92302e-09 photons/cm^2/s
#
# FL16Y J1132.7+0034:
# norm: 1.23423
# alpha: 1.96175
# beta: 0.0913762
# Eb: 1431.43
# Flux: 1.73179e-08 photons/cm^2/s
#
# FL16Y J1133.8-2048:
# norm: 1.37584
# alpha: 1.65528
# beta: 0.305305
# Eb: 4109.72
# Flux: 2.52778e-10 photons/cm^2/s
#
# FL16Y J1134.2+0051:
# norm: 3.85901
# alpha: 2.77285
# beta: 0.188901
# Eb: 206.973
# Flux: 1.54636e-08 photons/cm^2/s
#
# FL16Y J1134.8-1728:
# norm: 2.11425
# alpha: 1.49733
# beta: 0.195697
# Eb: 9175.85
# Flux: 1.04312e-10 photons/cm^2/s
#
# FL16Y J1136.0-0428:
# Prefactor: 4.51723
# Index: 2.66306
# Scale: 866.318
# Flux: 8.54669e-09 photons/cm^2/s
#
# FL16Y J1136.2-0507:
# norm: 5.11738
# alpha: 2.58294
# beta: 0.241863
# Eb: 901.649
# Flux: 5.04835e-09 photons/cm^2/s
#
# FL16Y J1137.8-1709:
# norm: 1.16111
# alpha: 1.44243
# beta: 0.314906
# Eb: 5739.89
# Flux: 2.44918e-10 photons/cm^2/s
#
# FL16Y J1140.7-0129:
# Prefactor: 1.11433
# Index: 2.01773
# Scale: 3292.87
# Flux: 1.26369e-09 photons/cm^2/s
#
# FL16Y J1141.6-1407:
# Prefactor: 2.08505
# Index: 1.97334
# Scale: 3436.74
# Flux: 2.30325e-09 photons/cm^2/s
#
# FL16Y J1142.8+0120:
# Prefactor: 6.59983
# IndexS: 1.65176
# Scale: 1355.67
# ExpfactorS: 4.25988
# Index2: 0.666667
# Flux: 4.8442e-09 photons/cm^2/s
#
# FL16Y J1143.7-1016:
# norm: 5.09437
# alpha: 2.16992
# beta: 0.518572
# Eb: 1967
# Flux: 4.62914e-10 photons/cm^2/s
#
# FL16Y J1145.5-0341:
# Prefactor: 8.59367
# Index: 2.04927
# Scale: 3702.79
# Flux: 1.34236e-09 photons/cm^2/s
#
# FL16Y J1146.0-0638:
# norm: 2.23794
# alpha: 1.66301
# beta: 0.1203
# Eb: 3930.48
# Flux: 7.5444e-10 photons/cm^2/s
#
# FL16Y J1146.1+0451:
# Prefactor: 1.7417
# Index: 2.881
# Scale: 437.742
# Flux: 6.52953e-09 photons/cm^2/s
#
# FL16Y J1146.4-0926:
# Prefactor: 6.73294
# Index: 2.5
# Scale: 1000
# Flux: 1.42139e-09 photons/cm^2/s
#
# FL16Y J1147.8-0725:
# norm: 2.6605
# alpha: 2.44043
# beta: 0.0875157
# Eb: 639.236
# Flux: 1.4642e-08 photons/cm^2/s
#
# FL16Y J1148.3-0022:
# Prefactor: 8.11183
# Index: 2.74764
# Scale: 584.493
# Flux: 5.94722e-09 photons/cm^2/s
#
# FL16Y J1149.9+1034:
# Prefactor: 3.78333
# Index: 1.96976
# Scale: 4994.48
# Flux: 8.64906e-10 photons/cm^2/s
#
# FL16Y J1150.8-1904:
# norm: 1.25173
# alpha: 1.498
# beta: 0.363423
# Eb: 10726.2
# Flux: 4.68e-11 photons/cm^2/s
#
# FL16Y J1151.2+0958:
# Prefactor: 1.76288
# Index: 2.41659
# Scale: 1605.47
# Flux: 1.02084e-08 photons/cm^2/s
#
# FL16Y J1151.5-1347:
# norm: 6.96236
# alpha: 1.79418
# beta: 0.0887214
# Eb: 2507.91
# Flux: 1.83544e-09 photons/cm^2/s
#
# FL16Y J1151.6-2114:
# Prefactor: 1.81951
# Index: 1.97778
# Scale: 3302.19
# Flux: 1.87809e-09 photons/cm^2/s
#
# FL16Y J1152.2-0840:
# norm: 5.14471
# alpha: 2.32815
# beta: 0.110827
# Eb: 664.743
# Flux: 2.61582e-08 photons/cm^2/s
#
# FL16Y J1153.3+0123:
# Prefactor: 2.81582
# Index: 1.90295
# Scale: 5236.92
# Flux: 5.82474e-10 photons/cm^2/s
#
# FL16Y J1153.3-1104:
# norm: 5.07598
# alpha: 2.21148
# beta: 0.0962078
# Eb: 684.547
# Flux: 2.48093e-08 photons/cm^2/s
#
# FL16Y J1153.6-2553:
# norm: 3.58875
# alpha: 1.74414
# beta: 0.186773
# Eb: 3056.88
# Flux: 7.63366e-10 photons/cm^2/s
#
# FL16Y J1154.0-0010:
# Prefactor: 2.11998
# Index: 1.8248
# Scale: 4056.51
# Flux: 2.2097e-09 photons/cm^2/s
#
# FL16Y J1155.2-1111:
# norm: 3.84472
# alpha: 1.64486
# beta: 0.347897
# Eb: 6641.44
# Flux: 1.03123e-10 photons/cm^2/s
#
# FL16Y J1155.9-1216:
# Prefactor: 4.75963
# Index: 2.32649
# Scale: 1735.75
# Flux: 2.7478e-09 photons/cm^2/s
#
# FL16Y J1156.6-2250:
# Prefactor: 2.66385
# Index: 2.0117
# Scale: 3557.68
# Flux: 3.47645e-09 photons/cm^2/s
#
# FL16Y J1156.7+0641:
# Prefactor: 4.15732
# Index: 2.50867
# Scale: 888.742
# Flux: 6.62206e-09 photons/cm^2/s
#
# FL16Y J1156.8-1537:
# Prefactor: 1.96975
# Index: 2.33829
# Scale: 1282.66
# Flux: 5.74676e-09 photons/cm^2/s
#
# FL16Y J1158.8+0820:
# Prefactor: 2.10906
# Index: 1.98692
# Scale: 3182.63
# Flux: 2.06959e-09 photons/cm^2/s
#
# FL16Y J1158.8+0953:
# norm: 1.48092
# alpha: 2.3548
# beta: 0.225327
# Eb: 738.676
# Flux: 7.81508e-09 photons/cm^2/s
#
# FL16Y J1158.9+0938:
# norm: 3.70133
# alpha: 1.60253
# beta: 0.212682
# Eb: 3553.49
# Flux: 7.12517e-10 photons/cm^2/s
#
# FL16Y J1159.1-1430:
# Prefactor: 2.32474
# Index: 1.72431
# Scale: 9521.17
# Flux: 8.27097e-10 photons/cm^2/s
#
# FL16Y J1159.2-2228:
# norm: 1.73749
# alpha: 2.28086
# beta: 0.168897
# Eb: 1067.9
# Flux: 1.85193e-08 photons/cm^2/s
#
# FL16Y J1159.4-2142:
# norm: 3.13326
# alpha: 2.52042
# beta: 0.084319
# Eb: 870.008
# Flux: 3.86059e-08 photons/cm^2/s
#
# FL16Y J1159.5-0723:
# norm: 4.59064
# alpha: 1.6346
# beta: 0.269147
# Eb: 3116.02
# Flux: 6.75824e-10 photons/cm^2/s
#
# FL16Y J1200.2+0202:
# norm: 2.21656
# alpha: 1.88754
# beta: 0.119911
# Eb: 1663.16
# Flux: 3.23294e-09 photons/cm^2/s
#
# FL16Y J1200.7+1230:
# Prefactor: 3.30411
# Index: 2.49043
# Scale: 1015.97
# Flux: 7.14344e-09 photons/cm^2/s
#
# FL16Y J1200.9-1430:
# Prefactor: 1.02476
# Index: 1.96467
# Scale: 4175.13
# Flux: 1.62353e-09 photons/cm^2/s
#
# FL16Y J1201.1-0333:
# norm: 3.96929
# alpha: 1.95401
# beta: 0.19828
# Eb: 2300.47
# Flux: 7.75323e-10 photons/cm^2/s
#
# FL16Y J1201.9+1429:
# norm: 1.92623
# alpha: 2.14667
# beta: 0.32115
# Eb: 1231.86
# Flux: 1.48616e-09 photons/cm^2/s
#
# FL16Y J1202.5-0529:
# norm: 1.5062
# alpha: 2.77868
# beta: 0.227119
# Eb: 313.971
# Flux: 1.76943e-08 photons/cm^2/s
#
# FL16Y J1203.2+1118:
# Prefactor: 8.03424
# Index: 2.38243
# Scale: 1491.63
# Flux: 3.63894e-09 photons/cm^2/s
#
# FL16Y J1203.6-1324:
# Prefactor: 7.48665
# Index: 2.44663
# Scale: 1351.67
# Flux: 3.02905e-09 photons/cm^2/s
#
# FL16Y J1203.6-1748:
# norm: 2.14502
# alpha: 2.11425
# beta: 0.277235
# Eb: 1442.88
# Flux: 2.19694e-09 photons/cm^2/s
#
# FL16Y J1204.1+1146:
# Prefactor: 9.31404
# Index: 1.82704
# Scale: 5207.88
# Flux: 1.54106e-09 photons/cm^2/s
#
# FL16Y J1204.2-0710:
# norm: 1.18076
# alpha: 1.75299
# beta: 0.0820866
# Eb: 2440.57
# Flux: 2.87082e-09 photons/cm^2/s
#
# FL16Y J1204.8+0402:
# Prefactor: 5.72157
# Index: 2.69579
# Scale: 655.064
# Flux: 5.36343e-09 photons/cm^2/s
#
# FL16Y J1205.6-2635:
# Prefactor: 1.20223
# Index: 2.51112
# Scale: 893.508
# Flux: 1.94814e-08 photons/cm^2/s
#
# FL16Y J1207.3-0525:
# norm: 1.73875
# alpha: 1.61888
# beta: 0.19763
# Eb: 3629.87
# Flux: 3.67061e-10 photons/cm^2/s
#
# FL16Y J1207.6-0107:
# norm: 1.21194
# alpha: 2.14177
# beta: 0.149719
# Eb: 903.53
# Flux: 8.35635e-09 photons/cm^2/s
#
# FL16Y J1207.6-2230:
# Prefactor: 3.61661
# Index: 2.03136
# Scale: 3075.53
# Flux: 3.69498e-09 photons/cm^2/s
#
# FL16Y J1208.4+1159:
# norm: 8.06693
# alpha: 2.07268
# beta: 0.181236
# Eb: 1728.48
# Flux: 1.34483e-09 photons/cm^2/s
#
# FL16Y J1208.5+0956:
# Prefactor: 1.11453
# Index: 2.53221
# Scale: 1096.48
# Flux: 3.13253e-09 photons/cm^2/s
#
# FL16Y J1208.7-1754:
# norm: 4.00884
# alpha: 1.84949
# beta: 0.241015
# Eb: 2649.71
# Flux: 6.91886e-10 photons/cm^2/s
#
# FL16Y J1208.9-2755:
# norm: 9.3749
# alpha: 1.96118
# beta: 0.234381
# Eb: 2129.68
# Flux: 1.47827e-09 photons/cm^2/s
#
# FL16Y J1211.5-2734:
# Prefactor: 1.15889
# Index: 2.61933
# Scale: 832.784
# Flux: 1.84751e-08 photons/cm^2/s
#
# FL16Y J1211.9+0305:
# norm: 2.30441
# alpha: 1.63613
# beta: 0.418974
# Eb: 7365.87
# Flux: 5.91384e-11 photons/cm^2/s
#
# FL16Y J1212.0-2328:
# norm: 8.18527
# alpha: 1.93598
# beta: 0.0982689
# Eb: 2481.06
# Flux: 2.62215e-09 photons/cm^2/s
#
# FL16Y J1212.7-1401:
# Prefactor: 3.22082
# Index: 2.09557
# Scale: 5560.51
# Flux: 1.33544e-09 photons/cm^2/s
#
# FL16Y J1213.1-1122:
# Prefactor: 2.50385
# Index: 2.34371
# Scale: 2225.39
# Flux: 2.68357e-09 photons/cm^2/s
#
# FL16Y J1213.3-2618:
# Prefactor: 8.91098
# Index: 1.78719
# Scale: 5807.38
# Flux: 1.60711e-09 photons/cm^2/s
#
# FL16Y J1213.5+1306:
# norm: 1.57165
# alpha: 2.42995
# beta: 0.127495
# Eb: 814.936
# Flux: 1.33823e-08 photons/cm^2/s
#
# FL16Y J1213.6+1236:
# Prefactor: 5.44948
# Index: 2.12408
# Scale: 4306.19
# Flux: 1.43485e-09 photons/cm^2/s
#
# FL16Y J1213.8-1659:
# Prefactor: 2.23057
# Index: 2.22125
# Scale: 2484.94
# Flux: 2.29794e-09 photons/cm^2/s
#
# FL16Y J1214.5-2320:
# Prefactor: 4.00003
# Index: 2.32873
# Scale: 2203.21
# Flux: 4.04306e-09 photons/cm^2/s
#
# FL16Y J1214.6-1925:
# norm: 2.6465
# alpha: 2.52076
# beta: 0.541341
# Eb: 1002.57
# Flux: 1.53523e-09 photons/cm^2/s
#
# FL16Y J1215.0+1655:
# Prefactor: 8.43804
# Index: 2.39637
# Scale: 965.587
# Flux: 1.38575e-08 photons/cm^2/s
#
# FL16Y J1215.1+0731:
# Prefactor: 2.17614
# Index: 1.86434
# Scale: 3827.47
# Flux: 2.24909e-09 photons/cm^2/s
#
# FL16Y J1215.3-0627:
# norm: 1.23222
# alpha: 2.60732
# beta: 0.393375
# Eb: 1394.3
# Flux: 1.75574e-09 photons/cm^2/s
#
# FL16Y J1215.7-1731:
# Prefactor: 7.6765
# Index: 2.62124
# Scale: 773.594
# Flux: 1.01163e-08 photons/cm^2/s
#
# FL16Y J1216.0-0243:
# Prefactor: 1.10772
# Index: 2.02844
# Scale: 3939.26
# Flux: 1.8564e-09 photons/cm^2/s
#
# FL16Y J1216.1+0929:
# Prefactor: 5.90024
# Index: 1.99682
# Scale: 2411.38
# Flux: 3.40853e-09 photons/cm^2/s
#
# FL16Y J1216.1-1550:
# Prefactor: 6.54597
# Index: 2.03771
# Scale: 3945.17
# Flux: 1.12836e-09 photons/cm^2/s
#
# FL16Y J1216.4-0558:
# Prefactor: 4.28751
# Index: 2.48011
# Scale: 1118.2
# Flux: 1.15594e-08 photons/cm^2/s
#
# FL16Y J1216.4-1030:
# norm: 1.28373
# alpha: 2.5907
# beta: 0.210721
# Eb: 700.621
# Flux: 8.23183e-09 photons/cm^2/s
#
# FL16Y J1216.8-1355:
# Prefactor: 1.89459
# Index: 2.07745
# Scale: 2915.84
# Flux: 1.94248e-09 photons/cm^2/s
#
# FL16Y J1217.2-2459:
# norm: 1.3189
# alpha: 2.22873
# beta: 0.331598
# Eb: 1562.63
# Flux: 1.51903e-09 photons/cm^2/s
#
# FL16Y J1218.1-0028:
# norm: 2.51392
# alpha: 2.29249
# beta: 0.111431
# Eb: 1391.4
# Flux: 5.31924e-09 photons/cm^2/s
#
# FL16Y J1218.5-0119:
# norm: 1.14916
# alpha: 2.01492
# beta: 0.0954881
# Eb: 1296.05
# Flux: 1.45143e-08 photons/cm^2/s
#
# FL16Y J1219.4+0549:
# Prefactor: 4.13104
# Index: 2.17989
# Scale: 2301.87
# Flux: 3.26406e-09 photons/cm^2/s
#
# FL16Y J1219.7+0445:
# Prefactor: 3.36697
# Index: 2.17181
# Scale: 2786.57
# Flux: 3.95501e-09 photons/cm^2/s
#
# FL16Y J1219.7-0313:
# Prefactor: 3.78879
# Index: 1.96558
# Scale: 3239.8
# Flux: 3.65505e-09 photons/cm^2/s
#
# FL16Y J1219.8-2008:
# Prefactor: 1.2466
# Index: 2.07924
# Scale: 3359.26
# Flux: 1.72306e-09 photons/cm^2/s
#
# FL16Y J1220.2+0200:
# Prefactor: 6.01805
# Index: 1.97755
# Scale: 3883.73
# Flux: 8.55633e-10 photons/cm^2/s
#
# FL16Y J1220.2-2459:
# Prefactor: 1.70314
# Index: 2.09411
# Scale: 3559.67
# Flux: 2.76245e-09 photons/cm^2/s
#
# FL16Y J1220.4-2740:
# Prefactor: 3.89125
# Index: 2.69468
# Scale: 888.681
# Flux: 8.28582e-09 photons/cm^2/s
#
# FL16Y J1221.4-0633:
# Prefactor: 7.26122
# IndexS: 1.79401
# Scale: 1223.43
# ExpfactorS: 5.43357
# Index2: 0.666667
# Flux: 4.8989e-09 photons/cm^2/s
#
# FL16Y J1221.6+0820:
# Prefactor: 2.33323
# Index: 2.15185
# Scale: 2278.64
# Flux: 1.69201e-09 photons/cm^2/s
#
# FL16Y J1222.5+0414:
# norm: 7.41357
# alpha: 2.55879
# beta: 0.238971
# Eb: 583.938
# Flux: 3.00019e-08 photons/cm^2/s
#
# FL16Y J1223.0+0045:
# Prefactor: 2.42295
# Index: 2.33618
# Scale: 2078.57
# Flux: 2.17517e-09 photons/cm^2/s
#
# FL16Y J1223.0+1059:
# norm: 2.36182
# alpha: 1.4477
# beta: 0.368944
# Eb: 3880.81
# Flux: 3.05025e-10 photons/cm^2/s
#
# FL16Y J1223.5+0819:
# Prefactor: 1.01549
# Index: 1.92853
# Scale: 4068.14
# Flux: 1.38904e-09 photons/cm^2/s
#
# FL16Y J1223.7+1203:
# Prefactor: 4.59906
# Index: 2.3381
# Scale: 2145.8
# Flux: 4.46736e-09 photons/cm^2/s
#
# FL16Y J1223.9-0545:
# Prefactor: 4.05426
# Index: 2.66225
# Scale: 780.952
# Flux: 5.81221e-09 photons/cm^2/s
#
# FL16Y J1225.0+0330:
# Prefactor: 8.57804
# Index: 2.73523
# Scale: 907.364
# Flux: 2.06344e-08 photons/cm^2/s
#
# FL16Y J1225.4-2851:
# norm: 1.67359
# alpha: 2.19267
# beta: 0.254658
# Eb: 1337.86
# Flux: 1.81556e-09 photons/cm^2/s
#
# FL16Y J1225.9-2941:
# Prefactor: 9.02614
# Index: 2.50863
# Scale: 1388.99
# Flux: 4.40693e-09 photons/cm^2/s
#
# FL16Y J1226.8+0637:
# Prefactor: 8.25926
# Index: 1.78962
# Scale: 4841.4
# Flux: 1.08298e-09 photons/cm^2/s
#
# FL16Y J1226.8-1329:
# norm: 1.88622
# alpha: 1.935
# beta: 0.100035
# Eb: 1931.31
# Flux: 4.02591e-09 photons/cm^2/s
#
# FL16Y J1228.5-0316:
# Prefactor: 5.43972
# Index: 2.06607
# Scale: 2679.61
# Flux: 4.55559e-09 photons/cm^2/s
#
# FL16Y J1229.0+0203:
# norm: 1.03812
# alpha: 2.64644
# beta: 0.102609
# Eb: 410.12
# Flux: 2.38931e-07 photons/cm^2/s
#
# FL16Y J1230.8+1223:
# Prefactor: 5.34033
# Index: 2.06892
# Scale: 1757.21
# Flux: 1.8807e-08 photons/cm^2/s
#
# FL16Y J1231.1-1411:
# Prefactor: 9.07315
# IndexS: 1.83885
# Scale: 1587.74
# ExpfactorS: 7.75547
# Index2: 0.535631
# Flux: 7.35046e-08 photons/cm^2/s
#
# FL16Y J1231.5+1421:
# Prefactor: 1.19781
# Index: 1.89638
# Scale: 4894.78
# Flux: 2.1393e-09 photons/cm^2/s
#
# FL16Y J1232.9+1335:
# norm: 4.91774
# alpha: 2.38776
# beta: 0.253907
# Eb: 1077.18
# Flux: 4.96373e-09 photons/cm^2/s
#
# FL16Y J1233.1+1702:
# norm: 1.3635
# alpha: 1.61538
# beta: 0.260822
# Eb: 4116.54
# Flux: 2.70679e-10 photons/cm^2/s
#
# FL16Y J1233.7-0144:
# Prefactor: 2.73756
# Index: 2.08579
# Scale: 1835.68
# Flux: 1.09121e-08 photons/cm^2/s
#
# FL16Y J1234.7-0436:
# Prefactor: 1.34241
# Index: 2.10468
# Scale: 3645.49
# Flux: 2.35469e-09 photons/cm^2/s
#
# FL16Y J1235.1-1405:
# norm: 2.17028
# alpha: 1.27778
# beta: 0.376556
# Eb: 11498.7
# Flux: 7.58523e-11 photons/cm^2/s
#
# FL16Y J1236.0+1134:
# norm: 2.05415
# alpha: 2.15528
# beta: 0.271729
# Eb: 2744.37
# Flux: 5.29452e-10 photons/cm^2/s
#
# FL16Y J1238.2-1158:
# norm: 6.46653
# alpha: 2.5444
# beta: 0.0807206
# Eb: 475.234
# Flux: 2.00441e-08 photons/cm^2/s
#
# FL16Y J1238.3-1959:
# norm: 6.01424
# alpha: 2.00497
# beta: 0.0863033
# Eb: 1298.19
# Flux: 7.72138e-09 photons/cm^2/s
#
# FL16Y J1239.4+0728:
# norm: 2.02488
# alpha: 2.02041
# beta: 0.190011
# Eb: 1391.64
# Flux: 2.19681e-09 photons/cm^2/s
#
# FL16Y J1239.5+0443:
# norm: 2.40239
# alpha: 2.25408
# beta: 0.120365
# Eb: 568.824
# Flux: 8.10995e-08 photons/cm^2/s
#
# FL16Y J1240.5-2607:
# Prefactor: 3.8768
# Index: 2.17137
# Scale: 2317.91
# Flux: 3.0497e-09 photons/cm^2/s
#
# FL16Y J1240.8-2919:
# Prefactor: 1.25288
# Index: 2.79823
# Scale: 578.013
# Flux: 9.46246e-09 photons/cm^2/s
#
# FL16Y J1241.8+0635:
# Prefactor: 7.01869
# Index: 2.00776
# Scale: 4158.03
# Flux: 1.24002e-09 photons/cm^2/s
#
# FL16Y J1241.8-1456:
# norm: 5.11098
# alpha: 1.67172
# beta: 0.184514
# Eb: 2877.24
# Flux: 9.22612e-10 photons/cm^2/s
#
# FL16Y J1243.7+1727:
# Prefactor: 5.9209
# Index: 2.01958
# Scale: 4111.92
# Flux: 1.05649e-09 photons/cm^2/s
#
# FL16Y J1243.8-0218:
# norm: 1.20963 +/- 0.60875
# alpha: 2.04488
# beta: 0.179922
# Eb: 1242.6
# TS value: 5.39825
# Flux: 1.1709e-09 +/- 5.8923e-10 photons/cm^2/s
#
# FL16Y J1244.6+1615:
# Prefactor: 3.96213
# Index: 2.15327
# Scale: 2370.06
# Flux: 3.13734e-09 photons/cm^2/s
#
# FL16Y J1245.8+0231:
# norm: 3.66019
# alpha: 2.15027
# beta: 0.338277
# Eb: 1243.45
# Flux: 2.7656e-09 photons/cm^2/s
#
# FL16Y J1246.1+0114:
# norm: 2.04527
# alpha: 1.86038
# beta: 0.304356
# Eb: 2716.98
# Flux: 3.0486e-10 photons/cm^2/s
#
# FL16Y J1246.7-2548:
# norm: 2.50951
# alpha: 2.22998
# beta: 0.105863
# Eb: 649.45
# Flux: 1.10653e-07 photons/cm^2/s
#
# FL16Y J1247.8+0711:
# Prefactor: 4.8463
# Index: 1.98263
# Scale: 4217.46
# Flux: 8.22351e-10 photons/cm^2/s
#
# FL16Y J1249.2-2808:
# Prefactor: 6.34006
# Index: 2.01296
# Scale: 2816.74
# Flux: 5.18776e-09 photons/cm^2/s
#
# FL16Y J1249.3-0545:
# Prefactor: 3.62511 +/- 1.29488
# Index: 2.03868
# Scale: 2832.63
# TS value: 13.9181
# Flux: 3.18874e-09 +/- 1.13826e-09 photons/cm^2/s
#
# FL16Y J1250.6+0217:
# Prefactor: 7.70758
# Index: 2.06366
# Scale: 2340.6
# Flux: 4.85507e-09 photons/cm^2/s
#
# FL16Y J1251.2+1038:
# Prefactor: 1.8927
# Index: 2.04445
# Scale: 2908.93
# Flux: 1.78218e-09 photons/cm^2/s
#
# FL16Y J1251.3-0201:
# norm: 0.0142513 +/- 0.0838558
# alpha: 2.03665
# beta: 0.151609
# Eb: 1210.36
# TS value: 0.00111589
# Flux: 1.40994e-11 +/- 8.2953e-11 photons/cm^2/s
#
# FL16Y J1251.5-1719:
# Prefactor: 2.0531
# Index: 3.04836
# Scale: 413.263
# Flux: 7.59633e-09 photons/cm^2/s
#
# FL16Y J1253.8+0327:
# Prefactor: 1.85469
# Index: 2.005
# Scale: 2084.13
# Flux: 8.14216e-09 photons/cm^2/s
#
# FL16Y J1254.3-2205:
# Prefactor: 7.34214
# Index: 2.21363
# Scale: 2175.4
# Flux: 5.53269e-09 photons/cm^2/s
#
# FL16Y J1254.4-1958:
# Prefactor: 5.47199
# Index: 2.20069
# Scale: 1965.74
# Flux: 3.2043e-09 photons/cm^2/s
#
# FL16Y J1254.9+1139:
# Prefactor: 1.95354
# Index: 2.77768
# Scale: 514.047
# Flux: 1.03933e-08 photons/cm^2/s
#
# FL16Y J1256.1-0547:
# Prefactor: 3.59439 +/- 0.0374476
# IndexS: 2.28676
# Scale: 1004.64
# ExpfactorS: 1.49069
# Index2: 0.191555
# TS value: 27670.1
# Flux: 4.52156e-07 +/- 4.70752e-09 photons/cm^2/s
#
# FL16Y J1256.2-1146:
# Prefactor: 1.02946
# Index: 1.97777
# Scale: 2644.67
# Flux: 6.84933e-09 photons/cm^2/s
#
# FL16Y J1256.8-1333:
# Prefactor: 2.61586
# Index: 2.35859
# Scale: 2085.28
# Flux: 2.49106e-09 photons/cm^2/s
#
# FL16Y J1258.4-0934:
# Prefactor: 0.616131 +/- 0.600113
# Index: 2.08583
# Scale: 3035.03
# TS value: 1.42124
# Flux: 7.01006e-10 +/- 6.82291e-10 photons/cm^2/s
#
# FL16Y J1258.6-1759:
# norm: 3.53864
# alpha: 2.21307
# beta: 0.15724
# Eb: 685.078
# Flux: 1.56561e-08 photons/cm^2/s
#
# FL16Y J1258.7-0450:
# norm: 5.48252 +/- 2.89341
# alpha: 1.45359
# beta: 0.282847
# Eb: 6067.13
# TS value: 8.97063
# Flux: 1.32095e-10 +/- 6.97148e-11 photons/cm^2/s
#
# FL16Y J1258.8-2219:
# norm: 3.59107
# alpha: 2.32942
# beta: 0.0926027
# Eb: 843.875
# Flux: 3.11909e-08 photons/cm^2/s
#
# FL16Y J1259.1-2311:
# Prefactor: 1.19213
# Index: 2.08307
# Scale: 2609.67
# Flux: 9.83535e-09 photons/cm^2/s
#
# FL16Y J1259.8+1751:
# Prefactor: 8.14162
# Index: 2.38561
# Scale: 1351.42
# Flux: 2.93224e-09 photons/cm^2/s
#
# FL16Y J1300.3+1416:
# norm: 8.91087
# alpha: 2.58833
# beta: 0.130589
# Eb: 395.216
# Flux: 1.74719e-08 photons/cm^2/s
#
# FL16Y J1301.6+0835:
# Prefactor: 1.62657
# IndexS: 1.83012
# Scale: 1018.88
# ExpfactorS: 6.47306
# Index2: 0.666667
# Flux: 8.08464e-09 photons/cm^2/s
#
# FL16Y J1302.1+0536:
# Prefactor: 4.80511
# Index: 2.64261
# Scale: 753.056
# Flux: 6.08138e-09 photons/cm^2/s
#
# FL16Y J1302.1-0030:
# Prefactor: 1.40804
# Index: 2.55104
# Scale: 1000
# Flux: 3.23351e-09 photons/cm^2/s
#
# FL16Y J1303.9+1848:
# Prefactor: 8.00621
# Index: 2.8227
# Scale: 568.169
# Flux: 5.93287e-09 photons/cm^2/s
#
# FL16Y J1304.2-2412:
# norm: 1.92481
# alpha: 1.8712
# beta: 0.100611
# Eb: 2088.26
# Flux: 4.16581e-09 photons/cm^2/s
#
# FL16Y J1304.5+1201:
# norm: 2.54974
# alpha: 1.98464
# beta: 0.651716
# Eb: 1425.27
# Flux: 1.13992e-09 photons/cm^2/s
#
# FL16Y J1304.7+0541:
# norm: 1.20717
# alpha: 2.26705
# beta: 0.369285
# Eb: 1494.03
# Flux: 1.25102e-09 photons/cm^2/s
#
# FL16Y J1304.9-2106:
# Prefactor: 7.81045
# Index: 2.26193
# Scale: 2057.48
# Flux: 5.79065e-09 photons/cm^2/s
#
# FL16Y J1306.4+1114:
# Prefactor: 4.4288
# Index: 1.89848
# Scale: 5264.66
# Flux: 9.13649e-10 photons/cm^2/s
#
# FL16Y J1306.7-2148:
# norm: 1.67933
# alpha: 1.97508
# beta: 0.217426
# Eb: 1888.14
# Flux: 2.43402e-09 photons/cm^2/s
#
# FL16Y J1306.8-1720:
# Prefactor: 1.01982
# Index: 2.33037
# Scale: 1418.17
# Flux: 3.70655e-09 photons/cm^2/s
#
# FL16Y J1307.1-0343:
# Prefactor: 0.797731 +/- 0.539376
# Index: 2.03339
# Scale: 3402.09
# TS value: 3.74535
# Flux: 1.00566e-09 +/- 6.79524e-10 photons/cm^2/s
#
# FL16Y J1308.9+0348:
# norm: 1.22896
# alpha: 1.87052
# beta: 0.298935
# Eb: 1703.42
# Flux: 1.09588e-09 photons/cm^2/s
#
# FL16Y J1309.6+1154:
# Prefactor: 2.03607
# Index: 2.15258
# Scale: 1629.71
# Flux: 7.18818e-09 photons/cm^2/s
#
# FL16Y J1310.2-0450:
# Prefactor: 0.64926 +/- 1.61518
# Index: 2.4789
# Scale: 1747.03
# TS value: 0.188936
# Flux: 5.27968e-10 +/- 1.31169e-09 photons/cm^2/s
#
# FL16Y J1310.2-1158:
# Prefactor: 3.39884
# Index: 1.97476
# Scale: 3628.95
# Flux: 4.19539e-09 photons/cm^2/s
#
# FL16Y J1310.9+0034:
# Prefactor: 3.93155
# Index: 2.12799
# Scale: 3160.37
# Flux: 5.42001e-09 photons/cm^2/s
#
# FL16Y J1312.4-2156:
# norm: 9.34186
# alpha: 1.91403
# beta: 0.108748
# Eb: 1516.15
# Flux: 1.2704e-08 photons/cm^2/s
#
# FL16Y J1312.6-1859:
# Prefactor: 1.09661
# Index: 1.98789
# Scale: 3951.6
# Flux: 1.6585e-09 photons/cm^2/s
#
# FL16Y J1312.7+0050:
# Prefactor: 1.89459
# IndexS: 1.89345
# Scale: 1352.83
# ExpfactorS: 8.35641
# Index2: 0.666667
# Flux: 1.31271e-08 photons/cm^2/s
#
# FL16Y J1312.7-2350:
# norm: 6.71925
# alpha: 1.74178
# beta: 0.0708415
# Eb: 3225.26
# Flux: 2.55104e-09 photons/cm^2/s
#
# FL16Y J1312.9-0425:
# norm: 0.616195 +/- 0.179492
# alpha: 2.2564
# beta: 0.159506
# Eb: 797.902
# TS value: 17.3281
# Flux: 3.79664e-09 +/- 1.10557e-09 photons/cm^2/s
#
# FL16Y J1313.7+0200:
# Prefactor: 1.44069
# Index: 2.58167
# Scale: 1100.17
# Flux: 4.45484e-09 photons/cm^2/s
#
# FL16Y J1314.7-0902:
# Prefactor: 3.72835
# Index: 1.88216
# Scale: 5866.76
# Flux: 9.00227e-10 photons/cm^2/s
#
# FL16Y J1315.5+1134:
# norm: 1.90251
# alpha: 1.58784
# beta: 0.146324
# Eb: 3844.96
# Flux: 4.96983e-10 photons/cm^2/s
#
# FL16Y J1315.9-0732:
# norm: 9.74456
# alpha: 1.78912
# beta: 0.143477
# Eb: 2329.74
# Flux: 1.83755e-09 photons/cm^2/s
#
# FL16Y J1317.6-0200:
# norm: 1.37073
# alpha: 2.06131
# beta: 0.493814
# Eb: 1680
# Flux: 9.84816e-10 photons/cm^2/s
#
# FL16Y J1318.0-1142:
# Prefactor: 7.7433
# Index: 2.00914
# Scale: 3969.33
# Flux: 1.25086e-09 photons/cm^2/s
#
# FL16Y J1318.1-1738:
# Prefactor: 6.97713
# Index: 2.27301
# Scale: 1749.19
# Flux: 3.66648e-09 photons/cm^2/s
#
# FL16Y J1318.7-1235:
# norm: 2.81894
# alpha: 2.02354
# beta: 0.0733897
# Eb: 1549.23
# Flux: 5.31559e-09 photons/cm^2/s
#
# FL16Y J1319.5+1405:
# Prefactor: 2.19266
# Index: 2.02988
# Scale: 3220.84
# Flux: 2.45128e-09 photons/cm^2/s
#
# FL16Y J1319.6-0046:
# norm: 1.03331
# alpha: 2.3085
# beta: 0.272797
# Eb: 763.704
# Flux: 5.06298e-09 photons/cm^2/s
#
# FL16Y J1321.2-2636:
# Prefactor: 3.46773
# Index: 2.60705
# Scale: 897.133
# Flux: 6.58953e-09 photons/cm^2/s
#
# FL16Y J1322.2+0843:
# Prefactor: 8.74227
# Index: 2.18991
# Scale: 1787.06
# Flux: 4.06018e-09 photons/cm^2/s
#
# FL16Y J1322.3-0606:
# norm: 7.80719
# alpha: 1.85298
# beta: 0.209434
# Eb: 2188.76
# Flux: 1.1853e-09 photons/cm^2/s
#
# FL16Y J1322.5-1417:
# Prefactor: 6.68144
# Index: 1.96319
# Scale: 4157.31
# Flux: 1.04551e-09 photons/cm^2/s
#
# FL16Y J1322.7-0937:
# norm: 5.91257
# alpha: 2.50223
# beta: 0.131816
# Eb: 486.917
# Flux: 1.75805e-08 photons/cm^2/s
#
# FL16Y J1322.7-1616:
# Prefactor: 3.29402
# Index: 2.12947
# Scale: 2473.22
# Flux: 2.70445e-09 photons/cm^2/s
#
# FL16Y J1323.0+0438:
# norm: 1.42509
# alpha: 1.68793
# beta: 0.175346
# Eb: 3873.44
# Flux: 3.86376e-10 photons/cm^2/s
#
# FL16Y J1323.9+1405:
# norm: 8.09625
# alpha: 1.60309
# beta: 0.176111
# Eb: 2689.18
# Flux: 1.2724e-09 photons/cm^2/s
#
# FL16Y J1324.5-2338:
# Prefactor: 1.85206
# Index: 2.21276
# Scale: 2795.39
# Flux: 2.42597e-09 photons/cm^2/s
#
# FL16Y J1324.6-2524:
# Prefactor: 3.83673
# Index: 2.00411
# Scale: 4887.89
# Flux: 9.28006e-10 photons/cm^2/s
#
# FL16Y J1325.7-0227:
# norm: 1.12698
# alpha: 1.86437
# beta: 0.346296
# Eb: 3994.67
# Flux: 2.27606e-10 photons/cm^2/s
#
# FL16Y J1326.1+1231:
# Prefactor: 5.77554
# Index: 2.00942
# Scale: 4031.78
# Flux: 9.63453e-10 photons/cm^2/s
#
# FL16Y J1326.6+0153:
# Prefactor: 3.41305
# Index: 1.8962
# Scale: 5395.63
# Flux: 7.32902e-10 photons/cm^2/s
#
# FL16Y J1326.7-0503:
# Prefactor: 5.47456
# Index: 1.68664
# Scale: 11743.5
# Flux: 2.46317e-10 photons/cm^2/s
#
# FL16Y J1328.5+1145:
# norm: 2.81431
# alpha: 1.33567
# beta: 0.283835
# Eb: 8763.71
# Flux: 9.0437e-11 photons/cm^2/s
#
# FL16Y J1329.5-0530:
# norm: 3.01216
# alpha: 2.18999
# beta: 0.319673
# Eb: 1421.8
# Flux: 2.99463e-09 photons/cm^2/s
#
# FL16Y J1329.8-1558:
# Prefactor: 6.11783
# Index: 2.01549
# Scale: 4201.18
# Flux: 1.12724e-09 photons/cm^2/s
#
# FL16Y J1331.3-1325:
# norm: 3.40251
# alpha: 2.37753
# beta: 0.160203
# Eb: 1435.03
# Flux: 7.40814e-09 photons/cm^2/s
#
# FL16Y J1331.6+1711:
# Prefactor: 1.43086
# Index: 2.23862
# Scale: 1532.6
# Flux: 5.20928e-09 photons/cm^2/s
#
# FL16Y J1331.6-0343:
# norm: 1.41236
# alpha: 2.5661
# beta: 0.386507
# Eb: 636.417
# Flux: 5.49441e-09 photons/cm^2/s
#
# FL16Y J1331.6-0647:
# norm: 2.83833
# alpha: 1.78714
# beta: 0.245511
# Eb: 2966.24
# Flux: 5.0637e-10 photons/cm^2/s
#
# FL16Y J1332.0-0509:
# norm: 5.92072
# alpha: 2.57261
# beta: 0.14871
# Eb: 829.889
# Flux: 6.04586e-08 photons/cm^2/s
#
# FL16Y J1332.3-2301:
# Prefactor: 2.9383
# Index: 2.66858
# Scale: 843.091
# Flux: 5.21511e-09 photons/cm^2/s
#
# FL16Y J1332.6-1256:
# norm: 3.97211
# alpha: 2.44556
# beta: 0.109864
# Eb: 1033.2
# Flux: 5.95416e-08 photons/cm^2/s
#
# FL16Y J1333.5+1539:
# Prefactor: 8.46661
# Index: 2.06172
# Scale: 3418.41
# Flux: 1.15949e-09 photons/cm^2/s
#
# FL16Y J1334.0-1150:
# Prefactor: 1.88768
# Index: 2.18146
# Scale: 2658.29
# Flux: 2.04916e-09 photons/cm^2/s
#
# FL16Y J1336.6-1528:
# Prefactor: 1.81919
# Index: 2.27004
# Scale: 1548.61
# Flux: 7.20602e-09 photons/cm^2/s
#
# FL16Y J1337.2+0036:
# Prefactor: 5.76597
# Index: 2.40305
# Scale: 1469.84
# Flux: 2.62623e-09 photons/cm^2/s
#
# FL16Y J1337.6-1256:
# norm: 6.58667
# alpha: 2.27938
# beta: 0.0961792
# Eb: 735.995
# Flux: 4.02107e-08 photons/cm^2/s
#
# FL16Y J1337.9-1959:
# Prefactor: 1.45983
# Index: 2.49057
# Scale: 1216.79
# Flux: 4.9471e-09 photons/cm^2/s
#
# FL16Y J1338.0-0931:
# Prefactor: 3.47531
# Index: 1.93718
# Scale: 5288.46
# Flux: 8.08448e-10 photons/cm^2/s
#
# FL16Y J1338.9+1153:
# Prefactor: 4.82895
# Index: 1.99289
# Scale: 2798.49
# Flux: 3.72117e-09 photons/cm^2/s
#
# FL16Y J1339.0-2359:
# norm: 9.32671
# alpha: 2.1903
# beta: 0.0779201
# Eb: 1009.31
# Flux: 1.00034e-08 photons/cm^2/s
#
# FL16Y J1339.3-2619:
# Prefactor: 1.98531
# Index: 2.28683
# Scale: 1503.23
# Flux: 7.59282e-09 photons/cm^2/s
#
# FL16Y J1339.9-0136:
# norm: 5.93674
# alpha: 2.176
# beta: 0.450107
# Eb: 1005.78
# Flux: 2.81911e-09 photons/cm^2/s
#
# FL16Y J1340.0-1501:
# Prefactor: 2.14888
# Index: 1.85544
# Scale: 6745.48
# Flux: 6.21639e-10 photons/cm^2/s
#
# FL16Y J1340.6-0411:
# Prefactor: 4.03422
# Index: 2.00799
# Scale: 2848.79
# Flux: 3.33764e-09 photons/cm^2/s
#
# FL16Y J1341.9-2055:
# Prefactor: 1.20778
# Index: 2.69325
# Scale: 632.415
# Flux: 1.02644e-08 photons/cm^2/s
#
# FL16Y J1342.0+1043:
# Prefactor: 2.44723
# Index: 2.33041
# Scale: 1945.94
# Flux: 1.85933e-09 photons/cm^2/s
#
# FL16Y J1342.6+0941:
# Prefactor: 4.1644
# Index: 2.02015
# Scale: 2622.62
# Flux: 3.00023e-09 photons/cm^2/s
#
# FL16Y J1342.7+0503:
# Prefactor: 8.51333
# Index: 2.1503
# Scale: 1839.74
# Flux: 3.88351e-09 photons/cm^2/s
#
# FL16Y J1344.2-1724:
# norm: 2.77448
# alpha: 2.07223
# beta: 0.11991
# Eb: 900.473
# Flux: 1.86685e-08 photons/cm^2/s
#
# FL16Y J1345.8+0707:
# Prefactor: 1.94146
# Index: 2.45695
# Scale: 713.115
# Flux: 1.66503e-08 photons/cm^2/s
#
# FL16Y J1345.9-2611:
# norm: 3.87343
# alpha: 1.91591
# beta: 0.697138
# Eb: 1414.1
# Flux: 1.55614e-09 photons/cm^2/s
#
# FL16Y J1347.9-0615:
# norm: 2.40536
# alpha: 2.15532
# beta: 0.494874
# Eb: 2584.72
# Flux: 3.01575e-10 photons/cm^2/s
#
# FL16Y J1348.9+0756:
# Prefactor: 1.14681
# Index: 1.9897
# Scale: 4027.96
# Flux: 1.81046e-09 photons/cm^2/s
#
# FL16Y J1349.1-1113:
# Prefactor: 1.2153
# Index: 2.59318
# Scale: 1493.25
# Flux: 8.46903e-09 photons/cm^2/s
#
# FL16Y J1349.5-1132:
# norm: 7.14011
# alpha: 2.43571
# beta: 0.192562
# Eb: 1155.1
# Flux: 1.03256e-08 photons/cm^2/s
#
# FL16Y J1350.0+0404:
# Prefactor: 2.90955
# Index: 2.61872
# Scale: 792.906
# Flux: 4.07533e-09 photons/cm^2/s
#
# FL16Y J1351.1+0030:
# norm: 2.36549
# alpha: 2.11501
# beta: 0.204245
# Eb: 1305.45
# Flux: 2.54711e-09 photons/cm^2/s
#
# FL16Y J1351.2-1529:
# Prefactor: 7.27348
# Index: 2.15729
# Scale: 2305.54
# Flux: 5.47678e-09 photons/cm^2/s
#
# FL16Y J1351.3+1114:
# norm: 2.42644
# alpha: 1.8052
# beta: 0.0697489
# Eb: 1963.77
# Flux: 4.84441e-09 photons/cm^2/s
#
# FL16Y J1352.3-0015:
# Prefactor: 2.36558
# Index: 2.36366
# Scale: 2215.13
# Flux: 2.62904e-09 photons/cm^2/s
#
# FL16Y J1353.3+1434:
# Prefactor: 1.62071
# Index: 2.20759
# Scale: 1665.11
# Flux: 6.67734e-09 photons/cm^2/s
#
# FL16Y J1354.1-0205:
# norm: 1.76959
# alpha: 2.65833
# beta: 0.30908
# Eb: 577.524
# Flux: 7.00949e-09 photons/cm^2/s
#
# FL16Y J1354.2+0353:
# Prefactor: 2.09825
# Index: 1.80744
# Scale: 7475.29
# Flux: 6.3233e-10 photons/cm^2/s
#
# FL16Y J1354.7+0622:
# Prefactor: 1.14922
# Index: 1.98233
# Scale: 3377.89
# Flux: 1.25482e-09 photons/cm^2/s
#
# FL16Y J1354.8-1041:
# norm: 2.63432
# alpha: 2.32324
# beta: 0.145944
# Eb: 728.385
# Flux: 1.50787e-08 photons/cm^2/s
#
# FL16Y J1356.2-2455:
# Prefactor: 1.87053
# Index: 2.48505
# Scale: 1138.13
# Flux: 5.31496e-09 photons/cm^2/s
#
# FL16Y J1356.3-1725:
# norm: 3.16701
# alpha: 1.84126
# beta: 0.304817
# Eb: 2741.07
# Flux: 4.65164e-10 photons/cm^2/s
#
# FL16Y J1356.6+0232:
# norm: 3.02007
# alpha: 2.04896
# beta: 0.532285
# Eb: 1286.56
# Flux: 1.49905e-09 photons/cm^2/s
#
# FL16Y J1357.6+0127:
# norm: 1.45993
# alpha: 1.89825
# beta: 0.141357
# Eb: 1914.44
# Flux: 2.48307e-09 photons/cm^2/s
#
# FL16Y J1358.9-0701:
# norm: 8.39915
# alpha: 1.94336
# beta: 0.35666
# Eb: 1944.93
# Flux: 8.30123e-10 photons/cm^2/s
#
# FL16Y J1359.2-1152:
# Prefactor: 2.55512
# Index: 1.56822
# Scale: 18786.5
# Flux: 1.64221e-10 photons/cm^2/s
#
# FL16Y J1359.3+0200:
# Prefactor: 2.30311
# Index: 2.54016
# Scale: 1022.77
# Flux: 5.50026e-09 photons/cm^2/s
#
# FL16Y J1400.1-2415:
# norm: 3.41104
# alpha: 1.69404
# beta: 0.486981
# Eb: 1661.96
# Flux: 1.80832e-09 photons/cm^2/s
#
# FL16Y J1400.6-1432:
# Prefactor: 1.26983
# IndexS: 1.81401
# Scale: 1075.65
# ExpfactorS: 6.89338
# Index2: 0.666667
# Flux: 6.52442e-09 photons/cm^2/s
#
# FL16Y J1401.3-0915:
# norm: 1.21973
# alpha: 1.94914
# beta: 0.158487
# Eb: 1740.36
# Flux: 1.83614e-09 photons/cm^2/s
#
# FL16Y J1402.0-0023:
# norm: 2.35352
# alpha: 2.66459
# beta: 0.379701
# Eb: 446.657
# Flux: 5.10521e-09 photons/cm^2/s
#
# FL16Y J1402.6-1829:
# Prefactor: 1.19161
# Index: 2.70507
# Scale: 630.444
# Flux: 1.01923e-08 photons/cm^2/s
#
# FL16Y J1404.8+0402:
# Prefactor: 1.15169
# Index: 1.97907
# Scale: 2394.7
# Flux: 6.31408e-09 photons/cm^2/s
#
# FL16Y J1405.1-0640:
# Prefactor: 2.02186
# Index: 2.13935
# Scale: 3072.3
# Flux: 2.70157e-09 photons/cm^2/s
#
# FL16Y J1405.1-1550:
# norm: 2.1568
# alpha: 2.31568
# beta: 0.219875
# Eb: 1162.28
# Flux: 2.44462e-09 photons/cm^2/s
#
# FL16Y J1405.8-1853:
# Prefactor: 8.55763
# Index: 1.99449
# Scale: 4110.18
# Flux: 1.42482e-09 photons/cm^2/s
#
# FL16Y J1406.5-1654:
# Prefactor: 4.41864
# Index: 2.26035
# Scale: 1987.46
# Flux: 3.01875e-09 photons/cm^2/s
#
# FL16Y J1408.9-0751:
# norm: 3.91242
# alpha: 2.28918
# beta: 0.103462
# Eb: 1495
# Flux: 9.72877e-08 photons/cm^2/s
#
# FL16Y J1410.1+0202:
# norm: 8.35744
# alpha: 2.11135
# beta: 0.123069
# Eb: 940.467
# Flux: 6.32933e-09 photons/cm^2/s
#
# FL16Y J1410.1+0516:
# Prefactor: 5.36561
# Index: 1.75018
# Scale: 11353.6
# Flux: 2.82316e-10 photons/cm^2/s
#
# FL16Y J1411.5-0724:
# Prefactor: 4.22363
# Index: 1.8748
# Scale: 6619.81
# Flux: 1.25156e-09 photons/cm^2/s
#
# FL16Y J1414.7+0825:
# Prefactor: 1.80151
# Index: 2.85521
# Scale: 451.422
# Flux: 7.19677e-09 photons/cm^2/s
#
# FL16Y J1415.8-1503:
# Prefactor: 8.71156
# Index: 2.36549
# Scale: 1527.95
# Flux: 4.03924e-09 photons/cm^2/s
#
# FL16Y J1416.1-1008:
# norm: 1.04505
# alpha: 2.53626
# beta: 0.379849
# Eb: 665.129
# Flux: 4.30721e-09 photons/cm^2/s
#
# FL16Y J1418.4-0233:
# Prefactor: 4.62628
# IndexS: 1.63871
# Scale: 2550.41
# ExpfactorS: 0.485563
# Index2: 1
# Flux: 1.34735e-08 photons/cm^2/s
#
# FL16Y J1419.3+0445:
# norm: 1.76063
# alpha: 1.65016
# beta: 0.203496
# Eb: 3957.33
# Flux: 4.17694e-10 photons/cm^2/s
#
# FL16Y J1419.4-0838:
# norm: 5.34315
# alpha: 2.13273
# beta: 0.100473
# Eb: 768.711
# Flux: 2.98854e-08 photons/cm^2/s
#
# FL16Y J1420.3+0613:
# Prefactor: 9.48259
# Index: 2.42781
# Scale: 1404.75
# Flux: 4.06396e-09 photons/cm^2/s
#
# FL16Y J1421.1-1119:
# norm: 5.52918
# alpha: 2.24737
# beta: 0.112023
# Eb: 990.772
# Flux: 5.66527e-09 photons/cm^2/s
#
# FL16Y J1421.4-1655:
# Prefactor: 2.11952
# Index: 1.80273
# Scale: 7406.57
# Flux: 6.19134e-10 photons/cm^2/s
#
# FL16Y J1423.7-0534:
# Prefactor: 1.25946
# Index: 2.89291
# Scale: 489.636
# Flux: 6.60322e-09 photons/cm^2/s
#
# FL16Y J1424.0-1751:
# Prefactor: 1.32138
# Index: 1.88648
# Scale: 4350.86
# Flux: 1.83858e-09 photons/cm^2/s
#
# FL16Y J1424.1+0433:
# norm: 5.33823
# alpha: 1.97463
# beta: 0.123127
# Eb: 1272.9
# Flux: 5.70295e-09 photons/cm^2/s
#
# FL16Y J1425.4-0119:
# norm: 4.85547
# alpha: 1.72956
# beta: 0.355455
# Eb: 5863.22
# Flux: 1.2243e-10 photons/cm^2/s
#
# FL16Y J1427.7+0001:
# Prefactor: 2.24508
# Index: 1.9794
# Scale: 5731.34
# Flux: 6.92977e-10 photons/cm^2/s
#
# FL16Y J1428.8-1017:
# Prefactor: 2.2967
# Index: 1.68795
# Scale: 8642.15
# Flux: 6.18531e-10 photons/cm^2/s
#
# FL16Y J1429.7-0736:
# norm: 1.74233
# alpha: 2.07778
# beta: 0.508152
# Eb: 1532.9
# Flux: 1.12157e-09 photons/cm^2/s
#
# gll_iem_v07:
# Prefactor: 0.916817 +/- 0.0359692
# Index: -0.0965872 +/- 0.00688992
# Scale: 100
# Flux: 0.000432913 +/- 1.58928e-05 photons/cm^2/s
#
# iso_P8R3_SOURCE_V3_v1:
# Normalization: 1.51278 +/- 0.0530332
# Flux: 0.000185865 +/- 6.5147e-06 photons/cm^2/s
# WARNING: Fit may be bad in range [100, 251.124] (MeV)
# WARNING: Fit may be bad in range [316.126, 1583.67] (MeV)
# WARNING: Fit may be bad in range [1993.6, 2509.63] (MeV)
# WARNING: Fit may be bad in range [39744.4, 50032.1] (MeV)
# Total number of observed counts: 207751
# Total number of model events: 201723
#
# -log(Likelihood): 76964.13018
#
# Writing fitted model to ./data/3C279_binned_output.xml
# Elapsed CPU time: 21.951935

# %% [markdown]
# Most of the entries prompted for are fairly obvious. In addition to the various XML and FITS files, the user is prompted for a choice of IRFs, the type of statistic to use, and the optimizer.

# %% [markdown]
# The statistics available are:
# * **UNBINNED**: This should be used for short timescale or low source count data. If this option is chosen then parameters for the spacecraft file, event file, and exposure file must be given. See explanation in: [Likelihood Tutorial]()
#
# * **BINNED**: This is a standard binned analysis as described in this tutorial. This analysis is used for long timescale or high-density data (such as in the Galactic plane) which can cause memory errors in the unbinned analysis. If this option is chosen then parameters for the source map file, livetime file, and exposure file must be given.

# %% [markdown]
# There are five optimizers from which to choose: `DRMNGB`, `DRMNFB`, `NEWMINUIT`, `MINUIT` and `LBFGS`. Generally speaking, the faster way to find the parameter estimates is to use `DRMNGB` (or `DRMNFB`) to find initial values and then use `MINUIT` (or `NEWMINUIT`) to find more accurate results. If you have trouble achieving convergence at first, you can loosen your tolerance by setting the hidden parameter `ftol` on the command line. (The default value for `ftol` is `0.001`.)

# %% [markdown]
# Analyzing a 2-year dataset will take some time. The required running time will be higher if your source is in the Galactic plane. Here is some output from our fit, where J1229.0+0202 and J1256.1-0547 corresponds to 3C 273 and 3C 279, respectively:

# %% [markdown]
# Since we selected `plot=yes` in the command line, a plot of the fitted data appears.
#
# <img src="https://fermi.gsfc.nasa.gov/ssc/data/analysis/scitools/images/BinnedLikelihood/3C279_binned_spectral_fit.png">

# %% [markdown]
# In the first plot, the counts/MeV vs MeV are plotted. The points are the data, and the lines are the models. Error bars on the points represent sqrt(Nobs) in that band, where Nobs is the observed number of counts. The black line is the sum of the models for all sources.
#
# The colored lines follow the sources as follows:
# * Black - summed model
# * Red - first source (see below)
# * Green - second source
# * Blue - third source
# * Magenta - fourth source
# * Cyan - the fifth source
#
# If you have more sources, the colors are reused in the same order. In our case we have, in order of decreasing value on the y-axis: summed model (black), the extragalactic background (black), the galactic background (cyan), 3C 273 (red), and 3C 279 (black).
#
# The second plot gives the residuals between your model and the data. Error bars here represent (sqrt(Nopbs))/Npred, where Npred is the predicted number of counts in each band based on the fitted model.

# %% [markdown]
# To assess the quality of the fit, look first for the words at the top of the output `<Optimizer> did successfully converge.` Successful convergence is a minimum requirement for a good fit.
#
# Next, look at the energy ranges that are generating warnings of bad fits. If any of these ranges affect your source of interest, you may need to revise the source model and refit. You can also look at the residuals on the plot (bottom panel). If the residuals indicate a poor fit overall (e.g., the points trending all low or all high) you should consider changing your model file, perhaps by using a different source model definition, and refit the data.
#
# If the fits and spectral shapes are good, but could be improved, you may wish to simply update your model file to hold some of the spectral parameters fixed. For example, by fixing the spectral model for 3C 273, you may get a better quality fit for 3C 279. Close the plot and you will be asked if you wish to refit the data.

# %% [markdown]
# ```
# Refit? [y] n
# Elapsed CPU time: 1571.805872
# ```

# %% [markdown]
# Here, hitting `return` will instruct the application to fit again. We are happy with the result, so we type `n` and end the fit.

# %% [markdown]
# ### Results
#
# When it completes, **gtlike** generates a standard output XML file. If you re-run the tool in the same directory, these files will be overwritten by default. Use the `clobber=no` option on the command line to keep from overwriting the output files.
#
# Unfortunately, the fit details and the value for the `-log(likelihood)` are not recorded in the automatic output files.
#
# You should consider logging the output to a text file for your records by using `> fit_data.txt` (or something similar) with your **gtlike** command.
#
# Be aware, however, that this will make it impossible to request a refit when the likelihood process completes.

# %% [markdown]
# In this example, we used the `sfile` parameter to request that the model results be written to an output XML file. This file contains the source model results that were written to `results.dat` at the completion of the fit.
#
# >    **Note**: If you have specified an output XML model file and you wish to modify your model while waiting at the `Refit? [y]` prompt, you will need to copy the results of the output model file to your input model before making those modifications.

# %% [markdown]
# The results of the likelihood analysis have to be scaled by the quantity called "scale" in the XML model in order to obtain the total photon flux (photons cm-2 s-1) of the source. You must refer to the model formula of your source for the interpretation of each parameter. In our example the 'prefactor' of our power law model of the first fitted source (J1119.9-1007) has to be scaled by the factor 'scale'=10-14. For example the total flux of J1159.5-0723 is the integral between 100 MeV and 500000 MeV of:

# %% [markdown]
# $Prefactor \cdot scale \cdot (E /100)^{index}=(6.65x10^{-14}) \cdot (E/100)^{-2.209}$

# %% [markdown]
# Errors reported with each value in the `results.dat` file are 1Ïƒ estimates (based on inverse-Hessian at the optimum of the log-likelihood surface).

# %% [markdown]
# ### Other Useful Hidden Parameters
#
# If you are scripting and wish to generate multiple output files without overwriting, the `results` and `specfile` parameters allow you to specify output filenames for the `results.dat` and `counts_spectra.fits` files respectively.
#
# If you do not specify a source model output file with the `sfile` parameter, then the input model file will be overwritten with the latest fit. This is convenient as it allows the user to edit that file while the application is waiting at the `Refit? [y]` prompt so that parameters can be adjusted and set free or fixed. This would be similar to the use of the "newpar", "freeze", and "thaw" commands in [XSPEC](http://heasarc.gsfc.nasa.gov/docs/xanadu/xspec/index.html).

# %% [markdown]
# # 10. Create a model map
#
# For comparison to the counts map data, we create a model map of the region based on the fit parameters.
#
# This map is essentially an infinite-statistics counts map of the region-of-interest based on our model fit.
#
# The [gtmodel](https://fermi.gsfc.nasa.gov/ssc/data/analysis/scitools/help/gtmodel.txt) application reads in the fitted model, applies the proper scaling to the source maps, and adds them together to get the final map.

# %%
# %%bash
# gtmodel
#     ./data/3C279_binned_srcmaps.fits
#     ./data/3C279_binned_output.xml
#     ./data/3C279_model_map.fits
#     CALDB
#     ./data/3C279_binned_ltcube.fits
#     ./data/3C279_binned_allsky_expcube.fits
# Out:
# Source maps (or counts map) file[./data/3C279_binned_srcmaps.fits] Source model file[./data/3C279_binned_output.xml] Output file[./data/3C279_model_map.fits] Response functions[CALDB] Exposure cube[./data/3C279_binned_ltcube.fits] Binned exposure map[./data/3C279_binned_allsky_expcube.fits]

# %% [markdown]
# To understand how well the fit matches the data, we want to compare the [model map](https://fermi.gsfc.nasa.gov/ssc/data/analysis/scitools/data/BinnedLikelihood/3C279_model_map.fits) just created with the counts map over the same field of view. First we have to create the [new counts map](https://fermi.gsfc.nasa.gov/ssc/data/analysis/scitools/data/BinnedLikelihood/3C279_binned_cmap_small.fits) that matches in size the model map (the one generated in encircles the ROI, while the model map is completely inscribed within the ROI): We will use again the [gtbin](https://fermi.gsfc.nasa.gov/ssc/data/analysis/scitools/help/gtbin.txt) tool with the option `CMAP` as shown below:

# %%
# %%bash
# gtbin
#     CMAP
#     ./data/3C279_binned_gti.fits
#     ./data/3C279_binned_cmap_small.fits
#     NONE
#     100
#     100
#     0.2
#     CEL
#     193.98
#     -5.82
#     0.0
#     STG
# Out:
# This is gtbin version HEAD
# Type of output file (CCUBE|CMAP|LC|PHA1|PHA2|HEALPIX) [CCUBE] Event data file name[./data/3C279_binned_gti.fits] Output file name[./data/3C279_binned_ccube.fits] Spacecraft data file name[NONE] Size of the X axis in pixels[100] Size of the Y axis in pixels[100] Image scale (in degrees/pixel)[0.2] Coordinate system (CEL - celestial, GAL -galactic) (CEL|GAL) [CEL] First coordinate of image center in degrees (RA or galactic l)[193.98] Second coordinate of image center in degrees (DEC or galactic b)[-5.82] Rotation angle of image axis, in degrees[0] Projection method e.g. AIT|ARC|CAR|GLS|MER|NCP|SIN|STG|TAN:[AIT]
# gtbin: WARNING: No spacecraft file: EXPOSURE keyword will be set equal to ontime.

# %% [markdown]
# Here we've plotted the model map next to the the energy-summed counts map for the data.
#
# <img src='https://fermi.gsfc.nasa.gov/ssc/data/analysis/scitools/images/BinnedLikelihood/3C279_binned_map_comparison.png'>

# %% [markdown]
# Finally we want to create the [residual map](https://fermi.gsfc.nasa.gov/ssc/data/analysis/scitools/data/BinnedLikelihood/3C279_residual.fits) by using the FTOOL **farith** to check if we can improve the model. For this section you need to install [FTOOLS](https://heasarc.gsfc.nasa.gov/ftools/) separately. A possible sequence is farith
#     ./data/3C279_binned_cmap_small.fits
#     ./data/3C279_model_map.fits
#     ./data/3C279_residual.fits
#     SUB

# %% [markdown]
# The residual map is shown below. As you can see, the binning we chose probably used pixels that were too large.
#
# The primary sources, 3C 273 and 3C 279, have some positive pixels next to some negative ones. This effect could be lessened by either using a smaller pixel size or by offsetting the central position slightly from the position of the blazar (or both).
#
# If your residual map contains bright sources, the next step would be to iterate the analysis with the additional sources included in the XML model file.
#
# <img src='https://fermi.gsfc.nasa.gov/ssc/data/analysis/scitools/images/BinnedLikelihood/3C279_binned_residuals.png'>
